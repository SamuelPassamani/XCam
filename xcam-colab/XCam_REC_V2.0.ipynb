# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelPassamani/XCam/blob/notebook-auto/xcam-colab/XCam_REC_V2.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Célula 1: Configurações Auxiliares e Parâmetros Gerais
#
# **Objetivo:**
# Esta célula inicializa variáveis globais para ajuste rápido do comportamento do notebook, como:
#
# Quantidade de transmissões por página
#
# *   Quantidade de transmissões por página (LIMIT_DEFAULT)
# *   Página inicial a ser buscada (PAGE_DEFAULT)
# *   Tempo máximo de gravação de cada vídeo (RECORD_SECONDS)
# *   Tempo mínimo exigido para considerar o vídeo válido (RECORD_SECONDS_MIN)
# *   Limite de busca ao procurar usuários específicos (API_SEARCH_LIMIT)
#
# **Interatividade:**
# Inclui a função perguntar_transmissoes_especificas() que pergunta ao usuário se deseja gravar transmissões de usuários específicos. Caso sim, solicita os nomes e retorna uma lista.
#
# **Como funciona:**
# Antes do processamento, você pode ajustar facilmente qualquer parâmetro. O notebook perguntará se você quer gravar transmissões de usuários específicos e, se quiser, pedirá os nomes (ex: "userNovo234, jovemPT").

# %%
# Célula 1: Configurações Auxiliares e Parâmetros Gerais
# ------------------------------------------------------
# Ajuste facilmente os principais parâmetros do sistema e escolha se deseja gravar transmissões específicas.

import os

# Parâmetros globais editáveis
LIMIT_DEFAULT = 33           # Quantidade padrão de transmissões por página
PAGE_DEFAULT = 1             # Página inicial
RECORD_SECONDS = 1980         # Tempo máximo de gravação por vídeo (segundos)
RECORD_SECONDS_MIN = 420      # Tempo mínimo de gravação exigido para upload (segundos)
API_SEARCH_LIMIT = 1000      # Limite máximo para busca de usuários específicos

globals().update({
    'LIMIT_DEFAULT': LIMIT_DEFAULT,
    'PAGE_DEFAULT': PAGE_DEFAULT,
    'RECORD_SECONDS': RECORD_SECONDS,
    'RECORD_SECONDS_MIN': RECORD_SECONDS_MIN,
    'API_SEARCH_LIMIT': API_SEARCH_LIMIT
})

def perguntar_transmissoes_especificas():
    resp = input('Deseja gravar alguma transmissão específica? (sim/não): ').strip().lower()
    if resp.startswith('s'):
        usuarios = input('Informe o(s) nome(s) de usuário, separados por vírgula (ex: userNovo234, jovemPT): ')
        usuarios_lista = [u.strip() for u in usuarios.split(',') if u.strip()]
        return usuarios_lista
    return []

# %% [markdown]
# # Célula 2: Instalação do ffmpeg
#
# **Objetivo:**
# Garante que o ffmpeg esteja instalado no ambiente do Google Colab. O ffmpeg é fundamental para gravar os vídeos das transmissões.
#
# **Como funciona:**
# Executa comandos de instalação do ffmpeg, necessários para o funcionamento correto das próximas etapas.

# %%
# Célula 2: Instalação do ffmpeg
# ------------------------------
# Garante que o ffmpeg está instalado no ambiente Colab.

# !apt-get update -y
# !apt-get install -y ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,721 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,994 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,736 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,953 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,246 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,553 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,264 kB]
# Fetched 22.9 MB in 4s (5,229 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %% [markdown]
# # Célula 3: Imports Essenciais e Funções Utilitárias
#
# **Objetivo:**
# Importa todas as bibliotecas do Python necessárias (como requests, multiprocessing, datetime, etc.) e define funções utilitárias para:
#
# *   Formatar o tempo de gravação (format_seconds)
# *   Exibir logs de progresso (log_progress)
# *   Baixar e salvar a imagem de poster de cada transmissão (download_and_save_poster)
#
# **Como funciona:**
# Essas funções são usadas em várias partes do notebook para manipular tempos, apresentar informações mais amigáveis e garantir que os posters das transmissões sejam baixados corretamente.

# %%
# Célula 3: Imports essenciais e utilitários
# ------------------------------------------
# Importação de bibliotecas e funções auxiliares de formatação e download.

import os
import requests
import multiprocessing
from datetime import datetime
import json
import time
import subprocess
import math
import re

from IPython import get_ipython
from IPython.display import display

def format_seconds(seconds):
    total_seconds = int(seconds)
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    parts = []
    if hours > 0: parts.append(f"{hours}h")
    if minutes > 0 or (hours == 0 and seconds > 0): parts.append(f"{minutes}m")
    if seconds > 0 or total_seconds == 0: parts.append(f"{seconds}s")
    return "".join(parts) if parts else "0s"

def log_progress(username, elapsed_seconds, total_seconds):
    percent = min((elapsed_seconds / total_seconds) * 100, 100)
    tempo = format_seconds(elapsed_seconds)
    minutos_gravados = math.floor(elapsed_seconds / 60)
    minutos_restantes = max(0, math.ceil((total_seconds - elapsed_seconds) / 60))
    print(f"⏱️ [{username}] Gravados: {minutos_gravados} min | Restantes: {minutos_restantes} min | Tempo total: {tempo} — 📊 {percent:.1f}% concluído")

def download_and_save_poster(poster_url, username, temp_folder):
    try:
        response = requests.get(poster_url, timeout=15)
        response.raise_for_status()
        ext = os.path.splitext(poster_url)[1].lower()
        if ext not in [".jpg", ".jpeg", ".png"]:
            ext = ".jpg"
        poster_temp_path = os.path.join(temp_folder, f"{username}_poster_temp{ext}")
        with open(poster_temp_path, "wb") as f:
            f.write(response.content)
        print(f"🖼️ Poster baixado em: {poster_temp_path}")
        return poster_temp_path
    except Exception as e:
        print(f"❌ Erro ao baixar poster {poster_url}: {e}")
        return None

# %% [markdown]
# # Célula 4: Clonagem do Repositório GitHub para o Colab
#
# **Objetivo:**
# Clona o repositório do GitHub para o ambiente local do Colab, garantindo que o ambiente sempre esteja atualizado e pronto para armazenar os arquivos gerados.
#
# **Como funciona:**
# Remove qualquer repositório anterior para evitar conflitos, clona o novo, prepara pastas temporárias e define a URL de upload para o Abyss.to.

# %%
# Célula 4: Clonagem do repositório GitHub para o Colab
# -----------------------------------------------------
# Clona o repositório para o ambiente Colab, garantindo ambiente limpo e atualizado.

GITHUB_USER = "SamuelPassamani"
GITHUB_REPO = "XCam"
GITHUB_BRANCH = "notebook-auto"
GITHUB_TOKEN = "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"

repo_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"

# !rm -rf {GITHUB_REPO}
# !git clone -b {GITHUB_BRANCH} {repo_url}

TEMP_OUTPUT_FOLDER = "/content/temp_recordings"
os.makedirs(TEMP_OUTPUT_FOLDER, exist_ok=True)
BASE_REPO_FOLDER = f"/content/{GITHUB_REPO}"

ABYSS_UPLOAD_URL = 'http://up.hydrax.net/0128263f78f0b426d617bb61c2a8ff43'
# Out:
# Cloning into 'XCam'...
# fatal: Remote branch notebook-auto not found in upstream origin

# %% [markdown]
# # Célula 5: Commit e Push Automáticos (rec.json e poster)
#
# **Objetivo:**
# Define a função git_commit_and_push() para garantir que apenas arquivos importantes (JSON de gravação e posters de imagem) sejam adicionados, commitados e enviados ao repositório.
#
# **Como funciona:**
# Configura o git, adiciona o arquivo desejado, faz commit e push para o repositório remoto.

# %%
# Célula 5: Commit e Push automáticos (rec.json e poster)
# -------------------------------------------------------
def git_commit_and_push(file_path, commit_message="Atualiza rec.json"):
    repo_dir = f"/content/{GITHUB_REPO}"
    os.chdir(repo_dir)
    subprocess.run(["git", "config", "user.email", "colab@xcam.com"])
    subprocess.run(["git", "config", "user.name", "Colab XCam Bot"])
    subprocess.run(["git", "add", file_path])
    subprocess.run(["git", "commit", "-m", commit_message, "--allow-empty"], check=False)
    subprocess.run([
        "git", "push", f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"
    ])

# %% [markdown]
# # Célula 6: Busca de Transmissões na API XCam, com Fallback via liveInfo
#
# **Objetivo:**
# Busca as transmissões ativas na API principal da XCam. Se alguma transmissão não retornar o link da stream (src), faz um fallback via a API /liveInfo do usuário para tentar obter o link direto e o poster.
#
# **Como funciona:**
#
# *   Para cada transmissão encontrada, retorna um dicionário com username, src (endereço do stream) e poster (imagem).
# *   Se for solicitado buscar usuários específicos, só retorna esses.
# *   Caso algum usuário não tenha src, faz nova chamada à API liveInfo para tentar encontrar o link e o poster.

# %%
# Célula 6: Busca de transmissões na API XCam, com fallback via liveInfo
# ----------------------------------------------------------------------
def get_broadcasts(limit=LIMIT_DEFAULT, page=PAGE_DEFAULT, usuarios_especificos=None):
    """
    Busca transmissões ao vivo via API principal da XCam.
    Se usuarios_especificos for fornecido (lista), retorna apenas essas transmissões.
    Faz fallback via liveInfo para transmissões sem src.
    """
    api_url_main = f"https://api.xcam.gay/?limit={limit}&page={page}"
    print(f"🌐 Acessando API principal: {api_url_main}")

    streams_from_main = []
    streams_without_preview = []

    try:
        response_main = requests.get(api_url_main)
        response_main.raise_for_status()
        data_main = response_main.json()
        broadcasts_data = data_main.get("broadcasts")
        if not broadcasts_data:
            print("⚠️ Chave 'broadcasts' não encontrada na resposta da API principal.")
            return []
        items = broadcasts_data.get("items")
        if not isinstance(items, list):
            print(f"⚠️ Chave 'items' não encontrada ou não é uma lista em 'broadcasts'.")
            return []

        for item in items:
            preview = item.get("preview") or {}
            src = preview.get("src")
            poster = preview.get("poster")
            username = item.get("username", "desconhecido")
            if src:
                if (not usuarios_especificos) or (username in usuarios_especificos):
                    streams_from_main.append({
                        "username": username,
                        "src": src,
                        "poster": poster
                    })
            else:
                if (not usuarios_especificos) or (username in usuarios_especificos):
                    streams_without_preview.append({"username": username})

        print(f"✅ {len(streams_from_main)} transmissões com URL na API principal (página {page}).")

    except Exception as e:
        print(f"❌ Erro ao acessar API principal: {e}")
        return []

    # Fallback: busca via liveInfo para streams sem URL na API principal
    streams_from_liveinfo = []
    if streams_without_preview:
        print(f"🔁 Buscando liveInfo para {len(streams_without_preview)} streams sem URL na API principal...")
        for stream_info in streams_without_preview:
            username = stream_info["username"]
            api_url_liveinfo = f"https://api.xcam.gay/user/{username}/liveInfo"
            try:
                response_liveinfo = requests.get(api_url_liveinfo)
                response_liveinfo.raise_for_status()
                data_liveinfo = response_liveinfo.json()
                m3u8_url = data_liveinfo.get("cdnURL") or data_liveinfo.get("edgeURL")
                poster = data_liveinfo.get("poster")
                if m3u8_url:
                    streams_from_liveinfo.append({
                        "username": username,
                        "src": m3u8_url,
                        "poster": poster
                    })
            except Exception:
                pass
            time.sleep(0.5)

    final_streams_list = streams_from_main + streams_from_liveinfo
    print(f"🔎 Página {page}: {len(final_streams_list)} streams válidas após fallback.")
    return final_streams_list

def buscar_usuarios_especificos(usuarios_lista):
    """
    Busca usuários específicos via API, utilizando um limit alto.
    Fallback via liveInfo para usuários sem src.
    """
    api_url = f"https://api.xcam.gay/?limit={API_SEARCH_LIMIT}&page=1"
    print(f"🔍 Buscando usuários específicos em {api_url}")
    try:
        response = requests.get(api_url)
        response.raise_for_status()
        data = response.json()
        items = data.get("broadcasts", {}).get("items", [])
        encontrados = []
        sem_src = []
        for item in items:
            username = item.get("username", "")
            if username in usuarios_lista:
                preview = item.get("preview") or {}
                src = preview.get("src")
                poster = preview.get("poster")
                if src:
                    encontrados.append({
                        "username": username,
                        "src": src,
                        "poster": poster
                    })
                else:
                    sem_src.append(username)
        # Fallback via liveInfo
        for username in sem_src:
            api_url_liveinfo = f"https://api.xcam.gay/user/{username}/liveInfo"
            try:
                response_liveinfo = requests.get(api_url_liveinfo)
                response_liveinfo.raise_for_status()
                data_liveinfo = response_liveinfo.json()
                m3u8_url = data_liveinfo.get("cdnURL") or data_liveinfo.get("edgeURL")
                poster = data_liveinfo.get("poster")
                if m3u8_url:
                    encontrados.append({
                        "username": username,
                        "src": m3u8_url,
                        "poster": poster
                    })
            except Exception:
                pass
            time.sleep(0.5)
        print(f"Encontrados {len(encontrados)} dos {len(usuarios_lista)} usuários procurados (incluindo fallback).")
        return encontrados
    except Exception as e:
        print(f"❌ Erro ao buscar usuários específicos: {e}")
        return []

# %% [markdown]
# # Célula 7: Gravação da Stream, Download do Poster e Controle de Tempo Mínimo
#
# **Objetivo:**
# Grava a transmissão ao vivo do usuário usando ffmpeg. Durante a gravação, baixa o poster da transmissão e, ao final, verifica se o tempo de gravação atingiu o mínimo desejado para ser considerado válido.
#
# **Como funciona:**
#
# *  Se o vídeo gravado for muito curto, descarta imediatamente o vídeo e o poster.
# *  Se for suficiente, renomeia o vídeo, faz upload, renomeia o poster e chama a função de atualização de JSON.

# %%
# Célula 7: Gravação de stream, download do poster e controle de tempo mínimo
# ---------------------------------------------------------------------------
def gravar_stream(username, m3u8_url, poster_url=None):
    start_time_dt = datetime.now()
    data_str = start_time_dt.strftime("%d-%m-%Y")
    horario_str = start_time_dt.strftime("%H-%M")
    temp_filename = f"{username}_{start_time_dt.strftime('%Y%m%d_%H%M%S')}_temp.mp4"
    filepath = os.path.join(TEMP_OUTPUT_FOLDER, temp_filename)

    print(f"\n🎬 Iniciando gravação de: {username} (URL: {m3u8_url}) em {filepath}")

    poster_temp_path = None
    if poster_url:
        poster_temp_path = download_and_save_poster(poster_url, username, TEMP_OUTPUT_FOLDER)

    ffmpeg_cmd = ["ffmpeg", "-i", m3u8_url, "-t", str(RECORD_SECONDS), "-c", "copy", "-y", filepath]

    start_time_process = time.time()
    process = None

    try:
        process = subprocess.Popen(ffmpeg_cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, universal_newlines=True)
        elapsed_seconds = 0
        last_log_minute = -1
        while True:
            line = process.stdout.readline()
            if not line and process.poll() is not None:
                break
            if "time=" in line:
                try:
                    match = re.search(r"time=(\d+):(\d+):(\d+)", line)
                    if match:
                        h, m, s = map(int, match.groups())
                        elapsed_seconds = h * 3600 + m * 60 + s
                        if elapsed_seconds // 60 != last_log_minute:
                            log_progress(username, elapsed_seconds, RECORD_SECONDS)
                            last_log_minute = elapsed_seconds // 60
                except Exception:
                    pass

        process.wait()
        end_time_process = time.time()
        elapsed_seconds = round(end_time_process - start_time_process)
        log_progress(username, elapsed_seconds, RECORD_SECONDS)

        if process.returncode != 0:
            print(f"❌ FFmpeg falhou para {username}. Código de saída: {process.returncode}")
            return {'username': username, 'filename': temp_filename, 'filepath': filepath, 'upload_success': False, 'abyss_response': "Gravação FFmpeg falhou"}
        else:
            print(f"✅ Gravação FFmpeg finalizada para: {temp_filename}. Duração aproximada: {elapsed_seconds}s")

            if elapsed_seconds < RECORD_SECONDS_MIN:
                print(f"⏩ Duração gravada ({elapsed_seconds}s) menor que o mínimo ({RECORD_SECONDS_MIN}s). Arquivo descartado.")
                if os.path.exists(filepath): os.remove(filepath)
                if poster_temp_path and os.path.exists(poster_temp_path): os.remove(poster_temp_path)
                return {'username': username, 'filename': temp_filename, 'filepath': filepath, 'upload_success': False, 'abyss_response': "Gravação muito curta (descartada)"}

            tempo_formatado = format_seconds(elapsed_seconds)
            final_filename = f"{username}_{data_str}_{horario_str}_{tempo_formatado}.mp4"
            final_filepath = os.path.join(TEMP_OUTPUT_FOLDER, final_filename)

            try:
                os.rename(filepath, final_filepath)
                print(f"✅ Arquivo renomeado para: {final_filename}")
                filepath_for_upload = final_filepath
                filename_for_upload = final_filename
            except Exception as e:
                print(f"❌ Erro ao renomear arquivo {temp_filename} para {final_filename}: {e}")
                filepath_for_upload = filepath
                filename_for_upload = temp_filename

            success, abyss_resp, slug = upload_to_abyss_and_update_json(
                filepath_for_upload, username, elapsed_seconds,
                poster_temp_path=poster_temp_path
            )

            return {
                'username': username,
                'filename': filename_for_upload,
                'filepath': filepath_for_upload,
                'upload_success': success,
                'abyss_response': abyss_resp,
                'slug': slug
            }

    except FileNotFoundError:
        print(f"❌ Erro: Comando 'ffmpeg' não encontrado. Certifique-se de que foi instalado corretamente.")
        return {'username': username, 'filename': None, 'filepath': None, 'upload_success': False, 'abyss_response': "Comando FFmpeg não encontrado"}
    except Exception as e:
        print(f"❌ Erro inesperado durante a execução do FFmpeg para {username}: {e}")
        return {'username': username, 'filename': None, 'filepath': None, 'upload_success': False, 'abyss_response': f"Erro inesperado na execução do FFmpeg: {e}"}
    finally:
        if 'filepath_for_upload' in locals() and os.path.exists(filepath_for_upload):
            try:
                os.remove(filepath_for_upload)
                print(f"🗑️ Arquivo de vídeo removido do Colab: {filepath_for_upload}")
            except Exception as e:
                print(f"⚠️ Não foi possível remover o arquivo de vídeo temporário: {e}")

# %% [markdown]
# # Célula 8: Upload para Abyss.to, Atualização do rec.json, Commit do Poster
#
# **Objetivo:**
# Faz upload do vídeo para o Abyss.to. Se bem-sucedido, renomeia/move o poster para a pasta correta do repositório, atualiza/cria o arquivo rec.json do usuário com todos os metadados (incluindo poster e urlIframe) e faz commit/push dos arquivos.
#
# **Como funciona:**
#
# *   Preenche todos os campos do JSON conforme seu padrão.
# *   Garante que apenas vídeos válidos sejam registrados e compartilha os links corretos.

# %%
# Célula 8: Upload para Abyss.to, atualização do rec.json, commit do poster
# -------------------------------------------------------------------------
def upload_to_abyss_and_update_json(filepath, username, duration_seconds, poster_temp_path=None):
    file_name = os.path.basename(filepath)
    file_type = 'video/mp4'
    print(f"⬆️ Upload de: {file_name} para Abyss.to...")

    upload_success = False
    abyss_response = "Upload falhou - Sem resposta"
    uploaded_url = None
    video_id = None
    slug = None

    try:
        with open(filepath, 'rb') as f:
            files = { 'file': (file_name, f, file_type) }
            response = requests.post(ABYSS_UPLOAD_URL, files=files)
            resp_json = response.json()
            abyss_response = resp_json
            if resp_json.get('status'):
                upload_success = True
                uploaded_url = resp_json.get('url') or resp_json.get('urlIframe')
                video_id = resp_json.get('slug') or resp_json.get('video')
                slug = video_id
                print(f"📤 Upload bem-sucedido. URL: {uploaded_url} | SLUG: {slug}")
            else:
                print(f"❌ Falha no upload. Mensagem: {resp_json.get('message','')}")
    except Exception as e:
        abyss_response = f"Erro no upload: {e}"
        print(f"❌ Erro no upload: {e}")

    poster_final_relpath = None
    if upload_success and poster_temp_path and slug:
        try:
            user_folder = os.path.join(BASE_REPO_FOLDER, "xcam-db", "user", username)
            os.makedirs(user_folder, exist_ok=True)
            poster_final_name = f"{slug}.jpg"
            poster_final_path = os.path.join(user_folder, poster_final_name)
            os.rename(poster_temp_path, poster_final_path)
            poster_final_relpath = os.path.relpath(poster_final_path, BASE_REPO_FOLDER)
            print(f"🖼️ Poster movido para {poster_final_path}")
            git_commit_and_push(poster_final_relpath, commit_message=f"Add poster {poster_final_name} do usuário {username}")
        except Exception as e:
            print(f"❌ Erro ao mover/renomear poster: {e}")

    if upload_success:
        try:
            user_folder = os.path.join(BASE_REPO_FOLDER, "xcam-db", "user", username)
            os.makedirs(user_folder, exist_ok=True)
            json_filepath = os.path.join(user_folder, "rec.json")

            file_base = file_name.replace('.mp4', '')
            parts = file_base.split('_')
            if len(parts) >= 4:
                json_data = parts[-3]
                json_horario = parts[-2]
                json_tempo = parts[-1]
            else:
                now = datetime.now()
                json_data = now.strftime("%d-%m-%Y")
                json_horario = now.strftime("%H-%M")
                json_tempo = format_seconds(duration_seconds)

            poster_url = f"https://db.xcam.gay/user/{username}/{slug}.jpg" if slug else ""
            url_iframe = f"https://short.icu/{slug}?thumbnail={poster_url}" if slug else ""

            new_video_entry = {
                "video": slug if slug else "ID_não_retornado",
                "title": file_base,
                "file": file_name,
                "url": uploaded_url if uploaded_url else "URL_não_retornada",
                "poster": poster_url,
                "urlIframe": url_iframe,
                "data": json_data,
                "horario": json_horario,
                "tempo": json_tempo
            }

            def zerar_base(username):
                return {
                    "username": username,
                    "records": 0,
                    "videos": []
                }

            if not os.path.exists(json_filepath):
                rec_data = zerar_base(username)
            else:
                try:
                    with open(json_filepath, 'r', encoding='utf-8') as f:
                        loaded = json.load(f)
                    valid = (
                        isinstance(loaded, dict)
                        and "username" in loaded
                        and "records" in loaded
                        and "videos" in loaded
                        and isinstance(loaded["videos"], list)
                    )
                    rec_data = loaded if valid else zerar_base(username)
                except Exception:
                    rec_data = zerar_base(username)

            rec_data["records"] += 1
            rec_data["videos"].append(new_video_entry)
            with open(json_filepath, 'w', encoding='utf-8') as f:
                json.dump(rec_data, f, indent=2, ensure_ascii=False)
            print(f"✅ rec.json para {username} atualizado em {json_filepath}")

            rel_json_path = os.path.relpath(json_filepath, BASE_REPO_FOLDER)
            git_commit_and_push(rel_json_path, commit_message=f"Atualiza rec.json do usuário {username}")
        except Exception as e:
            print(f"❌ Erro ao atualizar rec.json: {e}")
            abyss_response = f"Upload sucesso, erro no JSON: {e}"

    if poster_temp_path and os.path.exists(poster_temp_path):
        try:
            os.remove(poster_temp_path)
            print(f"🗑️ Poster temporário removido: {poster_temp_path}")
        except Exception as e:
            print(f"⚠️ Não foi possível remover o poster temporário: {e}")

    return upload_success, abyss_response, slug

# %% [markdown]
# # Célula 9: Processamento Automático (Paralelo e Interativo)
#
# **Objetivo:**
# Controla todo o fluxo do notebook, processando as transmissões em paralelo (mais de uma ao mesmo tempo) para eficiência. Utiliza as funções anteriores para buscar, gravar, processar, fazer upload e registrar os vídeos.
#
# **Como funciona:**
#
# *   Se o usuário informou nomes específicos, busca/grava apenas esses.
# *   Caso contrário, processa normalmente por páginas.
# *   Mantém o loop até não encontrar mais transmissões.
# *   Exibe logs amigáveis e controla a espera entre páginas.

# %%
# Célula 9: Processamento automático (paralelo e interativo)
# ----------------------------------------------------------
def process_page(page=PAGE_DEFAULT, limit=LIMIT_DEFAULT, usuarios_especificos=None):
    print(f"\n📄 Processando página {page}\n")
    streams = []
    if usuarios_especificos:
        streams = buscar_usuarios_especificos(usuarios_especificos)
    else:
        streams = get_broadcasts(limit=limit, page=page)

    if not streams:
        print(f"\n🚫 Nenhuma stream encontrada na página {page}.")
        return False

    jobs = []
    results = multiprocessing.Manager().list()

    def worker(username, m3u8_url, poster_url, results):
        result = gravar_stream(username, m3u8_url, poster_url)
        results.append(result)

    print(f"🚀 Gravando {len(streams)} streams em paralelo...")
    for stream in streams:
        username = stream["username"]
        m3u8_url = stream["src"]
        poster_url = stream.get("poster")
        p = multiprocessing.Process(target=worker, args=(username, m3u8_url, poster_url, results))
        jobs.append(p)
        p.start()

    for job in jobs:
        job.join()

    print(f"\n🏁 Todas as gravações da página {page} concluídas.")

    return True if streams else False

def main():
    usuarios_especificos = perguntar_transmissoes_especificas()
    page = PAGE_DEFAULT
    limit = LIMIT_DEFAULT if not usuarios_especificos else API_SEARCH_LIMIT

    print("🤖 Iniciando busca e gravação de streams...")
    while True:
        ok = process_page(page=page, limit=limit, usuarios_especificos=usuarios_especificos)
        if not ok:
            print("\nEncerrando processo por falta de streams.")
            break
        if not usuarios_especificos:
            page += 1
            if page > 10:
                page = 1
            print(f"\nAguardando 5 segundos antes de processar a próxima página...")
            time.sleep(5)
        else:
            break

    print("\n✨ Processo principal finalizado.")

if __name__ == '__main__':
    try:
        if 'google.colab' in str(get_ipython()):
            main()
        else:
            print("Execute main() manualmente se desejar rodar fora do Colab.")
    except NameError:
        print("Não está rodando em Colab/IPython. Execute main() se desejar.")
# Out:
# Deseja gravar alguma transmissão específica? (sim/não): nao
# 🤖 Iniciando busca e gravação de streams...
#
# 📄 Processando página 1
#
# 🌐 Acessando API principal: https://api.xcam.gay/?limit=33&page=1
# ✅ 30 transmissões com URL na API principal (página 1).
# 🔁 Buscando liveInfo para 3 streams sem URL na API principal...
# 🔎 Página 1: 32 streams válidas após fallback.
# 🚀 Gravando 32 streams em paralelo...
#
# 🎬 Iniciando gravação de: joli39 (URL: https://stackvaults-hls.xcdnpro.com/a85b417e-741b-4241-9d06-1a630d2c6ccb/hls/as+8b088cc4-f563-41c6-b32b-2fad22592972/index.m3u8) em /content/temp_recordings/joli39_20250601_051219_temp.mp4
#
# 🎬 Iniciando gravação de: thiagostd2 (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/thiagostd2-321-56d8a345-2004-435c-b508-46c9827cf37a_aac/playlist.m3u8) em /content/temp_recordings/thiagostd2_20250601_051219_temp.mp4
# 🎬 Iniciando gravação de: andreas_ath (URL: https://cam4-hls.xcdnpro.com/281/cam4-origin-live/andreas_ath-281-29815b7c-107e-4ca2-9e83-06391b01df23_aac/playlist.m3u8) em /content/temp_recordings/andreas_ath_20250601_051219_temp.mp4
#
#
# 🎬 Iniciando gravação de: CERUJOIS (URL: https://stackvaults-hls.xcdnpro.com/af0ab04d-6992-48d6-9d3f-3865bae8bce4/hls/as+c9675920-6405-4304-aacd-d0b9e9e0cfd7/index.m3u8) em /content/temp_recordings/CERUJOIS_20250601_051219_temp.mp4
# 🎬 Iniciando gravação de: rodrigoeng_ (URL: https://cam4-hls.xcdnpro.com/318/cam4-origin-live/rodrigoeng_-318-db5b4431-f8fa-4e62-acd8-cc6e060b7d55_aac/playlist.m3u8) em /content/temp_recordings/rodrigoeng__20250601_051219_temp.mp4
#
#
# 🎬 Iniciando gravação de: BOR1S32 (URL: https://stackvaults-hls.xcdnpro.com/75565940-9beb-49cc-b56f-c30e40105d3d/hls/as+a6b37c0e-6552-4d31-b7ad-9f383b56ef2e/index.m3u8) em /content/temp_recordings/BOR1S32_20250601_051219_temp.mp4
# 🎬 Iniciando gravação de: Michaell_twinks (URL: https://cam4-hls.xcdnpro.com/317/cam4-origin-live/Michaell_twinks-317-239ebfdf-b396-4f96-9d4e-79aa27ab41a7_aac/playlist.m3u8) em /content/temp_recordings/Michaell_twinks_20250601_051219_temp.mp4
#
#
# 🎬 Iniciando gravação de: c0977 (URL: https://stackvaults-hls.xcdnpro.com/4383e558-8b28-41de-8133-05196225dc48/hls/as+9bb39fcd-c1b7-4aee-b0ff-98ab34471622/index.m3u8) em /content/temp_recordings/c0977_20250601_051219_temp.mp4
#
# 🎬 Iniciando gravação de: Latinosfit (URL: https://stackvaults-hls.xcdnpro.com/bbe643a5-4ea0-4585-9ef2-7e8e21695850/hls/as+6b08a49e-2fdf-4172-af1e-294ed5338d5e/index.m3u8) em /content/temp_recordings/Latinosfit_20250601_051219_temp.mp4
#
# 🎬 Iniciando gravação de: Enverga23 (URL: https://cam4-hls.xcdnpro.com/319/cam4-origin-live/Enverga23-319-34f6e06f-759c-4edc-91d6-0b2a0b950ce3_aac/playlist.m3u8) em /content/temp_recordings/Enverga23_20250601_051219_temp.mp4
# 🎬 Iniciando gravação de: Elmaslindo777 (URL: https://stackvaults-hls.xcdnpro.com/2b8bff2f-52f1-46f3-a7e4-55018a6b4787/hls/as+897381e6-9212-4c8e-a353-2c49b6c5f482/index.m3u8) em /content/temp_recordings/Elmaslindo777_20250601_051219_temp.mp4
#
# 🎬 Iniciando gravação de: momonga3rd (URL: https://stackvaults-hls.xcdnpro.com/9551d030-59e8-4b91-b0af-1592c2bda4da/hls/as+e91fa646-a985-4144-8c58-b1ae02dece01/index.m3u8) em /content/temp_recordings/momonga3rd_20250601_051219_temp.mp4
#
# 🖼️ Poster baixado em: /content/temp_recordings/joli39_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/rodrigoeng__poster_temp.jpg
# 🎬 Iniciando gravação de: Giingz22 (URL: https://stackvaults-hls.xcdnpro.com/76223a79-c4e8-4c48-a3ce-89f9fe091ee9/hls/as+3669d288-8b34-4b01-bac8-cc08e60db703/index.m3u8) em /content/temp_recordings/Giingz22_20250601_051219_temp.mp4
# 🖼️ Poster baixado em: /content/temp_recordings/CERUJOIS_poster_temp.jpg
# 🎬 Iniciando gravação de: dinosourd (URL: https://stackvaults-hls.xcdnpro.com/dd5518bc-1481-4310-bb08-faf7a12a8bca/hls/as+394c83b6-60ea-4862-b52f-846eac108dae/index.m3u8) em /content/temp_recordings/dinosourd_20250601_051219_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/andreas_ath_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/thiagostd2_poster_temp.jpg
# 🎬 Iniciando gravação de: warrenkener (URL: https://stackvaults-hls.xcdnpro.com/d2e5dba6-d2b4-434a-8098-86664b222905/hls/as+ca7ffb30-f223-41b9-92c0-abab4c669ce8/index.m3u8) em /content/temp_recordings/warrenkener_20250601_051219_temp.mp4
#
#
#
# 🖼️ Poster baixado em: /content/temp_recordings/BOR1S32_poster_temp.jpg
#
# 🖼️ Poster baixado em: /content/temp_recordings/c0977_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/Michaell_twinks_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/Latinosfit_poster_temp.jpg
#
# 🖼️ Poster baixado em: /content/temp_recordings/Enverga23_poster_temp.jpg
#
# 🎬 Iniciando gravação de: vergapink4 (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/vergapink4-321-45ad39a8-ef5c-4fd5-9f6a-119ed779a974_aac/playlist.m3u8) em /content/temp_recordings/vergapink4_20250601_051220_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/momonga3rd_poster_temp.jpg
#
# 🎬 Iniciando gravação de: xx19hornyxx (URL: https://stackvaults-hls.xcdnpro.com/f0127eba-167d-4522-a122-47775a04593d/hls/as+7b83839a-5427-4a73-8ae7-0cc97eb08b4f/index.m3u8) em /content/temp_recordings/xx19hornyxx_20250601_051220_temp.mp4
# 🎬 Iniciando gravação de: jackesparta (URL: https://stackvaults-hls.xcdnpro.com/1d31676d-2093-4310-a1cc-bd3fe3578f77/hls/as+54bb3fc1-6541-4e05-80b5-b2bb6c947936/index.m3u8) em /content/temp_recordings/jackesparta_20250601_051220_temp.mp4
#
# 🖼️ Poster baixado em: /content/temp_recordings/Elmaslindo777_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/Giingz22_poster_temp.jpg
#
#
#
# 🎬 Iniciando gravação de: classied3 (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/classied3-321-3c83ad02-4a55-4de8-970e-b29266e84144_aac/playlist.m3u8) em /content/temp_recordings/classied3_20250601_051220_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/warrenkener_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/dinosourd_poster_temp.jpg
# 🎬 Iniciando gravação de: Carioca_Novinho (URL: https://stackvaults-hls.xcdnpro.com/580118fd-59cd-47ea-858a-3954ef0710ba/hls/as+a5b9ccc7-d15d-45a5-ab30-b56f4b9f01d5/index.m3u8) em /content/temp_recordings/Carioca_Novinho_20250601_051220_temp.mp4
#
#
# 🖼️ Poster baixado em: /content/temp_recordings/jackesparta_poster_temp.jpg
# 🎬 Iniciando gravação de: taway4 (URL: https://stackvaults-hls.xcdnpro.com/4ba0a0d1-ff89-4434-a952-bf1644cd8048/hls/as+7011d58f-be39-4074-832a-bf02e0e19b91/index.m3u8) em /content/temp_recordings/taway4_20250601_051220_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/xx19hornyxx_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/vergapink4_poster_temp.jpg
#
#
# 🎬 Iniciando gravação de: encoxador19 (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/encoxador19-321-8e0b83af-cb07-4d6f-a8d4-9ef2bb709986_aac/playlist.m3u8) em /content/temp_recordings/encoxador19_20250601_051220_temp.mp4
#
#
#
# 🎬 Iniciando gravação de: Jacob1_ (URL: https://cam4-hls.xcdnpro.com/320/cam4-origin-live/Jacob1_-320-0882a68d-6f8f-4464-ac82-ed46e1487821_aac/playlist.m3u8) em /content/temp_recordings/Jacob1__20250601_051220_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/classied3_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/Carioca_Novinho_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/taway4_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/encoxador19_poster_temp.jpg
#
#
# 🎬 Iniciando gravação de: Kebec52 (URL: https://stackvaults-hls.xcdnpro.com/032c52b1-b960-4e35-9c4b-84310204b1f2/hls/as+d745b6b4-5cf7-483f-a39f-9392b50d41a8/index.m3u8) em /content/temp_recordings/Kebec52_20250601_051220_temp.mp4
#
#
# 🎬 Iniciando gravação de: lQAQl (URL: https://cam4-hls.xcdnpro.com/281/cam4-origin-live/lQAQl-281-86b46b30-06b3-4a4f-ac3c-8e533224388d_aac/playlist.m3u8) em /content/temp_recordings/lQAQl_20250601_051220_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/Jacob1__poster_temp.jpg
#
# 🎬 Iniciando gravação de: hairyhornyguy (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/hairyhornyguy-321-a12c1b6b-bf6b-4fcc-962c-62ccc403175e_aac/playlist.m3u8) em /content/temp_recordings/hairyhornyguy_20250601_051220_temp.mp4
#
#
# 🎬 Iniciando gravação de: cutenewmemory22 (URL: https://stackvaults-hls.xcdnpro.com/6a8661bb-b5c5-4b97-8b74-430a30750b3d/hls/as+821e9a73-b627-470c-8d43-5e84fd43d9d4/index.m3u8) em /content/temp_recordings/cutenewmemory22_20250601_051220_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/Kebec52_poster_temp.jpg
#
# 🖼️ Poster baixado em: /content/temp_recordings/lQAQl_poster_temp.jpg
# 🎬 Iniciando gravação de: Goflame (URL: https://stackvaults-hls.xcdnpro.com/98c1c213-9b09-4a2d-92d7-e3fe280c07e2/hls/as+acd7bee0-0cac-4526-bc2f-e323be9c9e51/index.m3u8) em /content/temp_recordings/Goflame_20250601_051220_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/hairyhornyguy_poster_temp.jpg
# 🎬 Iniciando gravação de: Cesar_Moon (URL: https://stackvaults-hls.xcdnpro.com/bcc86f92-638d-4242-b097-b2c0fd516fc8/hls/as+8262c0ed-8c41-497c-85d8-eaa3196d48d5/index.m3u8) em /content/temp_recordings/Cesar_Moon_20250601_051221_temp.mp4
#
# 🖼️ Poster baixado em: /content/temp_recordings/cutenewmemory22_poster_temp.jpg
#
#
#
# 🎬 Iniciando gravação de: Delut_yan (URL: https://cam4-hls.xcdnpro.com/317/cam4-origin-live/Delut_yan-317-87453820-36c8-4f62-9197-7c16c7e1b399_aac/playlist.m3u8) em /content/temp_recordings/Delut_yan_20250601_051221_temp.mp4
#
# 🎬 Iniciando gravação de: mickredge (URL: https://stackvaults-hls.xcdnpro.com/8278b775-4dfe-4f70-a3b8-309cc6e966f6/hls/as+9153a447-ead0-4cf9-80ff-c5718fd2ba9b/index.m3u8) em /content/temp_recordings/mickredge_20250601_051221_temp.mp4
# 🖼️ Poster baixado em: /content/temp_recordings/Goflame_poster_temp.jpg
# 🎬 Iniciando gravação de: Joydan_rize (URL: https://cs1809.cam4.com:443/cam4-edge-live/Joydan_rize-322-34192ae3-18eb-402d-bfbe-a6cf74f2ae7c_aac/playlist.m3u8) em /content/temp_recordings/Joydan_rize_20250601_051221_temp.mp4
# 🖼️ Poster baixado em: /content/temp_recordings/Cesar_Moon_poster_temp.jpg
#
# 🖼️ Poster baixado em: /content/temp_recordings/Delut_yan_poster_temp.jpg
# ⏱️ [Joydan_rize] Gravados: 0 min | Restantes: 33 min | Tempo total: 0m5s — 📊 0.3% concluído
# ❌ FFmpeg falhou para Joydan_rize. Código de saída: 1
# ⏱️ [momonga3rd] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Latinosfit] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [joli39] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [andreas_ath] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Enverga23] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Giingz22] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [CERUJOIS] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [jackesparta] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
#
#
# ⏱️ [warrenkener] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [Elmaslindo777] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Kebec52] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Carioca_Novinho] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
#
# ⏱️ [thiagostd2] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [BOR1S32] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Michaell_twinks] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [dinosourd] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [rodrigoeng_] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [vergapink4] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [c0977] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [classied3] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [taway4] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [xx19hornyxx] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [mickredge] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [lQAQl] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [encoxador19] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Jacob1_] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [cutenewmemory22] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Delut_yan] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [hairyhornyguy] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Cesar_Moon] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Goflame] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Carioca_Novinho] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [mickredge] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [xx19hornyxx] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [Elmaslindo777] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [thiagostd2] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [rodrigoeng_] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [CERUJOIS] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Enverga23] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [andreas_ath] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [Giingz22] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [dinosourd] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [c0977] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [momonga3rd] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [encoxador19] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [joli39] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [jackesparta] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [BOR1S32] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [taway4] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [Michaell_twinks] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [vergapink4] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [Cesar_Moon] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Kebec52] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Latinosfit] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [lQAQl] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [hairyhornyguy] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [warrenkener] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m4s — 📊 3.2% concluído
# ⏱️ [cutenewmemory22] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [classied3] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [Delut_yan] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m3s — 📊 3.2% concluído
# ⏱️ [Goflame] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Jacob1_] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [warrenkener] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Carioca_Novinho] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Elmaslindo777] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [xx19hornyxx] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Giingz22] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [thiagostd2] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [andreas_ath] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [mickredge] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [joli39] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [momonga3rd] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Michaell_twinks] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [jackesparta] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [dinosourd] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [vergapink4] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [taway4] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Kebec52] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [encoxador19] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Enverga23] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [Cesar_Moon] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [BOR1S32] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [rodrigoeng_] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [CERUJOIS] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [lQAQl] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [hairyhornyguy] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [Delut_yan] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [cutenewmemory22] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Goflame] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [c0977] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m4s — 📊 6.3% concluído
# ⏱️ [Jacob1_] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [classied3] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m3s — 📊 6.2% concluído
# ⏱️ [Latinosfit] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Carioca_Novinho] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m40s — 📊 8.1% concluído
# ✅ Gravação FFmpeg finalizada para: Carioca_Novinho_20250601_051220_temp.mp4. Duração aproximada: 160s
# ⏩ Duração gravada (160s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [warrenkener] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Elmaslindo777] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [CERUJOIS] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [thiagostd2] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [andreas_ath] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [joli39] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [rodrigoeng_] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Goflame] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [Giingz22] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [momonga3rd] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [xx19hornyxx] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [taway4] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Kebec52] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [vergapink4] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [Enverga23] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [lQAQl] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [hairyhornyguy] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [encoxador19] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [Michaell_twinks] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m3s — 📊 9.2% concluído
# ⏱️ [BOR1S32] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [c0977] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [cutenewmemory22] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Jacob1_] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [classied3] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [Cesar_Moon] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [Delut_yan] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [dinosourd] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m7s — 📊 9.4% concluído
# ✅ Gravação FFmpeg finalizada para: dinosourd_20250601_051219_temp.mp4. Duração aproximada: 187s
# ⏩ Duração gravada (187s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [jackesparta] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [Latinosfit] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [mickredge] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m4s — 📊 9.3% concluído
# ⏱️ [xx19hornyxx] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [thiagostd2] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [CERUJOIS] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [andreas_ath] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Giingz22] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [warrenkener] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [momonga3rd] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Enverga23] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [taway4] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [joli39] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [vergapink4] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Kebec52] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [rodrigoeng_] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [Elmaslindo777] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [Cesar_Moon] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [Michaell_twinks] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [BOR1S32] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [hairyhornyguy] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [encoxador19] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [Goflame] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [classied3] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [cutenewmemory22] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Delut_yan] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m3s — 📊 12.3% concluído
# ⏱️ [c0977] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [lQAQl] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m3s — 📊 12.3% concluído
# ⏱️ [Jacob1_] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [jackesparta] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [mickredge] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [Latinosfit] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m4s — 📊 12.3% concluído
# ⏱️ [xx19hornyxx] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m36s — 📊 13.9% concluído
# ✅ Gravação FFmpeg finalizada para: xx19hornyxx_20250601_051220_temp.mp4. Duração aproximada: 276s
# ⏩ Duração gravada (276s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [vergapink4] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m53s — 📊 14.8% concluído
# ✅ Gravação FFmpeg finalizada para: vergapink4_20250601_051220_temp.mp4. Duração aproximada: 293s
# ⏩ Duração gravada (293s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [c0977] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Cesar_Moon] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [andreas_ath] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído⏱️ [rodrigoeng_] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
#
# ⏱️ [momonga3rd] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Enverga23] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [Giingz22] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [joli39] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [BOR1S32] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [warrenkener] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [thiagostd2] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [CERUJOIS] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Elmaslindo777] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [Michaell_twinks] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [lQAQl] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [encoxador19] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [Kebec52] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [taway4] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [Jacob1_] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [Goflame] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [Delut_yan] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [classied3] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [hairyhornyguy] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m3s — 📊 15.3% concluído
# ⏱️ [Latinosfit] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [cutenewmemory22] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [mickredge] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m6s — 📊 15.5% concluído
# ⏱️ [jackesparta] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [BOR1S32] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [mickredge] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [thiagostd2] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [andreas_ath] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Giingz22] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Enverga23] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Goflame] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [momonga3rd] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [CERUJOIS] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [taway4] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [rodrigoeng_] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [lQAQl] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [joli39] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Kebec52] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Michaell_twinks] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Elmaslindo777] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [hairyhornyguy] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Cesar_Moon] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [Delut_yan] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [classied3] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Jacob1_] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [jackesparta] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [encoxador19] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m4s — 📊 18.4% concluído
# ⏱️ [cutenewmemory22] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [warrenkener] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m6s — 📊 18.5% concluído
# ⏱️ [c0977] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m8s — 📊 18.6% concluído
# ⏱️ [Latinosfit] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m6s — 📊 18.5% concluído
# ⏱️ [rodrigoeng_] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m59s — 📊 21.2% concluído
# ✅ Gravação FFmpeg finalizada para: rodrigoeng__20250601_051219_temp.mp4. Duração aproximada: 419s
# ⏩ Duração gravada (419s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [warrenkener] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [andreas_ath] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [Enverga23] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído⏱️ [momonga3rd] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
#
# ⏱️ [CERUJOIS] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [Giingz22] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [Cesar_Moon] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [thiagostd2] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [joli39] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [encoxador19] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [Delut_yan] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [taway4] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [Michaell_twinks] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [mickredge] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [hairyhornyguy] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído⏱️ [lQAQl] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
#
# ⏱️ [Goflame] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [Kebec52] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [Elmaslindo777] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [classied3] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [jackesparta] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m4s — 📊 21.4% concluído
# ⏱️ [Jacob1_] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [cutenewmemory22] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [c0977] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [BOR1S32] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m17s — 📊 22.1% concluído
# ✅ Gravação FFmpeg finalizada para: BOR1S32_20250601_051219_temp.mp4. Duração aproximada: 437s
# ✅ Arquivo renomeado para: BOR1S32_01-06-2025_05-12_7m17s.mp4
# ⬆️ Upload de: BOR1S32_01-06-2025_05-12_7m17s.mp4 para Abyss.to...
# 📤 Upload bem-sucedido. URL: https://short.icu/V3USr3_Qk | SLUG: V3USr3_Qk
# 🖼️ Poster movido para /content/XCam/xcam-db/user/BOR1S32/V3USr3_Qk.jpg
# ✅ rec.json para BOR1S32 atualizado em /content/XCam/dist/db/user/BOR1S32/rec.json
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/BOR1S32_01-06-2025_05-12_7m17s.mp4
# ⏱️ [Latinosfit] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [warrenkener] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Enverga23] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [andreas_ath] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [thiagostd2] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [momonga3rd] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Giingz22] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Cesar_Moon] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [joli39] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [mickredge] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m3s — 📊 24.4% concluído
# ⏱️ [Elmaslindo777] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m3s — 📊 24.4% concluído
# ⏱️ [CERUJOIS] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [encoxador19] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [Michaell_twinks] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Kebec52] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [c0977] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m3s — 📊 24.4% concluído
# ⏱️ [lQAQl] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Delut_yan] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [hairyhornyguy] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [cutenewmemory22] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [Jacob1_] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [classied3] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [taway4] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m2s — 📊 24.3% concluído
# ⏱️ [Goflame] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m2s — 📊 24.3% concluído
# ⏱️ [jackesparta] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Latinosfit] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m9s — 📊 24.7% concluído
# ⏱️ [CERUJOIS] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [mickredge] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [c0977] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [andreas_ath] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [thiagostd2] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [Giingz22] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Enverga23] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [warrenkener] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [Cesar_Moon] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Elmaslindo777] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Michaell_twinks] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [joli39] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [encoxador19] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [Kebec52] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Delut_yan] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [taway4] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m2s — 📊 27.4% concluído
# ⏱️ [momonga3rd] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [lQAQl] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Goflame] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [hairyhornyguy] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [cutenewmemory22] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [Jacob1_] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [classied3] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Latinosfit] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [jackesparta] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [Elmaslindo777] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m40s — 📊 29.3% concluído
# ✅ Gravação FFmpeg finalizada para: Elmaslindo777_20250601_051219_temp.mp4. Duração aproximada: 580s
# ✅ Arquivo renomeado para: Elmaslindo777_01-06-2025_05-12_9m40s.mp4
# ⬆️ Upload de: Elmaslindo777_01-06-2025_05-12_9m40s.mp4 para Abyss.to...
