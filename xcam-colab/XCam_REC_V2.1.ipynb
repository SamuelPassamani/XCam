# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelPassamani/XCam/blob/notebook-auto/xcam-colab/XCam_REC_V2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Célula 1: Configurações Auxiliares e Parâmetros Gerais
#
# **Objetivo:**
# Esta célula inicializa variáveis globais para ajuste rápido do comportamento do notebook, como:
#
# Quantidade de transmissões por página
#
# *   Quantidade de transmissões por página (LIMIT_DEFAULT)
# *   Página inicial a ser buscada (PAGE_DEFAULT)
# *   Tempo máximo de gravação de cada vídeo (RECORD_SECONDS)
# *   Tempo mínimo exigido para considerar o vídeo válido (RECORD_SECONDS_MIN)
# *   Limite de busca ao procurar usuários específicos (API_SEARCH_LIMIT)
#
# **Interatividade:**
# Inclui a função perguntar_transmissoes_especificas() que pergunta ao usuário se deseja gravar transmissões de usuários específicos. Caso sim, solicita os nomes e retorna uma lista.
#
# **Como funciona:**
# Antes do processamento, você pode ajustar facilmente qualquer parâmetro. O notebook perguntará se você quer gravar transmissões de usuários específicos e, se quiser, pedirá os nomes (ex: "userNovo234, jovemPT").

# %%
# Célula 1: Configurações Auxiliares e Parâmetros Gerais
# ------------------------------------------------------
# Ajuste facilmente os principais parâmetros do sistema e escolha se deseja gravar transmissões específicas.

import os

# Parâmetros globais editáveis
LIMIT_DEFAULT = 33           # Quantidade padrão de transmissões por página
PAGE_DEFAULT = 1             # Página inicial
RECORD_SECONDS = 1980         # Tempo máximo de gravação por vídeo (segundos)
RECORD_SECONDS_MIN = 420      # Tempo mínimo de gravação exigido para upload (segundos)
API_SEARCH_LIMIT = 1000      # Limite máximo para busca de usuários específicos

globals().update({
    'LIMIT_DEFAULT': LIMIT_DEFAULT,
    'PAGE_DEFAULT': PAGE_DEFAULT,
    'RECORD_SECONDS': RECORD_SECONDS,
    'RECORD_SECONDS_MIN': RECORD_SECONDS_MIN,
    'API_SEARCH_LIMIT': API_SEARCH_LIMIT
})

def perguntar_transmissoes_especificas():
    resp = input('Deseja gravar alguma transmissão específica? (sim/não): ').strip().lower()
    if resp.startswith('s'):
        usuarios = input('Informe o(s) nome(s) de usuário, separados por vírgula (ex: userNovo234, jovemPT): ')
        usuarios_lista = [u.strip() for u in usuarios.split(',') if u.strip()]
        return usuarios_lista
    return []

# %% [markdown]
# # Célula 2: Instalação do ffmpeg
#
# **Objetivo:**
# Garante que o ffmpeg esteja instalado no ambiente do Google Colab. O ffmpeg é fundamental para gravar os vídeos das transmissões.
#
# **Como funciona:**
# Executa comandos de instalação do ffmpeg, necessários para o funcionamento correto das próximas etapas.

# %%
# Célula 2: Instalação do ffmpeg
# ------------------------------
# Garante que o ffmpeg está instalado no ambiente Colab.

# !apt-get update -y
# !apt-get install -y ffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,721 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,994 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,736 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,246 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,953 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,264 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,553 kB]
# Fetched 22.9 MB in 9s (2,505 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %% [markdown]
# # Célula 3: Imports Essenciais e Funções Utilitárias
#
# **Objetivo:**
# Importa todas as bibliotecas do Python necessárias (como requests, multiprocessing, datetime, etc.) e define funções utilitárias para:
#
# *   Formatar o tempo de gravação (format_seconds)
# *   Exibir logs de progresso (log_progress)
# *   Baixar e salvar a imagem de poster de cada transmissão (download_and_save_poster)
#
# **Como funciona:**
# Essas funções são usadas em várias partes do notebook para manipular tempos, apresentar informações mais amigáveis e garantir que os posters das transmissões sejam baixados corretamente.

# %%
# Célula 3: Imports essenciais e utilitários
# ------------------------------------------
# Importação de bibliotecas e funções auxiliares de formatação e download.

import os
import requests
import multiprocessing
from datetime import datetime
import json
import time
import subprocess
import math
import re

from IPython import get_ipython
from IPython.display import display

def format_seconds(seconds):
    total_seconds = int(seconds)
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    parts = []
    if hours > 0: parts.append(f"{hours}h")
    if minutes > 0 or (hours == 0 and seconds > 0): parts.append(f"{minutes}m")
    if seconds > 0 or total_seconds == 0: parts.append(f"{seconds}s")
    return "".join(parts) if parts else "0s"

def log_progress(username, elapsed_seconds, total_seconds):
    percent = min((elapsed_seconds / total_seconds) * 100, 100)
    tempo = format_seconds(elapsed_seconds)
    minutos_gravados = math.floor(elapsed_seconds / 60)
    minutos_restantes = max(0, math.ceil((total_seconds - elapsed_seconds) / 60))
    print(f"⏱️ [{username}] Gravados: {minutos_gravados} min | Restantes: {minutos_restantes} min | Tempo total: {tempo} — 📊 {percent:.1f}% concluído")

def download_and_save_poster(poster_url, username, temp_folder):
    try:
        response = requests.get(poster_url, timeout=15)
        response.raise_for_status()
        ext = os.path.splitext(poster_url)[1].lower()
        if ext not in [".jpg", ".jpeg", ".png"]:
            ext = ".jpg"
        poster_temp_path = os.path.join(temp_folder, f"{username}_poster_temp{ext}")
        with open(poster_temp_path, "wb") as f:
            f.write(response.content)
        print(f"🖼️ Poster baixado em: {poster_temp_path}")
        return poster_temp_path
    except Exception as e:
        print(f"❌ Erro ao baixar poster {poster_url}: {e}")
        return None

# %% [markdown]
# # Célula 4: Clonagem do Repositório GitHub para o Colab
#
# **Objetivo:**
# Clona o repositório do GitHub para o ambiente local do Colab, garantindo que o ambiente sempre esteja atualizado e pronto para armazenar os arquivos gerados.
#
# **Como funciona:**
# Remove qualquer repositório anterior para evitar conflitos, clona o novo, prepara pastas temporárias e define a URL de upload para o Abyss.to.

# %%
# Célula 4: Clonagem do repositório GitHub para o Colab
# -----------------------------------------------------
# Clona o repositório para o ambiente Colab, garantindo ambiente limpo e atualizado.

GITHUB_USER = "SamuelPassamani"
GITHUB_REPO = "XCam"
GITHUB_BRANCH = "notebook-auto"
GITHUB_TOKEN = "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"

repo_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"

# !rm -rf {GITHUB_REPO}
# !git clone -b {GITHUB_BRANCH} {repo_url}

TEMP_OUTPUT_FOLDER = "/content/temp_recordings"
os.makedirs(TEMP_OUTPUT_FOLDER, exist_ok=True)
BASE_REPO_FOLDER = f"/content/{GITHUB_REPO}"

ABYSS_UPLOAD_URL = 'http://up.hydrax.net/0128263f78f0b426d617bb61c2a8ff43'
# Out:
# Cloning into 'XCam'...
# remote: Enumerating objects: 6696, done.
# remote: Counting objects: 100% (599/599), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 6696 (delta 523), reused 463 (delta 407), pack-reused 6097 (from 3)
# Receiving objects: 100% (6696/6696), 24.43 MiB | 18.04 MiB/s, done.
# Resolving deltas: 100% (4161/4161), done.

# %% [markdown]
# # Célula 5: Commit e Push Automáticos (rec.json e poster)
#
# **Objetivo:**
# Define a função git_commit_and_push() para garantir que apenas arquivos importantes (JSON de gravação e posters de imagem) sejam adicionados, commitados e enviados ao repositório.
#
# **Como funciona:**
# Configura o git, adiciona o arquivo desejado, faz commit e push para o repositório remoto.

# %%
# Célula 5: Commit e Push automáticos (rec.json e poster)
# -------------------------------------------------------
def git_commit_and_push(file_path, commit_message="Atualiza rec.json"):
    repo_dir = f"/content/{GITHUB_REPO}"
    os.chdir(repo_dir)
    subprocess.run(["git", "config", "user.email", "colab@xcam.com"])
    subprocess.run(["git", "config", "user.name", "Colab XCam Bot"])
    subprocess.run(["git", "add", file_path])
    subprocess.run(["git", "commit", "-m", commit_message, "--allow-empty"], check=False)
    subprocess.run([
        "git", "push", f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"
    ])

# %% [markdown]
# # Célula 6: Busca de Transmissões na API XCam, com Fallback via liveInfo
#
# **Objetivo:**
# Busca as transmissões ativas na API principal da XCam. Se alguma transmissão não retornar o link da stream (src), faz um fallback via a API /liveInfo do usuário para tentar obter o link direto e o poster.
#
# **Como funciona:**
#
# *   Para cada transmissão encontrada, retorna um dicionário com username, src (endereço do stream) e poster (imagem).
# *   Se for solicitado buscar usuários específicos, só retorna esses.
# *   Caso algum usuário não tenha src, faz nova chamada à API liveInfo para tentar encontrar o link e o poster.

# %%
# Célula 6: Busca de transmissões na API XCam, com fallback via liveInfo
# ----------------------------------------------------------------------
def get_broadcasts(limit=LIMIT_DEFAULT, page=PAGE_DEFAULT, usuarios_especificos=None):
    """
    Busca transmissões ao vivo via API principal da XCam.
    Se usuarios_especificos for fornecido (lista), retorna apenas essas transmissões.
    Faz fallback via liveInfo para transmissões sem src.
    """
    api_url_main = f"https://api.xcam.gay/?limit={limit}&page={page}"
    print(f"🌐 Acessando API principal: {api_url_main}")

    streams_from_main = []
    streams_without_preview = []

    try:
        response_main = requests.get(api_url_main)
        response_main.raise_for_status()
        data_main = response_main.json()
        broadcasts_data = data_main.get("broadcasts")
        if not broadcasts_data:
            print("⚠️ Chave 'broadcasts' não encontrada na resposta da API principal.")
            return []
        items = broadcasts_data.get("items")
        if not isinstance(items, list):
            print(f"⚠️ Chave 'items' não encontrada ou não é uma lista em 'broadcasts'.")
            return []

        for item in items:
            preview = item.get("preview") or {}
            src = preview.get("src")
            poster = preview.get("poster")
            username = item.get("username", "desconhecido")
            if src:
                if (not usuarios_especificos) or (username in usuarios_especificos):
                    streams_from_main.append({
                        "username": username,
                        "src": src,
                        "poster": poster
                    })
            else:
                if (not usuarios_especificos) or (username in usuarios_especificos):
                    streams_without_preview.append({"username": username})

        print(f"✅ {len(streams_from_main)} transmissões com URL na API principal (página {page}).")

    except Exception as e:
        print(f"❌ Erro ao acessar API principal: {e}")
        return []

    # Fallback: busca via liveInfo para streams sem URL na API principal
    streams_from_liveinfo = []
    if streams_without_preview:
        print(f"🔁 Buscando liveInfo para {len(streams_without_preview)} streams sem URL na API principal...")
        for stream_info in streams_without_preview:
            username = stream_info["username"]
            api_url_liveinfo = f"https://api.xcam.gay/user/{username}/liveInfo"
            try:
                response_liveinfo = requests.get(api_url_liveinfo)
                response_liveinfo.raise_for_status()
                data_liveinfo = response_liveinfo.json()
                m3u8_url = data_liveinfo.get("cdnURL") or data_liveinfo.get("edgeURL")
                poster = data_liveinfo.get("poster")
                if m3u8_url:
                    streams_from_liveinfo.append({
                        "username": username,
                        "src": m3u8_url,
                        "poster": poster
                    })
            except Exception:
                pass
            time.sleep(0.5)

    final_streams_list = streams_from_main + streams_from_liveinfo
    print(f"🔎 Página {page}: {len(final_streams_list)} streams válidas após fallback.")
    return final_streams_list

def buscar_usuarios_especificos(usuarios_lista):
    """
    Busca usuários específicos via API, utilizando um limit alto.
    Fallback via liveInfo para usuários sem src.
    """
    api_url = f"https://api.xcam.gay/?limit={API_SEARCH_LIMIT}&page=1"
    print(f"🔍 Buscando usuários específicos em {api_url}")
    try:
        response = requests.get(api_url)
        response.raise_for_status()
        data = response.json()
        items = data.get("broadcasts", {}).get("items", [])
        encontrados = []
        sem_src = []
        for item in items:
            username = item.get("username", "")
            if username in usuarios_lista:
                preview = item.get("preview") or {}
                src = preview.get("src")
                poster = preview.get("poster")
                if src:
                    encontrados.append({
                        "username": username,
                        "src": src,
                        "poster": poster
                    })
                else:
                    sem_src.append(username)
        # Fallback via liveInfo
        for username in sem_src:
            api_url_liveinfo = f"https://api.xcam.gay/user/{username}/liveInfo"
            try:
                response_liveinfo = requests.get(api_url_liveinfo)
                response_liveinfo.raise_for_status()
                data_liveinfo = response_liveinfo.json()
                m3u8_url = data_liveinfo.get("cdnURL") or data_liveinfo.get("edgeURL")
                poster = data_liveinfo.get("poster")
                if m3u8_url:
                    encontrados.append({
                        "username": username,
                        "src": m3u8_url,
                        "poster": poster
                    })
            except Exception:
                pass
            time.sleep(0.5)
        print(f"Encontrados {len(encontrados)} dos {len(usuarios_lista)} usuários procurados (incluindo fallback).")
        return encontrados
    except Exception as e:
        print(f"❌ Erro ao buscar usuários específicos: {e}")
        return []

# %% [markdown]
# # Célula 7: Gravação da Stream, Download do Poster e Controle de Tempo Mínimo
#
# **Objetivo:**
# Grava a transmissão ao vivo do usuário usando ffmpeg. Durante a gravação, baixa o poster da transmissão e, ao final, verifica se o tempo de gravação atingiu o mínimo desejado para ser considerado válido.
#
# **Como funciona:**
#
# *  Se o vídeo gravado for muito curto, descarta imediatamente o vídeo e o poster.
# *  Se for suficiente, renomeia o vídeo, faz upload, renomeia o poster e chama a função de atualização de JSON.

# %%
# Célula 7: Gravação de stream, download do poster e controle de tempo mínimo
# ---------------------------------------------------------------------------
def gravar_stream(username, m3u8_url, poster_url=None):
    start_time_dt = datetime.now()
    data_str = start_time_dt.strftime("%d-%m-%Y")
    horario_str = start_time_dt.strftime("%H-%M")
    temp_filename = f"{username}_{start_time_dt.strftime('%Y%m%d_%H%M%S')}_temp.mp4"
    filepath = os.path.join(TEMP_OUTPUT_FOLDER, temp_filename)

    print(f"\n🎬 Iniciando gravação de: {username} (URL: {m3u8_url}) em {filepath}")

    poster_temp_path = None
    if poster_url:
        poster_temp_path = download_and_save_poster(poster_url, username, TEMP_OUTPUT_FOLDER)

    ffmpeg_cmd = ["ffmpeg", "-i", m3u8_url, "-t", str(RECORD_SECONDS), "-c", "copy", "-y", filepath]

    start_time_process = time.time()
    process = None

    try:
        process = subprocess.Popen(ffmpeg_cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, universal_newlines=True)
        elapsed_seconds = 0
        last_log_minute = -1
        while True:
            line = process.stdout.readline()
            if not line and process.poll() is not None:
                break
            if "time=" in line:
                try:
                    match = re.search(r"time=(\d+):(\d+):(\d+)", line)
                    if match:
                        h, m, s = map(int, match.groups())
                        elapsed_seconds = h * 3600 + m * 60 + s
                        if elapsed_seconds // 60 != last_log_minute:
                            log_progress(username, elapsed_seconds, RECORD_SECONDS)
                            last_log_minute = elapsed_seconds // 60
                except Exception:
                    pass

        process.wait()
        end_time_process = time.time()
        elapsed_seconds = round(end_time_process - start_time_process)
        log_progress(username, elapsed_seconds, RECORD_SECONDS)

        if process.returncode != 0:
            print(f"❌ FFmpeg falhou para {username}. Código de saída: {process.returncode}")
            return {'username': username, 'filename': temp_filename, 'filepath': filepath, 'upload_success': False, 'abyss_response': "Gravação FFmpeg falhou"}
        else:
            print(f"✅ Gravação FFmpeg finalizada para: {temp_filename}. Duração aproximada: {elapsed_seconds}s")

            if elapsed_seconds < RECORD_SECONDS_MIN:
                print(f"⏩ Duração gravada ({elapsed_seconds}s) menor que o mínimo ({RECORD_SECONDS_MIN}s). Arquivo descartado.")
                if os.path.exists(filepath): os.remove(filepath)
                if poster_temp_path and os.path.exists(poster_temp_path): os.remove(poster_temp_path)
                return {'username': username, 'filename': temp_filename, 'filepath': filepath, 'upload_success': False, 'abyss_response': "Gravação muito curta (descartada)"}

            tempo_formatado = format_seconds(elapsed_seconds)
            final_filename = f"{username}_{data_str}_{horario_str}_{tempo_formatado}.mp4"
            final_filepath = os.path.join(TEMP_OUTPUT_FOLDER, final_filename)

            try:
                os.rename(filepath, final_filepath)
                print(f"✅ Arquivo renomeado para: {final_filename}")
                filepath_for_upload = final_filepath
                filename_for_upload = final_filename
            except Exception as e:
                print(f"❌ Erro ao renomear arquivo {temp_filename} para {final_filename}: {e}")
                filepath_for_upload = filepath
                filename_for_upload = temp_filename

            success, abyss_resp, slug = upload_to_abyss_and_update_json(
                filepath_for_upload, username, elapsed_seconds,
                poster_temp_path=poster_temp_path
            )

            return {
                'username': username,
                'filename': filename_for_upload,
                'filepath': filepath_for_upload,
                'upload_success': success,
                'abyss_response': abyss_resp,
                'slug': slug
            }

    except FileNotFoundError:
        print(f"❌ Erro: Comando 'ffmpeg' não encontrado. Certifique-se de que foi instalado corretamente.")
        return {'username': username, 'filename': None, 'filepath': None, 'upload_success': False, 'abyss_response': "Comando FFmpeg não encontrado"}
    except Exception as e:
        print(f"❌ Erro inesperado durante a execução do FFmpeg para {username}: {e}")
        return {'username': username, 'filename': None, 'filepath': None, 'upload_success': False, 'abyss_response': f"Erro inesperado na execução do FFmpeg: {e}"}
    finally:
        if 'filepath_for_upload' in locals() and os.path.exists(filepath_for_upload):
            try:
                os.remove(filepath_for_upload)
                print(f"🗑️ Arquivo de vídeo removido do Colab: {filepath_for_upload}")
            except Exception as e:
                print(f"⚠️ Não foi possível remover o arquivo de vídeo temporário: {e}")

# %% [markdown]
# # Célula 8: Upload para Abyss.to, Atualização do rec.json, Commit do Poster
#
# **Objetivo:**
# Faz upload do vídeo para o Abyss.to. Se bem-sucedido, renomeia/move o poster para a pasta correta do repositório, atualiza/cria o arquivo rec.json do usuário com todos os metadados (incluindo poster e urlIframe) e faz commit/push dos arquivos.
#
# **Como funciona:**
#
# *   Preenche todos os campos do JSON conforme seu padrão.
# *   Garante que apenas vídeos válidos sejam registrados e compartilha os links corretos.

# %%
# Célula 8: Upload para Abyss.to, atualização do rec.json, commit do poster
# -------------------------------------------------------------------------
def upload_to_abyss_and_update_json(filepath, username, duration_seconds, poster_temp_path=None):
    file_name = os.path.basename(filepath)
    file_type = 'video/mp4'
    print(f"⬆️ Upload de: {file_name} para Abyss.to...")

    upload_success = False
    abyss_response = "Upload falhou - Sem resposta"
    uploaded_url = None
    video_id = None
    slug = None

    try:
        with open(filepath, 'rb') as f:
            files = { 'file': (file_name, f, file_type) }
            response = requests.post(ABYSS_UPLOAD_URL, files=files)
            resp_json = response.json()
            abyss_response = resp_json
            if resp_json.get('status'):
                upload_success = True
                uploaded_url = resp_json.get('url') or resp_json.get('urlIframe')
                video_id = resp_json.get('slug') or resp_json.get('video')
                slug = video_id
                print(f"📤 Upload bem-sucedido. URL: {uploaded_url} | SLUG: {slug}")
            else:
                print(f"❌ Falha no upload. Mensagem: {resp_json.get('message','')}")
    except Exception as e:
        abyss_response = f"Erro no upload: {e}"
        print(f"❌ Erro no upload: {e}")

    poster_final_relpath = None
    if upload_success and poster_temp_path and slug:
        try:
            user_folder = os.path.join(BASE_REPO_FOLDER, "xcam-db", "user", username)
            os.makedirs(user_folder, exist_ok=True)
            poster_final_name = f"{slug}.jpg"
            poster_final_path = os.path.join(user_folder, poster_final_name)
            os.rename(poster_temp_path, poster_final_path)
            poster_final_relpath = os.path.relpath(poster_final_path, BASE_REPO_FOLDER)
            print(f"🖼️ Poster movido para {poster_final_path}")
            git_commit_and_push(poster_final_relpath, commit_message=f"Add poster {poster_final_name} do usuário {username}")
        except Exception as e:
            print(f"❌ Erro ao mover/renomear poster: {e}")

    if upload_success:
        try:
            user_folder = os.path.join(BASE_REPO_FOLDER, "xcam-db", "user", username)
            os.makedirs(user_folder, exist_ok=True)
            json_filepath = os.path.join(user_folder, "rec.json")

            file_base = file_name.replace('.mp4', '')
            parts = file_base.split('_')
            if len(parts) >= 4:
                json_data = parts[-3]
                json_horario = parts[-2]
                json_tempo = parts[-1]
            else:
                now = datetime.now()
                json_data = now.strftime("%d-%m-%Y")
                json_horario = now.strftime("%H-%M")
                json_tempo = format_seconds(duration_seconds)

            poster_url = f"https://db.xcam.gay/user/{username}/{slug}.jpg" if slug else ""
            url_iframe = f"https://short.icu/{slug}?thumbnail={poster_url}" if slug else ""

            new_video_entry = {
                "video": slug if slug else "ID_não_retornado",
                "title": file_base,
                "file": file_name,
                "url": uploaded_url if uploaded_url else "URL_não_retornada",
                "poster": poster_url,
                "urlIframe": url_iframe,
                "data": json_data,
                "horario": json_horario,
                "tempo": json_tempo
            }

            def zerar_base(username):
                return {
                    "username": username,
                    "records": 0,
                    "videos": []
                }

            if not os.path.exists(json_filepath):
                rec_data = zerar_base(username)
            else:
                try:
                    with open(json_filepath, 'r', encoding='utf-8') as f:
                        loaded = json.load(f)
                    valid = (
                        isinstance(loaded, dict)
                        and "username" in loaded
                        and "records" in loaded
                        and "videos" in loaded
                        and isinstance(loaded["videos"], list)
                    )
                    rec_data = loaded if valid else zerar_base(username)
                except Exception:
                    rec_data = zerar_base(username)

            rec_data["records"] += 1
            rec_data["videos"].append(new_video_entry)
            with open(json_filepath, 'w', encoding='utf-8') as f:
                json.dump(rec_data, f, indent=2, ensure_ascii=False)
            print(f"✅ rec.json para {username} atualizado em {json_filepath}")

            rel_json_path = os.path.relpath(json_filepath, BASE_REPO_FOLDER)
            git_commit_and_push(rel_json_path, commit_message=f"Atualiza rec.json do usuário {username}")
        except Exception as e:
            print(f"❌ Erro ao atualizar rec.json: {e}")
            abyss_response = f"Upload sucesso, erro no JSON: {e}"

    if poster_temp_path and os.path.exists(poster_temp_path):
        try:
            os.remove(poster_temp_path)
            print(f"🗑️ Poster temporário removido: {poster_temp_path}")
        except Exception as e:
            print(f"⚠️ Não foi possível remover o poster temporário: {e}")

    return upload_success, abyss_response, slug

# %% [markdown]
# # Célula 9: Processamento Automático (Paralelo e Interativo)
#
# **Objetivo:**
# Controla todo o fluxo do notebook, processando as transmissões em paralelo (mais de uma ao mesmo tempo) para eficiência. Utiliza as funções anteriores para buscar, gravar, processar, fazer upload e registrar os vídeos.
#
# **Como funciona:**
#
# *   Se o usuário informou nomes específicos, busca/grava apenas esses.
# *   Caso contrário, processa normalmente por páginas.
# *   Mantém o loop até não encontrar mais transmissões.
# *   Exibe logs amigáveis e controla a espera entre páginas.

# %%
# Célula 9: Processamento automático (paralelo e interativo)
# ----------------------------------------------------------
def process_page(page=PAGE_DEFAULT, limit=LIMIT_DEFAULT, usuarios_especificos=None):
    print(f"\n📄 Processando página {page}\n")
    streams = []
    if usuarios_especificos:
        streams = buscar_usuarios_especificos(usuarios_especificos)
    else:
        streams = get_broadcasts(limit=limit, page=page)

    if not streams:
        print(f"\n🚫 Nenhuma stream encontrada na página {page}.")
        return False

    jobs = []
    results = multiprocessing.Manager().list()

    def worker(username, m3u8_url, poster_url, results):
        result = gravar_stream(username, m3u8_url, poster_url)
        results.append(result)

    print(f"🚀 Gravando {len(streams)} streams em paralelo...")
    for stream in streams:
        username = stream["username"]
        m3u8_url = stream["src"]
        poster_url = stream.get("poster")
        p = multiprocessing.Process(target=worker, args=(username, m3u8_url, poster_url, results))
        jobs.append(p)
        p.start()

    for job in jobs:
        job.join()

    print(f"\n🏁 Todas as gravações da página {page} concluídas.")

    return True if streams else False

def main():
    usuarios_especificos = perguntar_transmissoes_especificas()
    page = PAGE_DEFAULT
    limit = LIMIT_DEFAULT if not usuarios_especificos else API_SEARCH_LIMIT

    print("🤖 Iniciando busca e gravação de streams...")
    while True:
        ok = process_page(page=page, limit=limit, usuarios_especificos=usuarios_especificos)
        if not ok:
            print("\nEncerrando processo por falta de streams.")
            break
        if not usuarios_especificos:
            page += 1
            if page > 10:
                page = 1
            print(f"\nAguardando 5 segundos antes de processar a próxima página...")
            time.sleep(5)
        else:
            break

    print("\n✨ Processo principal finalizado.")

if __name__ == '__main__':
    try:
        if 'google.colab' in str(get_ipython()):
            main()
        else:
            print("Execute main() manualmente se desejar rodar fora do Colab.")
    except NameError:
        print("Não está rodando em Colab/IPython. Execute main() se desejar.")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#
# 🖼️ Poster baixado em: /content/temp_recordings/alan31956_poster_temp.jpg
# 🎬 Iniciando gravação de: monaco071 (URL: https://stackvaults-hls.xcdnpro.com/9f89a34b-fce4-47f3-bce3-651808ce855c/hls/as+229fc1ae-6c8d-4a4f-8e89-88fdbac09e06/index.m3u8) em /content/temp_recordings/monaco071_20250601_150320_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/magierdx_poster_temp.jpg
#
#
# 🎬 Iniciando gravação de: timmy48gay (URL: https://stackvaults-hls.xcdnpro.com/5f834bdd-63b2-4d30-89cf-c40d196f1753/hls/as+564299cf-d698-4bcc-a605-1d0a4f71e26c/index.m3u8) em /content/temp_recordings/timmy48gay_20250601_150320_temp.mp4
#
# 🖼️ Poster baixado em: /content/temp_recordings/osat1_poster_temp.jpg
# 🎬 Iniciando gravação de: reddy85 (URL: https://stackvaults-hls.xcdnpro.com/86f5ef48-86c3-488f-836a-ae78fdc836ed/hls/as+3e1ce976-6b32-4534-b1e4-51d20fb7eb82/index.m3u8) em /content/temp_recordings/reddy85_20250601_150321_temp.mp4
#
#
# 🎬 Iniciando gravação de: alanbob588 (URL: https://stackvaults-hls.xcdnpro.com/a5d7e4ff-ca7d-4092-ab91-874c78df37d5/hls/as+e3d5e949-ad23-45e1-b41b-f26582b907ed/index.m3u8) em /content/temp_recordings/alanbob588_20250601_150321_temp.mp4
#
# 🎬 Iniciando gravação de: Josemtz1 (URL: https://cam4-hls.xcdnpro.com/322/cam4-origin-live/Josemtz1-322-863a2a0d-db4d-48ad-a34d-e962c68a6fa0_aac/playlist.m3u8) em /content/temp_recordings/Josemtz1_20250601_150321_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/monaco071_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/timmy48gay_poster_temp.jpg
#
# 🎬 Iniciando gravação de: etab2 (URL: https://stackvaults-hls.xcdnpro.com/32841b10-705d-4203-a16f-be4be58ebb07/hls/as+e43b2607-8c07-4d38-b24d-44d098ad4eb3/index.m3u8) em /content/temp_recordings/etab2_20250601_150321_temp.mp4
# 🖼️ Poster baixado em: /content/temp_recordings/reddy85_poster_temp.jpg
#
# 🎬 Iniciando gravação de: cuirhautbois (URL: https://stackvaults-hls.xcdnpro.com/113c170d-6fec-4cf6-94f0-072e29c8e38d/hls/as+c6ff381f-cd9c-46c5-8a82-91704dffcf21/index.m3u8) em /content/temp_recordings/cuirhautbois_20250601_150321_temp.mp4
#
#
# 🎬 Iniciando gravação de: mcq937 (URL: https://cam4-hls.xcdnpro.com/296/cam4-origin-live/mcq937-296-6c13679c-fe2f-4dbb-a9f7-84e057c7f071_aac/playlist.m3u8) em /content/temp_recordings/mcq937_20250601_150321_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/Josemtz1_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/alanbob588_poster_temp.jpg
#
#
# 🖼️ Poster baixado em: /content/temp_recordings/etab2_poster_temp.jpg
# 🎬 Iniciando gravação de: VibesLover (URL: https://cam4-hls.xcdnpro.com/299/cam4-origin-live/VibesLover-299-1a3ec77b-d777-4698-8472-5442a006e20e_aac/playlist.m3u8) em /content/temp_recordings/VibesLover_20250601_150321_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/cuirhautbois_poster_temp.jpg
# 🎬 Iniciando gravação de: Partnerthotdirt (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/Partnerthotdirt-321-b2ca1ed2-6354-4c8c-a036-6b185ace2470_aac/playlist.m3u8) em /content/temp_recordings/Partnerthotdirt_20250601_150321_temp.mp4
#
# 🖼️ Poster baixado em: /content/temp_recordings/mcq937_poster_temp.jpg
# 🎬 Iniciando gravação de: kjellstrong (URL: https://stackvaults-hls.xcdnpro.com/e32a46e2-0127-42bd-b3a7-1ae60f9701c2/hls/as+f0b215f6-15e7-4e44-9939-b3999e148f5c/index.m3u8) em /content/temp_recordings/kjellstrong_20250601_150321_temp.mp4
#
#
#
#
# 🎬 Iniciando gravação de: CasaldNATALRN (URL: https://cam4-hls.xcdnpro.com/319/cam4-origin-live/CasaldNATALRN-319-7550e30e-853b-42bc-bca6-265a9073a418_aac/playlist.m3u8) em /content/temp_recordings/CasaldNATALRN_20250601_150322_temp.mp4
# 🖼️ Poster baixado em: /content/temp_recordings/kjellstrong_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/VibesLover_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/Partnerthotdirt_poster_temp.jpg
#
#
# 🎬 Iniciando gravação de: dodger27 (URL: https://stackvaults-hls.xcdnpro.com/0cd37419-9485-48f8-a655-1f845d67ae7c/hls/as+90612428-f34d-481b-9a05-0c8d3539c155/index.m3u8) em /content/temp_recordings/dodger27_20250601_150322_temp.mp4
# 🖼️ Poster baixado em: /content/temp_recordings/CasaldNATALRN_poster_temp.jpg
#
# 🎬 Iniciando gravação de: LoverForLadies (URL: https://stackvaults-hls.xcdnpro.com/7c323b86-eaba-4448-a31e-47f1d2ef5726/hls/as+e96e16c8-4fca-4ab5-ab3b-ca1612c41340/index.m3u8) em /content/temp_recordings/LoverForLadies_20250601_150322_temp.mp4
# 🎬 Iniciando gravação de: masosaudtmd2 (URL: https://stackvaults-hls.xcdnpro.com/f7c832d3-e5c8-4e75-9535-ef48e0627054/hls/as+bb746198-ad8d-4c95-a10e-003767d5e60d/index.m3u8) em /content/temp_recordings/masosaudtmd2_20250601_150322_temp.mp4
#
#
#
# 🎬 Iniciando gravação de: Papillondusud (URL: https://cam4-hls.xcdnpro.com/299/cam4-origin-live/Papillondusud-299-f89fbb34-4b04-43eb-9366-130b1c44a20f_aac/playlist.m3u8) em /content/temp_recordings/Papillondusud_20250601_150322_temp.mp4
#
# 🎬 Iniciando gravação de: sohotpassif (URL: https://stackvaults-hls.xcdnpro.com/edaedc65-90df-4f7a-80ae-e82639f0e87d/hls/as+437dda61-713f-4594-a2c3-d7e5ad5171cb/index.m3u8) em /content/temp_recordings/sohotpassif_20250601_150322_temp.mp4🖼️ Poster baixado em: /content/temp_recordings/LoverForLadies_poster_temp.jpg🖼️ Poster baixado em: /content/temp_recordings/dodger27_poster_temp.jpg
#
#
# 🖼️ Poster baixado em: /content/temp_recordings/masosaudtmd2_poster_temp.jpg
# 🎬 Iniciando gravação de: Mastschwein01 (URL: https://stackvaults-hls.xcdnpro.com/c457bfe1-a625-43e1-8dd2-a1feb95e44bc/hls/as+10249c92-66ca-4cc1-be65-1b9c7feec8eb/index.m3u8) em /content/temp_recordings/Mastschwein01_20250601_150322_temp.mp4
#
# 🖼️ Poster baixado em: /content/temp_recordings/Papillondusud_poster_temp.jpg
#
# 🎬 Iniciando gravação de: MattyBody21 (URL: https://stackvaults-hls.xcdnpro.com/6bac251f-226f-47fb-8c89-887a517346a7/hls/as+33b90668-91e0-4d5e-ae12-052654356f05/index.m3u8) em /content/temp_recordings/MattyBody21_20250601_150323_temp.mp4
# 🖼️ Poster baixado em: /content/temp_recordings/sohotpassif_poster_temp.jpg
# 🖼️ Poster baixado em: /content/temp_recordings/Mastschwein01_poster_temp.jpg
# ⏱️ [niconice87] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [estilico619619] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [vic_3051] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Felinoshere] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [virgenbta] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [MattyBody21] Gravados: 0 min | Restantes: 33 min | Tempo total: 0m5s — 📊 0.3% concluído
#
# ❌ FFmpeg falhou para MattyBody21. Código de saída: 1⏱️ [Tommy_bw] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [alan31956] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [timmy48gay] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [magierdx] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Pollon797] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [ken846752] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [SamuelArGo] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [naughtyd2] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
#
# ⏱️ [jospe94] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [monaco071] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [alanbob588] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [osat1] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [reddy85] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [etab2] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [cuirhautbois] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Josemtz1] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
#
# ⏱️ [LoverForLadies] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [VibesLover] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [Partnerthotdirt] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [masosaudtmd2] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Papillondusud] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [CasaldNATALRN] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [kjellstrong] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [sohotpassif] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Mastschwein01] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [dodger27] Gravados: 0 min | Restantes: 33 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [estilico619619] Gravados: 0 min | Restantes: 33 min | Tempo total: 0m29s — 📊 1.5% concluído
# ✅ Gravação FFmpeg finalizada para: estilico619619_20250601_150320_temp.mp4. Duração aproximada: 29s
# ⏩ Duração gravada (29s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [Tommy_bw] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [etab2] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [alan31956] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [vic_3051] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [Pollon797] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [timmy48gay] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [virgenbta] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [Felinoshere] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [LoverForLadies] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Papillondusud] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [naughtyd2] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [alanbob588] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [reddy85] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [osat1] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [ken846752] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [jospe94] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [VibesLover] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [niconice87] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [cuirhautbois] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [sohotpassif] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [SamuelArGo] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [CasaldNATALRN] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [kjellstrong] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [masosaudtmd2] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [monaco071] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Partnerthotdirt] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [magierdx] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [dodger27] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m4s — 📊 3.2% concluído
# ⏱️ [Mastschwein01] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Tommy_bw] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [etab2] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [alan31956] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Pollon797] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [naughtyd2] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [timmy48gay] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [ken846752] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [LoverForLadies] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [virgenbta] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Felinoshere] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [vic_3051] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [alanbob588] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [jospe94] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [reddy85] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [monaco071] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [niconice87] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [VibesLover] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [sohotpassif] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [masosaudtmd2] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [cuirhautbois] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [SamuelArGo] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [Mastschwein01] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [kjellstrong] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [dodger27] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [magierdx] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [CasaldNATALRN] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [osat1] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [Partnerthotdirt] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [Papillondusud] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Tommy_bw] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [etab2] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [vic_3051] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [alan31956] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [Pollon797] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [LoverForLadies] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [naughtyd2] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [virgenbta] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Felinoshere] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [jospe94] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [alanbob588] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [reddy85] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m4s — 📊 9.3% concluído
# ⏱️ [ken846752] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [SamuelArGo] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [VibesLover] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [kjellstrong] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [masosaudtmd2] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [timmy48gay] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m4s — 📊 9.3% concluído
# ⏱️ [monaco071] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [osat1] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [magierdx] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [niconice87] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [cuirhautbois] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [sohotpassif] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [Mastschwein01] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Partnerthotdirt] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [Papillondusud] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [dodger27] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m8s — 📊 9.5% concluído
# ⏱️ [Josemtz1] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m23s — 📊 10.3% concluído
# ✅ Gravação FFmpeg finalizada para: Josemtz1_20250601_150321_temp.mp4. Duração aproximada: 203s
# ⏩ Duração gravada (203s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [CasaldNATALRN] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m39s — 📊 11.1% concluído
# ✅ Gravação FFmpeg finalizada para: CasaldNATALRN_20250601_150322_temp.mp4. Duração aproximada: 219s
# ⏩ Duração gravada (219s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [alanbob588] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m48s — 📊 11.5% concluído
# ✅ Gravação FFmpeg finalizada para: alanbob588_20250601_150321_temp.mp4. Duração aproximada: 228s
# ⏩ Duração gravada (228s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [Tommy_bw] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [naughtyd2] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [alan31956] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [etab2] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [VibesLover] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ✅ Gravação FFmpeg finalizada para: VibesLover_20250601_150321_temp.mp4. Duração aproximada: 240s
# ⏩ Duração gravada (240s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [reddy85] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Pollon797] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [LoverForLadies] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [vic_3051] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [virgenbta] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Felinoshere] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [jospe94] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [ken846752] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [dodger27] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [monaco071] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [sohotpassif] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [cuirhautbois] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [SamuelArGo] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [niconice87] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [kjellstrong] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [masosaudtmd2] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [osat1] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [magierdx] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [timmy48gay] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Mastschwein01] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Partnerthotdirt] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [Papillondusud] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [Tommy_bw] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Papillondusud] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [etab2] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [vic_3051] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [naughtyd2] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [dodger27] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [LoverForLadies] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [reddy85] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Pollon797] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [virgenbta] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [Felinoshere] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [monaco071] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [osat1] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [niconice87] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [SamuelArGo] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [cuirhautbois] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [ken846752] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [jospe94] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [alan31956] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m4s — 📊 15.4% concluído
# ⏱️ [sohotpassif] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [masosaudtmd2] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [magierdx] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [timmy48gay] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [kjellstrong] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [Mastschwein01] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Partnerthotdirt] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m3s — 📊 15.3% concluído
# ⏱️ [Papillondusud] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Tommy_bw] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m3s — 📊 18.3% concluído
# ⏱️ [etab2] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [vic_3051] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [reddy85] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [alan31956] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [naughtyd2] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Pollon797] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [virgenbta] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [LoverForLadies] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [Felinoshere] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [kjellstrong] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [SamuelArGo] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [monaco071] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [ken846752] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [cuirhautbois] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [niconice87] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [osat1] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [dodger27] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m3s — 📊 18.3% concluído
# ⏱️ [timmy48gay] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [jospe94] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m4s — 📊 18.4% concluído
# ⏱️ [magierdx] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Mastschwein01] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [sohotpassif] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [masosaudtmd2] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m5s — 📊 18.4% concluído
# ⏱️ [Partnerthotdirt] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Tommy_bw] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [dodger27] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [etab2] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [vic_3051] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [reddy85] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [ken846752] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [LoverForLadies] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [naughtyd2] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [Pollon797] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [Papillondusud] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [virgenbta] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [jospe94] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [alan31956] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [monaco071] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [niconice87] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [Felinoshere] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [kjellstrong] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [masosaudtmd2] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [magierdx] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído⏱️ [timmy48gay] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
#
# ⏱️ [cuirhautbois] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [SamuelArGo] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [Mastschwein01] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
# ⏱️ [Partnerthotdirt] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m1s — 📊 21.3% concluído
# ⏱️ [osat1] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m2s — 📊 21.3% concluído
# ⏱️ [sohotpassif] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m — 📊 21.2% concluído
# ⏱️ [Papillondusud] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Tommy_bw] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [etab2] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m2s — 📊 24.3% concluído
# ⏱️ [alan31956] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [vic_3051] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Felinoshere] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [naughtyd2] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [LoverForLadies] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [Pollon797] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [ken846752] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [kjellstrong] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [reddy85] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [virgenbta] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [jospe94] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m2s — 📊 24.3% concluído
# ⏱️ [SamuelArGo] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m3s — 📊 24.4% concluído
# ⏱️ [monaco071] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [cuirhautbois] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [osat1] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m — 📊 24.2% concluído
# ⏱️ [masosaudtmd2] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m3s — 📊 24.4% concluído
# ⏱️ [niconice87] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [magierdx] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Partnerthotdirt] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [Mastschwein01] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m1s — 📊 24.3% concluído
# ⏱️ [timmy48gay] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m2s — 📊 24.3% concluído
# ⏱️ [sohotpassif] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m2s — 📊 24.3% concluído
# ⏱️ [Tommy_bw] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m16s — 📊 25.1% concluído
# ✅ Gravação FFmpeg finalizada para: Tommy_bw_20250601_150320_temp.mp4. Duração aproximada: 496s
# ✅ Arquivo renomeado para: Tommy_bw_01-06-2025_15-03_8m16s.mp4
# ⬆️ Upload de: Tommy_bw_01-06-2025_15-03_8m16s.mp4 para Abyss.to...
# ⏱️ [dodger27] Gravados: 8 min | Restantes: 25 min | Tempo total: 8m3s — 📊 24.4% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/uC-f6GosO | SLUG: uC-f6GosO
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Tommy_bw/uC-f6GosO.jpg
# ✅ rec.json para Tommy_bw atualizado em /content/XCam/xcam-db/user/Tommy_bw/rec.json
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Tommy_bw_01-06-2025_15-03_8m16s.mp4
# ⏱️ [naughtyd2] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [Pollon797] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [reddy85] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [virgenbta] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [etab2] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m2s — 📊 27.4% concluído
# ⏱️ [Felinoshere] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [vic_3051] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [LoverForLadies] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m4s — 📊 27.5% concluído
# ⏱️ [alan31956] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m4s — 📊 27.5% concluído
# ⏱️ [ken846752] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m — 📊 27.3% concluído
# ⏱️ [masosaudtmd2] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [jospe94] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [osat1] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [monaco071] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [cuirhautbois] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [kjellstrong] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [magierdx] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [SamuelArGo] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [niconice87] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m3s — 📊 27.4% concluído
# ⏱️ [sohotpassif] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [timmy48gay] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m5s — 📊 27.5% concluído
# ⏱️ [dodger27] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m5s — 📊 27.5% concluído
# ⏱️ [Mastschwein01] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Partnerthotdirt] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Papillondusud] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m1s — 📊 27.3% concluído
# ⏱️ [Papillondusud] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m3s — 📊 30.5% concluído
# ⏱️ [Mastschwein01] Gravados: 9 min | Restantes: 24 min | Tempo total: 9m58s — 📊 30.2% concluído✅ Gravação FFmpeg finalizada para: Mastschwein01_20250601_150322_temp.mp4. Duração aproximada: 598s
#
# ✅ Arquivo renomeado para: Mastschwein01_01-06-2025_15-03_9m58s.mp4
# ⬆️ Upload de: Mastschwein01_01-06-2025_15-03_9m58s.mp4 para Abyss.to...
# ⏱️ [etab2] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m3s — 📊 30.5% concluído
# ⏱️ [Pollon797] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m — 📊 30.3% concluído
# ⏱️ [LoverForLadies] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m3s — 📊 30.5% concluído
# ⏱️ [virgenbta] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m — 📊 30.3% concluído
# ⏱️ [naughtyd2] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [ken846752] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m — 📊 30.3% concluído
# ⏱️ [vic_3051] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [kjellstrong] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [reddy85] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [Felinoshere] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m2s — 📊 30.4% concluído
# ⏱️ [cuirhautbois] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [jospe94] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m3s — 📊 30.5% concluído
# ⏱️ [monaco071] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [niconice87] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [masosaudtmd2] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [osat1] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [magierdx] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [SamuelArGo] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [dodger27] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m9s — 📊 30.8% concluído
# ⏱️ [timmy48gay] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m5s — 📊 30.6% concluído
# ⏱️ [alan31956] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m8s — 📊 30.7% concluído
# ⏱️ [sohotpassif] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [Partnerthotdirt] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m1s — 📊 30.4% concluído
# ⏱️ [Papillondusud] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/qWArgxQv7 | SLUG: qWArgxQv7
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Mastschwein01/qWArgxQv7.jpg
# ✅ rec.json para Mastschwein01 atualizado em /content/XCam/xcam-db/user/Mastschwein01/rec.json
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Mastschwein01_01-06-2025_15-03_9m58s.mp4
# ⏱️ [osat1] Gravados: 10 min | Restantes: 23 min | Tempo total: 10m59s — 📊 33.3% concluído
# ✅ Gravação FFmpeg finalizada para: osat1_20250601_150320_temp.mp4. Duração aproximada: 659s
# ✅ Arquivo renomeado para: osat1_01-06-2025_15-03_10m59s.mp4
# ⬆️ Upload de: osat1_01-06-2025_15-03_10m59s.mp4 para Abyss.to...
# ⏱️ [etab2] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m5s — 📊 33.6% concluído
# ⏱️ [vic_3051] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [Felinoshere] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [masosaudtmd2] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m — 📊 33.3% concluído
# ⏱️ [naughtyd2] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [Pollon797] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m — 📊 33.3% concluído
# ⏱️ [LoverForLadies] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [ken846752] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m — 📊 33.3% concluído
# ⏱️ [virgenbta] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m — 📊 33.3% concluído
# ⏱️ [jospe94] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m3s — 📊 33.5% concluído
# ⏱️ [cuirhautbois] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [niconice87] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [kjellstrong] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m3s — 📊 33.5% concluído
# ⏱️ [reddy85] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m5s — 📊 33.6% concluído
# ⏱️ [monaco071] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [timmy48gay] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [magierdx] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [SamuelArGo] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m2s — 📊 33.4% concluído
# ⏱️ [Partnerthotdirt] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m2s — 📊 33.4% concluído
# ⏱️ [alan31956] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m5s — 📊 33.6% concluído
# ⏱️ [sohotpassif] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m1s — 📊 33.4% concluído
# ⏱️ [dodger27] Gravados: 11 min | Restantes: 22 min | Tempo total: 11m9s — 📊 33.8% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/PdcyCdYfM | SLUG: PdcyCdYfM
# 🖼️ Poster movido para /content/XCam/xcam-db/user/osat1/PdcyCdYfM.jpg
# ✅ rec.json para osat1 atualizado em /content/XCam/xcam-db/user/osat1/rec.json
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/osat1_01-06-2025_15-03_10m59s.mp4
# ⏱️ [Papillondusud] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [etab2] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [vic_3051] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m2s — 📊 36.5% concluído
# ⏱️ [Pollon797] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m — 📊 36.4% concluído
# ⏱️ [alan31956] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m3s — 📊 36.5% concluído
# ⏱️ [reddy85] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [naughtyd2] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [Felinoshere] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [LoverForLadies] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [virgenbta] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m — 📊 36.4% concluído
# ⏱️ [masosaudtmd2] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m — 📊 36.4% concluído
# ⏱️ [monaco071] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m — 📊 36.4% concluído
# ⏱️ [ken846752] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m — 📊 36.4% concluído
# ⏱️ [dodger27] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m — 📊 36.4% concluído
# ⏱️ [jospe94] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m3s — 📊 36.5% concluído
# ⏱️ [kjellstrong] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [SamuelArGo] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m — 📊 36.4% concluído
# ⏱️ [niconice87] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [magierdx] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [cuirhautbois] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m3s — 📊 36.5% concluído
# ⏱️ [timmy48gay] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [Partnerthotdirt] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [sohotpassif] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m1s — 📊 36.4% concluído
# ⏱️ [masosaudtmd2] Gravados: 12 min | Restantes: 21 min | Tempo total: 12m45s — 📊 38.6% concluído
# ✅ Gravação FFmpeg finalizada para: masosaudtmd2_20250601_150322_temp.mp4. Duração aproximada: 765s
# ✅ Arquivo renomeado para: masosaudtmd2_01-06-2025_15-03_12m45s.mp4
# ⬆️ Upload de: masosaudtmd2_01-06-2025_15-03_12m45s.mp4 para Abyss.to...
# ⏱️ [reddy85] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m — 📊 39.4% concluído
# ⏱️ [vic_3051] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m — 📊 39.4% concluído
# ⏱️ [naughtyd2] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m1s — 📊 39.4% concluído
# ⏱️ [etab2] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m3s — 📊 39.5% concluído
# ⏱️ [Pollon797] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m — 📊 39.4% concluído
# ⏱️ [alan31956] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m3s — 📊 39.5% concluído
# ⏱️ [ken846752] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m — 📊 39.4% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/6CNSTE5Bd | SLUG: 6CNSTE5Bd
# 🖼️ Poster movido para /content/XCam/xcam-db/user/masosaudtmd2/6CNSTE5Bd.jpg
# ✅ rec.json para masosaudtmd2 atualizado em /content/XCam/xcam-db/user/masosaudtmd2/rec.json
# ⏱️ [Felinoshere] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m1s — 📊 39.4% concluído
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/masosaudtmd2_01-06-2025_15-03_12m45s.mp4
# ⏱️ [Papillondusud] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m1s — 📊 39.4% concluído
# ⏱️ [jospe94] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m3s — 📊 39.5% concluído
# ⏱️ [SamuelArGo] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m — 📊 39.4% concluído
# ⏱️ [virgenbta] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m3s — 📊 39.5% concluído
# ⏱️ [niconice87] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m7s — 📊 39.7% concluído
#
# ✅ Gravação FFmpeg finalizada para: niconice87_20250601_150320_temp.mp4. Duração aproximada: 787s
# ✅ Arquivo renomeado para: niconice87_01-06-2025_15-03_13m7s.mp4⬆️ Upload de: niconice87_01-06-2025_15-03_13m7s.mp4 para Abyss.to...
# ⏱️ [cuirhautbois] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m1s — 📊 39.4% concluído
# ⏱️ [kjellstrong] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m3s — 📊 39.5% concluído
# ⏱️ [magierdx] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m1s — 📊 39.4% concluído
# ⏱️ [timmy48gay] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m2s — 📊 39.5% concluído
# ⏱️ [LoverForLadies] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m7s — 📊 39.7% concluído
# ⏱️ [monaco071] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m — 📊 39.4% concluído
# ⏱️ [sohotpassif] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m1s — 📊 39.4% concluído
# ⏱️ [dodger27] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m4s — 📊 39.6% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/npLXEsfBt | SLUG: npLXEsfBt
# 🖼️ Poster movido para /content/XCam/xcam-db/user/niconice87/npLXEsfBt.jpg
# ✅ rec.json para niconice87 atualizado em /content/XCam/xcam-db/user/niconice87/rec.json
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/niconice87_01-06-2025_15-03_13m7s.mp4
# ⏱️ [Partnerthotdirt] Gravados: 13 min | Restantes: 20 min | Tempo total: 13m31s — 📊 41.0% concluído
# ✅ Gravação FFmpeg finalizada para: Partnerthotdirt_20250601_150321_temp.mp4. Duração aproximada: 811s
# ✅ Arquivo renomeado para: Partnerthotdirt_01-06-2025_15-03_13m31s.mp4
# ⬆️ Upload de: Partnerthotdirt_01-06-2025_15-03_13m31s.mp4 para Abyss.to...
# ⏱️ [alan31956] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [etab2] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [vic_3051] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m — 📊 42.4% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/fN1voc2Pi | SLUG: fN1voc2Pi
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Partnerthotdirt/fN1voc2Pi.jpg
# ⏱️ [Pollon797] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ✅ rec.json para Partnerthotdirt atualizado em /content/XCam/xcam-db/user/Partnerthotdirt/rec.json
# ⏱️ [LoverForLadies] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Partnerthotdirt_01-06-2025_15-03_13m31s.mp4
# ⏱️ [reddy85] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m2s — 📊 42.5% concluído
# ⏱️ [jospe94] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [Felinoshere] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [ken846752] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m — 📊 42.4% concluído
# ⏱️ [naughtyd2] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [SamuelArGo] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m — 📊 42.4% concluído
# ⏱️ [cuirhautbois] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [timmy48gay] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m — 📊 42.4% concluído
# ⏱️ [magierdx] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [kjellstrong] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [virgenbta] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m2s — 📊 42.5% concluído
# ⏱️ [monaco071] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m — 📊 42.4% concluído
# ⏱️ [sohotpassif] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m1s — 📊 42.5% concluído
# ⏱️ [dodger27] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m4s — 📊 42.6% concluído
# ⏱️ [jospe94] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m28s — 📊 43.8% concluído
# ✅ Gravação FFmpeg finalizada para: jospe94_20250601_150320_temp.mp4. Duração aproximada: 868s
# ✅ Arquivo renomeado para: jospe94_01-06-2025_15-03_14m28s.mp4
# ⬆️ Upload de: jospe94_01-06-2025_15-03_14m28s.mp4 para Abyss.to...
# ⏱️ [Papillondusud] Gravados: 14 min | Restantes: 19 min | Tempo total: 14m5s — 📊 42.7% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/PFN1Fzmvk | SLUG: PFN1Fzmvk
# 🖼️ Poster movido para /content/XCam/xcam-db/user/jospe94/PFN1Fzmvk.jpg
# ✅ rec.json para jospe94 atualizado em /content/XCam/xcam-db/user/jospe94/rec.json
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/jospe94_01-06-2025_15-03_14m28s.mp4
# ⏱️ [etab2] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m1s — 📊 45.5% concluído
# ⏱️ [vic_3051] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m — 📊 45.5% concluído
# ⏱️ [reddy85] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m2s — 📊 45.6% concluído
# ⏱️ [Pollon797] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m4s — 📊 45.7% concluído✅ Gravação FFmpeg finalizada para: Pollon797_20250601_150320_temp.mp4. Duração aproximada: 904s
#
# ✅ Arquivo renomeado para: Pollon797_01-06-2025_15-03_15m4s.mp4
# ⬆️ Upload de: Pollon797_01-06-2025_15-03_15m4s.mp4 para Abyss.to...
# ⏱️ [naughtyd2] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m1s — 📊 45.5% concluído
# ⏱️ [virgenbta] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m1s — 📊 45.5% concluído
# ⏱️ [Felinoshere] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m1s — 📊 45.5% concluído
# ⏱️ [ken846752] Gravados: 15 min | Restantes: 18 min | Tempo total: 15m1s — 📊 45.5% concluído
# ...
# ⏱️ [Exedenieve] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [elincubo999] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [BEARMAX] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [marcofranca] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [Mariano19778] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [pegadormaxo] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [DominicSccott24] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [StellarDuo] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [Dot20_crajubar] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [OiRenan] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [hotboyneon49] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [rayan456fun] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [Big_dick_boys_] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [jovencitoxxxx18] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [rickyquetick] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [rayo220] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [placer188] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [superkinghot] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [Paulotesao7] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [AdonisKo] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m1s — 📊 3.1% concluído
# ⏱️ [Rubber_faggot] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m — 📊 3.0% concluído
# ⏱️ [alex21i] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m5s — 📊 3.3% concluído
# ✅ Gravação FFmpeg finalizada para: alex21i_20250601_180547_temp.mp4. Duração aproximada: 65s
# ⏩ Duração gravada (65s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [j_escorpio] Gravados: 1 min | Restantes: 32 min | Tempo total: 1m2s — 📊 3.1% concluído
# ⏱️ [ChicoElektroc] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [BEARMAX] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [hpluvscash] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [StellarDuo] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [Den_DreaddX] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [marioluige] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [DominicSccott24] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [kevinturvy1] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Exedenieve] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [marcofranca] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Mariano19778] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [superkinghot] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [MaitreAnges] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [AdonisKo] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [OiRenan] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Tatelover] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [pegadormaxo] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [rayan456fun] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [rayo220] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [Big_dick_boys_] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [rickyquetick] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [elincubo999] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m2s — 📊 6.2% concluído
# ⏱️ [hotboyneon49] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m3s — 📊 6.2% concluído
# ⏱️ [jovencitoxxxx18] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [Paulotesao7] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m1s — 📊 6.1% concluído
# ⏱️ [Rubber_faggot] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [j_escorpio] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [placer188] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m — 📊 6.1% concluído
# ⏱️ [Dot20_crajubar] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m35s — 📊 7.8% concluído
# ✅ Gravação FFmpeg finalizada para: Dot20_crajubar_20250601_180545_temp.mp4. Duração aproximada: 155s
# ⏩ Duração gravada (155s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [ChicoElektroc] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [marioluige] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [kevinturvy1] Gravados: 2 min | Restantes: 31 min | Tempo total: 2m56s — 📊 8.9% concluído
# ✅ Gravação FFmpeg finalizada para: kevinturvy1_20250601_180545_temp.mp4. Duração aproximada: 176s
# ⏩ Duração gravada (176s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [BEARMAX] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [StellarDuo] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Exedenieve] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [DominicSccott24] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [hpluvscash] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [marcofranca] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Den_DreaddX] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [pegadormaxo] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Mariano19778] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [hotboyneon49] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [elincubo999] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [MaitreAnges] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [Tatelover] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [AdonisKo] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [rayan456fun] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [jovencitoxxxx18] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [Big_dick_boys_] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [superkinghot] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [rayo220] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [Paulotesao7] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m1s — 📊 9.1% concluído
# ⏱️ [j_escorpio] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [OiRenan] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [rickyquetick] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [Rubber_faggot] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m — 📊 9.1% concluído
# ⏱️ [placer188] Gravados: 3 min | Restantes: 30 min | Tempo total: 3m2s — 📊 9.2% concluído
# ⏱️ [ChicoElektroc] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [marioluige] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [BEARMAX] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [hpluvscash] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [StellarDuo] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Den_DreaddX] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Mariano19778] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Exedenieve] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [jovencitoxxxx18] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [DominicSccott24] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [marcofranca] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [elincubo999] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Tatelover] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [superkinghot] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [hotboyneon49] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [AdonisKo] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [OiRenan] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [MaitreAnges] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [rickyquetick] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [Big_dick_boys_] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [pegadormaxo] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [rayo220] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m1s — 📊 12.2% concluído
# ⏱️ [Paulotesao7] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [rayan456fun] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [Rubber_faggot] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [j_escorpio] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m — 📊 12.1% concluído
# ⏱️ [placer188] Gravados: 4 min | Restantes: 29 min | Tempo total: 4m2s — 📊 12.2% concluído
# ⏱️ [ChicoElektroc] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Den_DreaddX] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [StellarDuo] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [hpluvscash] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [BEARMAX] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [DominicSccott24] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [elincubo999] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [marioluige] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [marcofranca] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Exedenieve] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Mariano19778] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [hotboyneon49] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m1s — 📊 15.2% concluído
# ⏱️ [MaitreAnges] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [pegadormaxo] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Tatelover] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [jovencitoxxxx18] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Paulotesao7] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [rayo220] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [superkinghot] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [OiRenan] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [AdonisKo] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [rayan456fun] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Big_dick_boys_] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [rickyquetick] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [j_escorpio] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m — 📊 15.2% concluído
# ⏱️ [Rubber_faggot] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m2s — 📊 15.3% concluído
# ⏱️ [placer188] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m4s — 📊 15.4% concluído
# ⏱️ [pegadormaxo] Gravados: 5 min | Restantes: 28 min | Tempo total: 5m54s — 📊 17.9% concluído
# ✅ Gravação FFmpeg finalizada para: pegadormaxo_20250601_180545_temp.mp4. Duração aproximada: 354s
# ⏩ Duração gravada (354s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [ChicoElektroc] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m3s — 📊 18.3% concluído
# ⏱️ [BEARMAX] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [marioluige] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m3s — 📊 18.3% concluído
# ⏱️ [DominicSccott24] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [StellarDuo] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Exedenieve] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [marcofranca] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Mariano19778] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [MaitreAnges] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Den_DreaddX] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m3s — 📊 18.3% concluído
# ⏱️ [hpluvscash] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [jovencitoxxxx18] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [hotboyneon49] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Big_dick_boys_] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Tatelover] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [rayo220] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [elincubo999] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [elincubo999] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m5s — 📊 18.4% concluído
# ✅ Gravação FFmpeg finalizada para: elincubo999_20250601_180545_temp.mp4. Duração aproximada: 365s
# ⏩ Duração gravada (365s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [rayan456fun] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [rickyquetick] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [AdonisKo] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m — 📊 18.2% concluído
# ⏱️ [Paulotesao7] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [OiRenan] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [j_escorpio] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m1s — 📊 18.2% concluído
# ⏱️ [Rubber_faggot] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [superkinghot] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m3s — 📊 18.3% concluído
# ⏱️ [placer188] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m2s — 📊 18.3% concluído
# ⏱️ [MaitreAnges] Gravados: 6 min | Restantes: 27 min | Tempo total: 6m43s — 📊 20.4% concluído
# ✅ Gravação FFmpeg finalizada para: MaitreAnges_20250601_180546_temp.mp4. Duração aproximada: 403s
# ⏩ Duração gravada (403s) menor que o mínimo (420s). Arquivo descartado.
# ⏱️ [ChicoElektroc] Gravados: 7 min | Restantes: 26 min | Tempo total: 7m3s — 📊 21.4% concluído
