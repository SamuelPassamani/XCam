# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelPassamani/XCam/blob/main/xcam-colab/XCam_REC_V2.8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Célula 1: Configurações Auxiliares e Parâmetros Gerais
#
# **Objetivo:**
# Esta célula inicializa variáveis globais para ajuste rápido do comportamento do notebook, como:
#
# *   Quantidade de transmissões por página (LIMIT_DEFAULT)
# *   Página inicial a ser buscada (PAGE_DEFAULT)
# *   Tempo máximo de gravação de cada vídeo (RECORD_SECONDS)
# *   Tempo mínimo exigido para considerar o vídeo válido (RECORD_SECONDS_MIN)
# *   Limite de busca ao procurar usuários específicos (API_SEARCH_LIMIT)
# *   **Novo:** Quantidade de transmissões processadas até realizar commit/push (COMMIT_PUSH_THRESHOLD)
#
# **Interatividade:**
# Inclui a função perguntar_transmissoes_especificas() que pergunta ao usuário se deseja gravar transmissões de usuários específicos. Caso sim, solicita os nomes e retorna uma lista.
#
# **Como funciona:**
# Antes do processamento, você pode ajustar facilmente qualquer parâmetro. O notebook perguntará se você quer gravar transmissões de usuários específicos e, se quiser, pedirá os nomes (ex: "userNovo234, jovemPT")

# %%
# Célula 1: Configurações Auxiliares e Parâmetros Gerais
# ------------------------------------------------------
# Ajuste facilmente os principais parâmetros do sistema e escolha se deseja gravar transmissões específicas.

from google.colab import drive
drive.mount('/content/drive')

import os

# Parâmetros globais editáveis
LIMIT_DEFAULT = 25            # Quantidade padrão de transmissões por página
PAGE_DEFAULT = 1              # Página inicial
RECORD_SECONDS = 420         # Tempo máximo de gravação por vídeo (segundos)
RECORD_SECONDS_MIN = 300      # Tempo mínimo de gravação exigido para upload (segundos)
API_SEARCH_LIMIT = 1000       # Limite máximo para busca de usuários específicos
COMMIT_PUSH_THRESHOLD = 0   # Apenas faz commit/push após processar/gravar 10 transmissões

globals().update({
    'LIMIT_DEFAULT': LIMIT_DEFAULT,
    'PAGE_DEFAULT': PAGE_DEFAULT,
    'RECORD_SECONDS': RECORD_SECONDS,
    'RECORD_SECONDS_MIN': RECORD_SECONDS_MIN,
    'API_SEARCH_LIMIT': API_SEARCH_LIMIT,
    'COMMIT_PUSH_THRESHOLD': COMMIT_PUSH_THRESHOLD
})

def perguntar_transmissoes_especificas():
    resp = input('Deseja gravar alguma transmissão específica? (sim/não): ').strip().lower()
    if resp.startswith('s'):
        usuarios = input('Informe o(s) nome(s) de usuário, separados por vírgula (ex: userNovo234, jovemPT): ')
        usuarios_lista = [u.strip() for u in usuarios.split(',') if u.strip()]
        return usuarios_lista
    return []
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Célula 2: Instalação do ffmpeg
#
# **Objetivo:**
# Garante que o ffmpeg esteja instalado no ambiente do Google Colab. O ffmpeg é fundamental para gravar os vídeos das transmissões.
#
# **Como funciona:**
# Executa comandos de instalação do ffmpeg, necessários para o funcionamento correto das próximas etapas.

# %%
# Célula 2: Instalação do ffmpeg
# ------------------------------
# Garante que o ffmpeg está instalado no ambiente Colab.

# !apt-get update -y
# !apt-get install -y ffmpeg
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:6 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,741 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [32.8 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,245 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,739 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,295 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,476 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,984 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,630 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,553 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,003 kB]
# Fetched 32.1 MB in 4s (8,467 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.

# %% [markdown]
# # Célula 3: Imports Essenciais e Funções Utilitárias
#
# **Objetivo:**
# Importa todas as bibliotecas do Python necessárias (como requests, multiprocessing, datetime, etc.) e define funções utilitárias para:
#
# *   Formatar o tempo de gravação (`format_seconds`)
# *   Exibir logs de progresso (`log_progress`)
# *   Baixar e salvar a imagem de poster de cada transmissão (`download_and_save_poster`)
# *   Gerar poster automaticamente com o ffmpeg a partir da transmissão ao vivo caso o poster esteja ausente ou inválido (`generate_poster_with_ffmpeg`)
# *   Validar se o poster é válido (`is_poster_valid`)
# *   Garantir a criação do arquivo de log temporário para controlar transmissões atualmente em processamento
#
# **Como funciona:**
# Essas funções são usadas em várias partes do notebook para manipular tempos, apresentar informações mais amigáveis, garantir que os posters das transmissões estejam sempre presentes (baixando da API ou gerando com ffmpeg se necessário) e manter o controle das transmissões em processamento por meio do arquivo de log temporário.

# %%
# Célula 3: Imports essenciais e utilitários
# ------------------------------------------
# Importação de bibliotecas e funções auxiliares de formatação e download.
# Também garante a criação do arquivo de log temporário para controle de transmissões em processamento.
# ADIÇÃO: Função para gerar poster com ffmpeg caso não haja poster válido na API.
# CORREÇÃO: Antes de rodar ffmpeg, testa se a URL do stream está acessível (HEAD).
# Se não estiver, retorna None e faz o tratamento do erro de stream offline.

import os
import requests
import multiprocessing
from datetime import datetime
import json
import time
import subprocess
import math
import re

from IPython import get_ipython
from IPython.display import display

# Caminho do arquivo de log temporário
LOG_PROCESSAMENTO_PATH = "/content/xcam_processing.log"

# Garante que o arquivo de log temporário exista ao iniciar o notebook
if not os.path.exists(LOG_PROCESSAMENTO_PATH):
    with open(LOG_PROCESSAMENTO_PATH, "w") as f:
        f.write("")  # Cria arquivo vazio

def format_seconds(seconds):
    total_seconds = int(seconds)
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    parts = []
    if hours > 0: parts.append(f"{hours}h")
    if minutes > 0 or (hours == 0 and seconds > 0): parts.append(f"{minutes}m")
    if seconds > 0 or total_seconds == 0: parts.append(f"{seconds}s")
    return "".join(parts) if parts else "0s"

def log_progress(username, elapsed_seconds, total_seconds):
    percent = min((elapsed_seconds / total_seconds) * 100, 100)
    tempo = format_seconds(elapsed_seconds)
    minutos_gravados = math.floor(elapsed_seconds / 60)
    minutos_restantes = max(0, math.ceil((total_seconds - elapsed_seconds) / 60))
    print(f"⏱️ [{username}] Gravados: {minutos_gravados} min | Restantes: {minutos_restantes} min | Tempo total: {tempo} — 📊 {percent:.1f}% concluído")

def download_and_save_poster(poster_url, username, temp_folder):
    """
    Baixa e salva o poster a partir de uma URL HTTP/HTTPS.
    Ou, se receber um caminho local existente, apenas retorna esse caminho.
    Retorna o caminho do arquivo salvo, ou None em caso de erro.
    """
    # Se for um caminho local já existente, apenas retorna
    if os.path.exists(poster_url):
        return poster_url
    # Se for uma URL HTTP/HTTPS, faz o download normalmente
    if isinstance(poster_url, str) and (poster_url.startswith("http://") or poster_url.startswith("https://")):
        try:
            response = requests.get(poster_url, timeout=15)
            response.raise_for_status()
            ext = os.path.splitext(poster_url)[1].lower()
            if ext not in [".jpg", ".jpeg", ".png"]:
                ext = ".jpg"
            poster_temp_path = os.path.join(temp_folder, f"{username}_poster_temp{ext}")
            with open(poster_temp_path, "wb") as f:
                f.write(response.content)
            print(f"🖼️ Poster baixado em: {poster_temp_path}")
            return poster_temp_path
        except Exception as e:
            print(f"❌ Erro ao baixar poster {poster_url}: {e}")
            return None
    else:
        print(f"❌ poster_url inválido ou não encontrado: {poster_url}")
        return None

def generate_poster_with_ffmpeg(m3u8_url, username, temp_folder, frame_time=7, timeout=20):
    """
    Gera um poster (screenshot) usando ffmpeg a partir da URL .m3u8 da transmissão.
    Retorna o caminho do arquivo gerado ou None em caso de erro.
    frame_time: segundo do vídeo em que o poster será capturado (padrão: 7s para evitar frame preto).
    Antes de rodar o ffmpeg, faz uma checagem HTTP HEAD para saber se a URL do stream está ativa.
    """
    # Checa se a URL está acessível antes de rodar ffmpeg
    try:
        head_resp = requests.head(m3u8_url, timeout=5)
        if not head_resp.ok:
            print(f"⚠️ Stream offline ou não disponível para {username} (status {head_resp.status_code})")
            return None
    except Exception as e:
        print(f"⚠️ Erro de conexão ao acessar stream de {username}: {e}")
        return None

    poster_ffmpeg_path = os.path.join(temp_folder, f"{username}_poster_ffmpeg.jpg")
    # Comando ffmpeg: captura 1 frame após frame_time segundos de vídeo
    command = [
        "ffmpeg",
        "-y",  # sobrescreve arquivo se já existir
        "-ss", str(frame_time),  # avança para frame_time segundos antes de capturar
        "-i", m3u8_url,
        "-vframes", "1",
        "-q:v", "2",  # qualidade alta
        poster_ffmpeg_path
    ]
    try:
        print(f"🎬 Gerando poster com ffmpeg para {username} no segundo {frame_time}...")
        # subprocess.run com timeout para evitar travamento caso a URL esteja offline/inválida
        result = subprocess.run(
            command,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            timeout=timeout
        )
        if result.returncode == 0 and os.path.exists(poster_ffmpeg_path):
            print(f"🖼️ Poster gerado via ffmpeg: {poster_ffmpeg_path}")
            return poster_ffmpeg_path
        else:
            print(f"❌ ffmpeg não conseguiu gerar poster para {username}. Saída: {result.stderr.decode(errors='ignore')}")
            return None
    except subprocess.TimeoutExpired:
        print(f"⏰ Tempo excedido ao tentar gerar poster para {username} via ffmpeg.")
        return None
    except Exception as e:
        print(f"❌ Erro inesperado ao gerar poster via ffmpeg: {e}")
        return None

def is_poster_valid(poster_path):
    """
    Verifica se o poster existe e não está vazio.
    """
    return poster_path and os.path.exists(poster_path) and os.path.getsize(poster_path) > 0

# %% [markdown]
# # Célula 4: Clonagem do Repositório GitHub para o Colab
#
# **Objetivo:**
# Clona o repositório do GitHub para o ambiente local do Colab, garantindo que o ambiente sempre esteja atualizado e pronto para armazenar os arquivos gerados.
#
# **Como funciona:**
# Remove qualquer repositório anterior para evitar conflitos, clona o novo, prepara pastas temporárias e define a URL de upload para o Abyss.to.

# %%
# Célula 4: Clonagem do repositório GitHub para o Colab e para o Drive
# --------------------------------------------------------------------
# Clona o repositório para o ambiente Colab E também para o Google Drive (se montado),
# garantindo ambiente limpo, persistência e sincronização para futuras execuções.

GITHUB_USER = "SamuelPassamani"
GITHUB_REPO = "XCam"
GITHUB_BRANCH = "main"
GITHUB_TOKEN = "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"

repo_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"

# Clona para o ambiente Colab
# !rm -rf {GITHUB_REPO}
# !git clone -b {GITHUB_BRANCH} {repo_url}

# Caminhos locais
TEMP_OUTPUT_FOLDER = "/content/temp_recordings"
os.makedirs(TEMP_OUTPUT_FOLDER, exist_ok=True)
BASE_REPO_FOLDER = f"/content/{GITHUB_REPO}"

# Caminho para o Drive (se montado)
DRIVE_MOUNT = "/content/drive/MyDrive/XCam.Drive"
DRIVE_REPO_FOLDER = f"{DRIVE_MOUNT}/{GITHUB_REPO}"

# Clona também para o Drive, se estiver montado
import os
if os.path.exists(DRIVE_MOUNT):
    # Remove repositório antigo no Drive (se existir), depois clona
    # !rm -rf "{DRIVE_REPO_FOLDER}"
    # !git clone -b {GITHUB_BRANCH} {repo_url} "{DRIVE_REPO_FOLDER}"
    print(f"✅ Repositório também clonado no Drive: {DRIVE_REPO_FOLDER}")
else:
    print(f"⚠️ Google Drive não está montado em {DRIVE_MOUNT}.")

ABYSS_UPLOAD_URL = 'http://up.hydrax.net/0128263f78f0b426d617bb61c2a8ff43'
# Out:
# Cloning into 'XCam'...
# remote: Enumerating objects: 6368, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 6368 (delta 128), reused 58 (delta 58), pack-reused 6159 (from 2)
# Receiving objects: 100% (6368/6368), 22.94 MiB | 14.28 MiB/s, done.
# Resolving deltas: 100% (3921/3921), done.
# Cloning into '/content/drive/MyDrive/XCam.Drive/XCam'...
# remote: Enumerating objects: 6368, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 6368 (delta 128), reused 58 (delta 58), pack-reused 6159 (from 2)
# Receiving objects: 100% (6368/6368), 22.94 MiB | 8.88 MiB/s, done.
# Resolving deltas: 100% (3920/3920), done.
# Updating files: 100% (404/404), done.
# ✅ Repositório também clonado no Drive: /content/drive/MyDrive/XCam.Drive/XCam

# %% [markdown]
# # Célula 5: Commit e Push Automáticos (rec.json e poster)
#
# ---
#
# **Objetivo:**
# Define a função git_commit_and_push() para garantir que apenas arquivos importantes (JSON de gravação e posters de imagem) sejam adicionados, commitados e enviados ao repositório.
#
# **Como funciona:**
# Configura o git, adiciona o arquivo desejado, faz commit e push para o repositório remoto.

# %%
# Célula 5: Commit e Push automáticos (rec.json e poster)
# -------------------------------------------------------
# Esta função agora aceita tanto um caminho único (str) quanto uma lista de caminhos (list) para realizar commit e push.
# O comportamento original para um único arquivo é preservado, mas agora é possível realizar commit em lote,
# conforme necessário para a estratégia de batch commit com threshold.

def git_commit_and_push(file_paths, commit_message="Atualiza rec.json"):
    """
    Realiza git add, commit e push dos arquivos especificados.
    - file_paths pode ser uma string (arquivo único) ou uma lista de arquivos.
    - commit_message é a mensagem de commit utilizada.
    """
    repo_dir = f"/content/{GITHUB_REPO}"
    os.chdir(repo_dir)
    subprocess.run(["git", "config", "user.email", "contato@aserio.work"])
    subprocess.run(["git", "config", "user.name", "SamuelPassamani"])

    # Permite tanto um arquivo único quanto uma lista de arquivos
    if isinstance(file_paths, str):
        file_paths = [file_paths]

    # Adiciona cada arquivo ao staging do git
    for file_path in file_paths:
        subprocess.run(["git", "add", file_path])

    # Realiza o commit (permite commit vazio por segurança)
    subprocess.run(["git", "commit", "-m", commit_message, "--allow-empty"], check=False)

    # Push para o repositório remoto usando autenticação via token
    subprocess.run([
        "git", "push", f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{GITHUB_REPO}.git"
    ])

# %% [markdown]
# # Célula 6: Busca de Transmissões na API XCam, com Fallback via liveInfo
#
# **Objetivo:**
# Busca as transmissões ativas na API principal da XCam. Se alguma transmissão não retornar o link da stream (src), faz um fallback via a API /liveInfo do usuário para tentar obter o link direto.
# Agora, além de garantir que o lote retornado esteja sempre completo até LIMIT_DEFAULT, evitar duplicidade consultando o log de transmissões em processamento e controlar a unicidade das transmissões processadas, também assegura que cada transmissão tenha um poster válido:
# Se o poster não estiver presente, for nulo ou inválido, o notebook gera automaticamente uma imagem de poster usando o ffmpeg a partir da URL da transmissão ao vivo (.m3u8).
#
# **Como funciona:**
#
# *   Para cada transmissão encontrada, retorna um dicionário com username, src (endereço do stream) e poster (imagem local gerada ou baixada).
# *   Se for solicitado buscar usuários específicos, só retorna esses.
# *   Caso algum usuário não tenha src na API principal, faz nova chamada à API liveInfo para tentar encontrar o link da transmissão.
# *   Caso o poster esteja ausente, vazio, nulo ou inválido (tanto na API principal quanto na liveInfo), o notebook gera e salva automaticamente uma imagem de poster via ffmpeg no momento do processamento.
# *   Antes de adicionar uma transmissão ao lote, verifica se ela já está em processamento (consultando o log temporário) e se não há duplicidade na seleção.
# *   O lote final respeita sempre o LIMIT_DEFAULT de transmissões válidas, preenchendo com fallback se necessário.

# %%
# Célula 6: Busca de transmissões na API XCam, com fallback via liveInfo
# ----------------------------------------------------------------------
# Ajuste: O parâmetro 'limit' agora é sempre respeitado, sem multiplicação nem excesso.
# O corte do número de transmissões válidas ocorre ao final, garantindo que nunca ultrapassa 'limit'.
# Não altera nenhuma outra lógica além do solicitado.

def get_broadcasts(limit=LIMIT_DEFAULT, page=PAGE_DEFAULT, usuarios_especificos=None, temp_folder="/content"):
    """
    Busca transmissões ao vivo via API principal da XCam.
    Se usuarios_especificos for fornecido (lista), retorna apenas essas transmissões.
    Faz fallback via liveInfo para transmissões sem src.
    Garante poster válido: se ausente, gera com ffmpeg a partir do src/m3u8.
    Mantém o lote até LIMIT_DEFAULT, evita duplicidade e checa log de transmissões em processamento.
    """
    # Caminho do arquivo de log temporário
    LOG_PROCESSAMENTO_PATH = "/content/xcam_processing.log"

    # Carrega transmissões já em processamento para evitar duplicidade
    transmissao_em_proc = set()
    if os.path.exists(LOG_PROCESSAMENTO_PATH):
        with open(LOG_PROCESSAMENTO_PATH, "r") as f:
            transmissao_em_proc = set([line.strip() for line in f if line.strip()])

    # Busca principal de transmissões
    # AJUSTE: Sempre usa 'limit' diretamente, sem multiplicação
    api_url_main = f"https://api.xcam.gay/?limit={API_SEARCH_LIMIT if usuarios_especificos else limit}&page={page}"
    print(f"🌐 Acessando API principal: {api_url_main}")

    streams_from_main = []
    streams_without_preview = []

    try:
        response_main = requests.get(api_url_main)
        response_main.raise_for_status()
        data_main = response_main.json()
        broadcasts_data = data_main.get("broadcasts")
        if not broadcasts_data:
            print("⚠️ Chave 'broadcasts' não encontrada na resposta da API principal.")
            return []
        items = broadcasts_data.get("items")
        if not isinstance(items, list):
            print(f"⚠️ Chave 'items' não encontrada ou não é uma lista em 'broadcasts'.")
            return []

        # Percorre todas as transmissões retornadas pela API principal
        for item in items:
            preview = item.get("preview") or {}
            src = preview.get("src")
            poster = preview.get("poster")
            username = item.get("username", "desconhecido")
            # Evita duplicidade: só adiciona se não estiver em processamento
            if username in transmissao_em_proc:
                continue
            if src:
                if (not usuarios_especificos) or (username in usuarios_especificos):
                    # Garante poster válido: se ausente, gera com ffmpeg
                    poster_path = None
                    if poster and isinstance(poster, str) and poster.strip():
                        poster_path = download_and_save_poster(poster, username, temp_folder)
                    if not is_poster_valid(poster_path):
                        poster_path = generate_poster_with_ffmpeg(src, username, temp_folder)
                    streams_from_main.append({
                        "username": username,
                        "src": src,
                        "poster": poster_path
                    })
            else:
                # Caso não tenha src, adiciona para tentar fallback via liveInfo
                if (not usuarios_especificos) or (username in usuarios_especificos):
                    streams_without_preview.append({"username": username})

        print(f"✅ {len(streams_from_main)} transmissões com URL na API principal (página {page}).")

    except Exception as e:
        print(f"❌ Erro ao acessar API principal: {e}")
        return []

    # Fallback: busca via liveInfo para streams sem URL na API principal
    streams_from_liveinfo = []
    if streams_without_preview:
        print(f"🔁 Buscando liveInfo para {len(streams_without_preview)} streams sem URL na API principal...")
        for stream_info in streams_without_preview:
            username = stream_info["username"]
            if username in transmissao_em_proc:
                continue
            api_url_liveinfo = f"https://api.xcam.gay/user/{username}/liveInfo"
            try:
                response_liveinfo = requests.get(api_url_liveinfo)
                response_liveinfo.raise_for_status()
                data_liveinfo = response_liveinfo.json()
                m3u8_url = data_liveinfo.get("cdnURL") or data_liveinfo.get("edgeURL")
                # liveInfo não retorna poster
                poster_path = None
                if m3u8_url:
                    # Gera poster via ffmpeg pois liveInfo não retorna poster
                    poster_path = generate_poster_with_ffmpeg(m3u8_url, username, temp_folder)
                    streams_from_liveinfo.append({
                        "username": username,
                        "src": m3u8_url,
                        "poster": poster_path
                    })
                else:
                    # Log detalhado para fácil debug de casos sem m3u8_url
                    print(f"⚠️ liveInfo de {username} não retornou cdnURL/edgeURL (usuário possivelmente offline).")
            except Exception as ex:
                print(f"❌ Erro ao buscar liveInfo para {username}: {ex}")
            time.sleep(0.5)

    # Junta, evita duplicidade de usuário e respeita 'limit' FINAL
    final_streams_list = []
    seen_usernames = set()
    for stream in streams_from_main + streams_from_liveinfo:
        username = stream["username"]
        if username in seen_usernames or username in transmissao_em_proc:
            continue
        final_streams_list.append(stream)
        seen_usernames.add(username)
        if len(final_streams_list) >= limit:
            break

    print(f"🔎 Página {page}: {len(final_streams_list)} streams válidas após fallback (respeitando limit={limit}).")
    return final_streams_list

def buscar_usuarios_especificos(usuarios_lista, temp_folder="/content"):
    """
    Busca usuários específicos via API, utilizando um limit alto.
    Fallback via liveInfo para usuários sem src.
    Garante poster válido: se ausente, gera com ffmpeg a partir do src/m3u8.
    Considera log de transmissões em processamento para evitar duplicidade.
    """
    LOG_PROCESSAMENTO_PATH = "/content/xcam_processing.log"
    transmissao_em_proc = set()
    if os.path.exists(LOG_PROCESSAMENTO_PATH):
        with open(LOG_PROCESSAMENTO_PATH, "r") as f:
            transmissao_em_proc = set([line.strip() for line in f if line.strip()])

    api_url = f"https://api.xcam.gay/?limit={API_SEARCH_LIMIT}&page=1"
    print(f"🔍 Buscando usuários específicos em {api_url}")
    try:
        response = requests.get(api_url)
        response.raise_for_status()
        data = response.json()
        items = data.get("broadcasts", {}).get("items", [])
        encontrados = []
        sem_src = []
        for item in items:
            username = item.get("username", "")
            if username in usuarios_lista and username not in transmissao_em_proc:
                preview = item.get("preview") or {}
                src = preview.get("src")
                poster = preview.get("poster")
                poster_path = None
                if src:
                    if poster and isinstance(poster, str) and poster.strip():
                        poster_path = download_and_save_poster(poster, username, temp_folder)
                    if not is_poster_valid(poster_path):
                        poster_path = generate_poster_with_ffmpeg(src, username, temp_folder)
                    encontrados.append({
                        "username": username,
                        "src": src,
                        "poster": poster_path
                    })
                else:
                    # Se não encontrou src, registra para fallback via liveInfo
                    sem_src.append(username)
        # Fallback via liveInfo
        for username in sem_src:
            if username in transmissao_em_proc:
                continue
            api_url_liveinfo = f"https://api.xcam.gay/user/{username}/liveInfo"
            try:
                response_liveinfo = requests.get(api_url_liveinfo)
                response_liveinfo.raise_for_status()
                data_liveinfo = response_liveinfo.json()
                m3u8_url = data_liveinfo.get("cdnURL") or data_liveinfo.get("edgeURL")
                poster_path = None
                if m3u8_url:
                    poster_path = generate_poster_with_ffmpeg(m3u8_url, username, temp_folder)
                    encontrados.append({
                        "username": username,
                        "src": m3u8_url,
                        "poster": poster_path
                    })
                else:
                    print(f"⚠️ liveInfo de {username} não retornou cdnURL/edgeURL (usuário possivelmente offline).")
            except Exception as ex:
                print(f"❌ Erro ao buscar liveInfo para {username}: {ex}")
            time.sleep(0.5)
        print(f"Encontrados {len(encontrados)} dos {len(usuarios_lista)} usuários procurados (incluindo fallback).")
        return encontrados
    except Exception as e:
        print(f"❌ Erro ao buscar usuários específicos: {e}")
        return []

# %% [markdown]
# # Célula 7: Gravação da Stream, Download/Geração do Poster e Controle de Tempo Mínimo
#
# **Objetivo:**
# Grava a transmissão ao vivo do usuário usando ffmpeg. Durante a gravação, baixa o poster da transmissão e, caso ele esteja ausente, inválido ou não possa ser baixado, gera automaticamente uma imagem de poster utilizando ffmpeg a partir da própria stream. Ao final, verifica se o tempo de gravação atingiu o mínimo desejado para ser considerado válido.
# Agora, também atualiza o log de transmissões em processamento ao iniciar e finalizar a gravação, garantindo o controle e a unicidade das transmissões processadas.
#
# **Como funciona:**
#
# *  Se o vídeo gravado for muito curto, descarta imediatamente o vídeo e o poster.
# *  Se for suficiente, renomeia o vídeo, faz upload, renomeia o poster e chama a função de atualização de JSON.
# *  Antes de iniciar a gravação, registra o usuário no log de transmissões em processamento; ao finalizar (com sucesso ou erro), remove o usuário desse log para liberar espaço para novas transmissões.
# *  Garante que sempre haverá um poster válido para cada transmissão, baixando da API quando possível ou gerando automaticamente com ffmpeg caso necessário.

# %%
# Célula 7: Gravação de stream, download/geração do poster e controle de tempo mínimo
# -----------------------------------------------------------------------------------
# Ajuste: Calcula a duração real do arquivo gravado usando ffprobe após finalizar o ffmpeg,
# garantindo que a validação de duração mínima e a formatação do nome usem o tempo real do arquivo,
# não o tempo do processo Python (que pode ser impreciso, finalizando antes).
# Não altera nenhuma outra lógica além do solicitado.

def get_video_duration(filepath):
    """
    Utiliza ffprobe para obter a duração real do arquivo mp4, em segundos.
    Retorna None em caso de erro.
    """
    import subprocess
    import json
    try:
        cmd = [
            "ffprobe", "-v", "error",
            "-show_entries", "format=duration",
            "-of", "json",
            filepath
        ]
        result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        info = json.loads(result.stdout)
        duration = float(info["format"]["duration"])
        return int(round(duration))
    except Exception as e:
        print(f"⚠️ Não foi possível obter duração via ffprobe: {e}")
        return None

def gravar_stream(username, m3u8_url, poster_url=None, poster_frame_time=7):
    """
    Grava a transmissão ao vivo do usuário usando ffmpeg.
    Garante poster válido: baixa da poster_url, ou gera automaticamente com ffmpeg se ausente/inválido.
    Controla o tempo mínimo de gravação e gerencia o log de transmissões em processamento.
    poster_frame_time: tempo (em segundos) do vídeo onde a captura do poster será feita, se gerado via ffmpeg.
    """
    # Caminho do arquivo de log temporário
    LOG_PROCESSAMENTO_PATH = "/content/xcam_processing.log"

    # ----> Adiciona a transmissão ao log de transmissões em processamento
    try:
        with open(LOG_PROCESSAMENTO_PATH, "a") as f:
            f.write(f"{username}\n")
    except Exception as e:
        print(f"❌ Erro ao registrar transmissão em processamento no log: {e}")

    start_time_dt = datetime.now()
    data_str = start_time_dt.strftime("%d-%m-%Y")
    horario_str = start_time_dt.strftime("%H-%M")
    temp_filename = f"{username}_{start_time_dt.strftime('%Y%m%d_%H%M%S')}_temp.mp4"
    filepath = os.path.join(TEMP_OUTPUT_FOLDER, temp_filename)

    print(f"\n🎬 Iniciando gravação de: {username} (URL: {m3u8_url}) em {filepath}")

    # Garantia de poster válido:
    poster_temp_path = None
    if poster_url:
        poster_temp_path = download_and_save_poster(poster_url, username, TEMP_OUTPUT_FOLDER)
    # Se não conseguiu baixar ou poster é inválido, gera via ffmpeg (caso src válido disponível)
    if not is_poster_valid(poster_temp_path) and m3u8_url:
        # ATENÇÃO: A função usada aqui é a da Célula 3, que suporta timeout e tratamento robusto.
        poster_temp_path = generate_poster_with_ffmpeg(
            m3u8_url, username, TEMP_OUTPUT_FOLDER, frame_time=poster_frame_time
        )

    ffmpeg_cmd = ["ffmpeg", "-i", m3u8_url, "-t", str(RECORD_SECONDS), "-c", "copy", "-y", filepath]

    start_time_process = time.time()
    process = None

    try:
        process = subprocess.Popen(
            ffmpeg_cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1,
            universal_newlines=True
        )
        # Monitora o andamento do ffmpeg em tempo real (mantido para logs)
        elapsed_seconds = 0
        last_log_minute = -1
        while True:
            line = process.stdout.readline()
            if not line and process.poll() is not None:
                break
            if "time=" in line:
                try:
                    match = re.search(r"time=(\d+):(\d+):(\d+)", line)
                    if match:
                        h, m, s = map(int, match.groups())
                        elapsed_seconds = h * 3600 + m * 60 + s
                        if elapsed_seconds // 60 != last_log_minute:
                            log_progress(username, elapsed_seconds, RECORD_SECONDS)
                            last_log_minute = elapsed_seconds // 60
                except Exception:
                    pass

        process.wait()
        end_time_process = time.time()
        # Duração pelo processo Python (para log apenas)
        elapsed_seconds_proc = round(end_time_process - start_time_process)
        log_progress(username, elapsed_seconds_proc, RECORD_SECONDS)

        if process.returncode != 0:
            print(f"❌ FFmpeg falhou para {username}. Código de saída: {process.returncode}")
            return {
                'username': username,
                'filename': temp_filename,
                'filepath': filepath,
                'upload_success': False,
                'abyss_response': "Gravação FFmpeg falhou"
            }
        else:
            # ATENÇÃO: Usa ffprobe para obter a duração real do arquivo gravado!
            elapsed_seconds_real = get_video_duration(filepath)
            if elapsed_seconds_real is not None:
                print(f"✅ Duração real do arquivo gravado: {elapsed_seconds_real}s (ffprobe)")
            else:
                print(f"⚠️ Não foi possível aferir duração real, usando a do processo: {elapsed_seconds_proc}s")
                elapsed_seconds_real = elapsed_seconds_proc

            # Validação pelo tempo real do arquivo!
            if elapsed_seconds_real < RECORD_SECONDS_MIN:
                print(f"⏩ Duração gravada ({elapsed_seconds_real}s) menor que o mínimo ({RECORD_SECONDS_MIN}s). Arquivo descartado.")
                if os.path.exists(filepath): os.remove(filepath)
                if poster_temp_path and os.path.exists(poster_temp_path): os.remove(poster_temp_path)
                return {
                    'username': username,
                    'filename': temp_filename,
                    'filepath': filepath,
                    'upload_success': False,
                    'abyss_response': "Gravação muito curta (descartada)"
                }

            tempo_formatado = format_seconds(elapsed_seconds_real)
            final_filename = f"{username}_{data_str}_{horario_str}_{tempo_formatado}.mp4"
            final_filepath = os.path.join(TEMP_OUTPUT_FOLDER, final_filename)

            try:
                os.rename(filepath, final_filepath)
                print(f"✅ Arquivo renomeado para: {final_filename}")
                filepath_for_upload = final_filepath
                filename_for_upload = final_filename
            except Exception as e:
                print(f"❌ Erro ao renomear arquivo {temp_filename} para {final_filename}: {e}")
                filepath_for_upload = filepath
                filename_for_upload = temp_filename

            success, abyss_resp, slug = upload_to_abyss_and_update_json(
                filepath_for_upload, username, elapsed_seconds_real,
                poster_temp_path=poster_temp_path
            )

            return {
                'username': username,
                'filename': filename_for_upload,
                'filepath': filepath_for_upload,
                'upload_success': success,
                'abyss_response': abyss_resp,
                'slug': slug
            }

    except FileNotFoundError:
        print(f"❌ Erro: Comando 'ffmpeg' não encontrado. Certifique-se de que foi instalado corretamente.")
        return {
            'username': username,
            'filename': None,
            'filepath': None,
            'upload_success': False,
            'abyss_response': "Comando FFmpeg não encontrado"
        }
    except Exception as e:
        print(f"❌ Erro inesperado durante a execução do FFmpeg para {username}: {e}")
        return {
            'username': username,
            'filename': None,
            'filepath': None,
            'upload_success': False,
            'abyss_response': f"Erro inesperado na execução do FFmpeg: {e}"
        }
    finally:
        # ----> Remove a transmissão do log de transmissões em processamento
        try:
            if os.path.exists(LOG_PROCESSAMENTO_PATH):
                with open(LOG_PROCESSAMENTO_PATH, "r") as f:
                    linhas = f.readlines()
                with open(LOG_PROCESSAMENTO_PATH, "w") as f:
                    for l in linhas:
                        if l.strip() != username:
                            f.write(l)
        except Exception as e:
            print(f"❌ Erro ao remover transmissão do log de processamento: {e}")

        # Limpa o arquivo de vídeo temporário após upload (para não ocupar espaço no Colab)
        if 'filepath_for_upload' in locals() and os.path.exists(filepath_for_upload):
            try:
                os.remove(filepath_for_upload)
                print(f"🗑️ Arquivo de vídeo removido do Colab: {filepath_for_upload}")
            except Exception as e:
                print(f"⚠️ Não foi possível remover o arquivo de vídeo temporário: {e}")

# %% [markdown]
# # Célula 8: Upload para Abyss.to, Atualização do rec.json, Commit do Poster
#
# **Objetivo:**
# Faz upload do vídeo para o Abyss.to. Se bem-sucedido, renomeia/move o poster para a pasta correta do repositório, atualiza/cria o arquivo rec.json do usuário com todos os metadados (incluindo poster e urlIframe) e faz commit/push dos arquivos.
# Agora, os commits e pushs são feitos em lote, apenas quando a quantidade de arquivos alterados atinge o valor definido por COMMIT_PUSH_THRESHOLD, otimizando o fluxo de trabalho e reduzindo operações desnecessárias. Também garante que o poster utilizado (baixado ou gerado via ffmpeg) é corretamente movido e registrado.
#
# **Como funciona:**
#
# *   Preenche todos os campos do JSON conforme seu padrão, incluindo poster e urlIframe.
# *   Garante que apenas vídeos válidos sejam registrados e compartilha os links corretos.
# *   Move/renomeia o arquivo do poster utilizado para o local definitivo, sempre associando ao vídeo pelo slug no nome do arquivo.
# *   Ao invés de commitar/pushar a cada alteração, acumula os arquivos modificados e só realiza o commit/push ao atingir o threshold definido. No final do processamento, realiza commit/push dos arquivos restantes, se houver.
# *   Remove arquivos temporários de poster após mover para o destino final, mantendo o ambiente limpo.

# %%
# Célula 8: Upload para Abyss.to, atualização do rec.json, commit do poster (com cópia p/ Google Drive)
# -----------------------------------------------------------------------------------------
# Esta célula é responsável por:
# - Fazer upload do vídeo gravado para o serviço Abyss.to
# - Atualizar e registrar os metadados no arquivo rec.json do usuário
# - Mover/renomear o poster (imagem) para o local correto, sempre usando o novo poster (seja baixado ou gerado via ffmpeg)
# - Acumular arquivos para commit/push e executar o envio ao atingir o threshold de alterações
# - Fazer a limpeza de arquivos temporários após o uso
# - **NOVO:** Sempre que salvar/atualizar rec.json ou poster, copia também para o Google Drive (se montado)

import shutil

# Caminho base do Drive (ajuste se necessário)
DRIVE_USER_BASE = "/content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user"

def upload_to_abyss_and_update_json(
    filepath, username, duration_seconds, poster_temp_path=None,
    commit_buffer=None, commit_threshold=None
):
    """
    Faz upload do vídeo, atualiza o rec.json e move o poster.
    Acumula arquivos para commit/push e só executa quando atingir o threshold (ou 0).
    Sempre salva/atualiza rec.json e poster também em /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/{username}/
    """
    file_name = os.path.basename(filepath)
    file_type = 'video/mp4'
    print(f"⬆️ Upload de: {file_name} para Abyss.to...")

    upload_success = False
    abyss_response = "Upload falhou - Sem resposta"
    uploaded_url = None
    video_id = None
    slug = None

    # Inicializa buffers se não enviados
    if commit_buffer is None:
        if not hasattr(upload_to_abyss_and_update_json, 'commit_buffer'):
            upload_to_abyss_and_update_json.commit_buffer = []
        commit_buffer = upload_to_abyss_and_update_json.commit_buffer

    if commit_threshold is None:
        global COMMIT_PUSH_THRESHOLD
        commit_threshold = COMMIT_PUSH_THRESHOLD if 'COMMIT_PUSH_THRESHOLD' in globals() else 100

    # ---- Upload do vídeo para Abyss.to ----
    try:
        with open(filepath, 'rb') as f:
            files = { 'file': (file_name, f, file_type) }
            response = requests.post(ABYSS_UPLOAD_URL, files=files)
            resp_json = response.json()
            abyss_response = resp_json
            if resp_json.get('status'):
                upload_success = True
                uploaded_url = resp_json.get('url') or resp_json.get('urlIframe')
                video_id = resp_json.get('slug') or resp_json.get('video')
                slug = video_id
                print(f"📤 Upload bem-sucedido. URL: {uploaded_url} | SLUG: {slug}")
            else:
                print(f"❌ Falha no upload. Mensagem: {resp_json.get('message','')}")
    except Exception as e:
        abyss_response = f"Erro no upload: {e}"
        print(f"❌ Erro no upload: {e}")

    poster_final_relpath = None
    poster_final_path = None
    poster_final_name = None

    # ---- Move/renomeia o poster (imagem) para o local correto do usuário ----
    if upload_success and poster_temp_path and slug:
        try:
            user_folder = os.path.join(BASE_REPO_FOLDER, "xcam-db", "user", username)
            os.makedirs(user_folder, exist_ok=True)
            poster_final_name = f"{slug}.jpg"
            poster_final_path = os.path.join(user_folder, poster_final_name)
            os.rename(poster_temp_path, poster_final_path)
            poster_final_relpath = os.path.relpath(poster_final_path, BASE_REPO_FOLDER)
            print(f"🖼️ Poster movido para {poster_final_path}")
            # Adiciona poster ao buffer de commit
            if poster_final_relpath not in commit_buffer:
                commit_buffer.append(poster_final_relpath)
            # ---------- NOVO: Copia poster para o Google Drive ----------
            drive_user_dir = os.path.join(DRIVE_USER_BASE, username)
            os.makedirs(drive_user_dir, exist_ok=True)
            poster_drive_path = os.path.join(drive_user_dir, poster_final_name)
            try:
                shutil.copy2(poster_final_path, poster_drive_path)
                print(f"🗂️ Poster também salvo no Drive: {poster_drive_path}")
            except Exception as e:
                print(f"⚠️ Falha ao copiar poster para o Drive: {e}")
        except Exception as e:
            print(f"❌ Erro ao mover/renomear poster: {e}")

    # ---- Atualiza/Cria rec.json do usuário com os dados do vídeo ----
    if upload_success:
        try:
            user_folder = os.path.join(BASE_REPO_FOLDER, "xcam-db", "user", username)
            os.makedirs(user_folder, exist_ok=True)
            json_filepath = os.path.join(user_folder, "rec.json")

            file_base = file_name.replace('.mp4', '')
            parts = file_base.split('_')
            if len(parts) >= 4:
                json_data = parts[-3]
                json_horario = parts[-2]
                json_tempo = parts[-1]
            else:
                now = datetime.now()
                json_data = now.strftime("%d-%m-%Y")
                json_horario = now.strftime("%H-%M")
                json_tempo = format_seconds(duration_seconds)

            poster_url = f"https://db.xcam.gay/user/{username}/{slug}.jpg" if slug else ""
            url_iframe = f"https://short.icu/{slug}?thumbnail={poster_url}" if slug else ""

            new_video_entry = {
                "video": slug if slug else "ID_não_retornado",
                "title": file_base,
                "file": file_name,
                "url": uploaded_url if uploaded_url else "URL_não_retornada",
                "poster": poster_url,
                "urlIframe": url_iframe,
                "data": json_data,
                "horario": json_horario,
                "tempo": json_tempo
            }

            def zerar_base(username):
                return {
                    "username": username,
                    "records": 0,
                    "videos": []
                }

            # Carrega ou inicializa rec.json
            if not os.path.exists(json_filepath):
                rec_data = zerar_base(username)
            else:
                try:
                    with open(json_filepath, 'r', encoding='utf-8') as f:
                        loaded = json.load(f)
                    valid = (
                        isinstance(loaded, dict)
                        and "username" in loaded
                        and "records" in loaded
                        and "videos" in loaded
                        and isinstance(loaded["videos"], list)
                    )
                    rec_data = loaded if valid else zerar_base(username)
                except Exception:
                    rec_data = zerar_base(username)

            # Adiciona novo vídeo ao histórico
            rec_data["records"] += 1
            rec_data["videos"].append(new_video_entry)
            with open(json_filepath, 'w', encoding='utf-8') as f:
                json.dump(rec_data, f, indent=2, ensure_ascii=False)
            print(f"✅ rec.json para {username} atualizado em {json_filepath}")

            rel_json_path = os.path.relpath(json_filepath, BASE_REPO_FOLDER)
            # Adiciona rec.json ao buffer de commit
            if rel_json_path not in commit_buffer:
                commit_buffer.append(rel_json_path)
            # ---------- NOVO: Copia rec.json para o Google Drive ----------
            drive_user_dir = os.path.join(DRIVE_USER_BASE, username)
            os.makedirs(drive_user_dir, exist_ok=True)
            try:
                shutil.copy2(json_filepath, os.path.join(drive_user_dir, "rec.json"))
                print(f"🗂️ rec.json também salvo no Drive: {os.path.join(drive_user_dir, 'rec.json')}")
            except Exception as e:
                print(f"⚠️ Falha ao copiar rec.json para o Drive: {e}")
        except Exception as e:
            print(f"❌ Erro ao atualizar rec.json: {e}")
            abyss_response = f"Upload sucesso, erro no JSON: {e}"

    # ---- Commit/push automático ajustado ----
    # Se threshold for 0, faz commit/push IMEDIATO após cada processamento bem-sucedido
    if commit_threshold == 0 and len(commit_buffer) > 0:
        print(f"🚀 Commit/push automático IMEDIATO (threshold=0): {len(commit_buffer)} arquivos")
        try:
            git_commit_and_push(commit_buffer, commit_message="Commit automático após processamento bem-sucedido")
        except Exception as e:
            print(f"❌ Falha no commit/push automático imediato: {e}")
        commit_buffer.clear()
    # Caso threshold > 0, mantém o comportamento em lote
    elif commit_threshold > 0 and len(commit_buffer) >= commit_threshold:
        print(f"🚀 Commit/push automático: {len(commit_buffer)} arquivos (threshold: {commit_threshold})")
        try:
            git_commit_and_push(commit_buffer, commit_message="Atualiza arquivos em lote (threshold automático)")
        except Exception as e:
            print(f"❌ Falha no commit/push em lote: {e}")
        commit_buffer.clear()

    # ---- Limpeza do arquivo de poster temporário, se sobrou ----
    if poster_temp_path and os.path.exists(poster_temp_path):
        try:
            os.remove(poster_temp_path)
            print(f"🗑️ Poster temporário removido: {poster_temp_path}")
        except Exception as e:
            print(f"⚠️ Não foi possível remover o poster temporário: {e}")

    return upload_success, abyss_response, slug

# Função auxiliar para garantir commit/push dos arquivos restantes ao final do processamento
def commit_push_restantes():
    """
    Realiza commit/push final de todos os arquivos pendentes no buffer.
    """
    buffer = getattr(upload_to_abyss_and_update_json, 'commit_buffer', None)
    if buffer and len(buffer) > 0:
        print(f"🚀 Commit/push final de {len(buffer)} arquivos restantes")
        try:
            git_commit_and_push(buffer, commit_message="Atualiza arquivos finais (commit final)")
        except Exception as e:
            print(f"❌ Falha no commit/push final em lote: {e}")
        buffer.clear()

# %% [markdown]
# # Célula 9: Processamento Automático (Paralelo e Interativo)
#
# **Objetivo:**
# Controla todo o fluxo do notebook, processando as transmissões em paralelo (mais de uma ao mesmo tempo) para eficiência. Utiliza as funções anteriores para buscar, gravar, processar, fazer upload e registrar os vídeos.
# Agora, também garante que o lote de transmissões seja sempre preenchido até o LIMIT_DEFAULT, controla a unicidade das transmissões em processamento e faz o gerenciamento automático das páginas.
#
# **Como funciona:**
#
# *   Se o usuário informou nomes específicos, busca/grava apenas esses.
# *   Caso contrário, processa normalmente por páginas, sempre mantendo o lote cheio até LIMIT_DEFAULT e pulando transmissões já em processamento.
# *   Mantém o loop até não encontrar mais transmissões disponíveis para processar.
# *   Exibe logs amigáveis e controla a espera entre páginas.
# *   Faz o controle das páginas e da unicidade das transmissões processadas, evitando duplicidade e otimizando o uso do processamento paralelo.

# %%
# Célula 9: Processamento automático (paralelo e interativo) das transmissões
# ----------------------------------------------------------------------------
# Esta célula gerencia o fluxo principal do notebook de gravação:
# - Busca transmissões disponíveis (com controle de lote e duplicidade)
# - Processa as gravações em paralelo usando multiprocessing
# - Garante unicidade e sincronização com o log de transmissões em processamento
# - Lida tanto com busca automática quanto com seleção de usuários específicos

def process_page(page=PAGE_DEFAULT, limit=LIMIT_DEFAULT, usuarios_especificos=None):
    """
    Processa uma página de transmissões:
    - Busca transmissões disponíveis, sempre tentando manter o lote cheio até LIMIT_DEFAULT.
    - Garante que não haja duplicidade (controle pelo log de transmissões em processamento).
    - Inicia o processamento paralelo das transmissões.
    """
    print(f"\n📄 Processando página {page}\n")
    streams = []
    if usuarios_especificos:
        # Busca apenas transmissões dos usuários solicitados
        streams = buscar_usuarios_especificos(usuarios_especificos)
        # Garante que não ultrapasse o limit solicitado
        streams = streams[:limit]
    else:
        # Busca automática: tenta preencher o lote completo, mesmo que precise avançar páginas
        tentative_page = page
        streams = []
        seen_usernames = set()
        LOG_PROCESSAMENTO_PATH = "/content/xcam_processing.log"
        # Carrega transmissões já em processamento para evitar duplicidade
        transmissao_em_proc = set()
        if os.path.exists(LOG_PROCESSAMENTO_PATH):
            with open(LOG_PROCESSAMENTO_PATH, "r") as f:
                transmissao_em_proc = set([line.strip() for line in f if line.strip()])
        max_tentativas = 10  # Evita loops infinitos
        tentativas = 0
        while len(streams) < limit and tentativas < max_tentativas:
            curr_streams = get_broadcasts(limit=limit, page=tentative_page)
            # Adiciona apenas streams novas e não em processamento
            for s in curr_streams:
                username = s["username"]
                if username not in seen_usernames and username not in transmissao_em_proc:
                    streams.append(s)
                    seen_usernames.add(username)
                    if len(streams) >= limit:
                        break
            # Avança para a próxima página se necessário
            tentative_page += 1
            if tentative_page > 10:
                tentative_page = 1
            tentativas += 1
        # Garante que não retorna mais que o limite
        streams = streams[:limit]

    if not streams:
        print(f"\n🚫 Nenhuma stream encontrada na página {page}.")
        return False

    jobs = []
    results = multiprocessing.Manager().list()

    # Worker para gravar cada stream; roda em processo separado
    def worker(username, m3u8_url, poster_url, results):
        # Chama a função principal de gravação (lida com poster local ou gerado)
        result = gravar_stream(username, m3u8_url, poster_url)
        results.append(result)

    print(f"🚀 Gravando {len(streams)} streams em paralelo...")
    for stream in streams:
        username = stream["username"]
        m3u8_url = stream["src"]
        poster_url = stream.get("poster")
        # Cada transmissão é processada em paralelo (multiprocessing)
        p = multiprocessing.Process(target=worker, args=(username, m3u8_url, poster_url, results))
        jobs.append(p)
        p.start()

    # Aguarda o término de todas as gravações em paralelo
    for job in jobs:
        job.join()

    print(f"\n🏁 Todas as gravações da página {page} concluídas.")

    return True if streams else False

def main():
    """
    Loop principal:
    - Pergunta se deseja processar transmissões específicas ou buscar automaticamente.
    - Mantém o lote sempre cheio até LIMIT_DEFAULT, avançando página conforme necessário e evitando duplicidade.
    - Garante o controle das páginas e a unicidade das transmissões processadas.
    """
    usuarios_especificos = perguntar_transmissoes_especificas()
    page = PAGE_DEFAULT
    limit = LIMIT_DEFAULT if not usuarios_especificos else API_SEARCH_LIMIT

    print("🤖 Iniciando busca e gravação de streams...")
    while True:
        ok = process_page(page=page, limit=limit, usuarios_especificos=usuarios_especificos)
        if not ok:
            print("\nEncerrando processo por falta de streams.")
            break
        if not usuarios_especificos:
            page += 1
            if page > 10:
                page = 1
            print(f"\nAguardando 5 segundos antes de processar a próxima página...")
            time.sleep(5)
        else:
            break

    print("\n✨ Processo principal finalizado.")

if __name__ == '__main__':
    try:
        # Detecta se está rodando em ambiente Colab para execução automática
        if 'google.colab' in str(get_ipython()):
            main()
        else:
            print("Execute main() manualmente se desejar rodar fora do Colab.")
    except NameError:
        print("Não está rodando em Colab/IPython. Execute main() se desejar.")
# Out:
# 🤖 Iniciando busca e gravação de streams...
#
# 📄 Processando página 1
#
# 🌐 Acessando API principal: https://api.xcam.gay/?limit=25&page=1
# ✅ 0 transmissões com URL na API principal (página 1).
# 🔁 Buscando liveInfo para 25 streams sem URL na API principal...
# 🎬 Gerando poster com ffmpeg para Clausribeiro no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Clausribeiro_poster_ffmpeg.jpg
# ⚠️ liveInfo de Rchrd2 não retornou cdnURL/edgeURL (usuário possivelmente offline).
# 🎬 Gerando poster com ffmpeg para NicoDavis no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/NicoDavis_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Johnklleyn no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Johnklleyn_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Jt14 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Jt14_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para camcouple27 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/camcouple27_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para NeilCage66 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/NeilCage66_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para SchagenNH no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/SchagenNH_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para weedluv420 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/weedluv420_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para EDuardoBranco no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/EDuardoBranco_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para toshi603 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/toshi603_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para aqa192 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/aqa192_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para VNA027 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/VNA027_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para LoiroFortal085 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/LoiroFortal085_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Caballerozodi no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Caballerozodi_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para MaxBenetti no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/MaxBenetti_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Angelgarcia_2 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Angelgarcia_2_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para br1974fun no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/br1974fun_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para JacksonOlsenn no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/JacksonOlsenn_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para IanandJoseph no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/IanandJoseph_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Hotdickyxxx no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Hotdickyxxx_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Paulhot18 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Paulhot18_poster_ffmpeg.jpg
# ⚠️ Stream offline ou não disponível para classied3 (status 403)
# 🎬 Gerando poster com ffmpeg para Slendt94 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Slendt94_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Alexpiers no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Alexpiers_poster_ffmpeg.jpg
# 🔎 Página 1: 24 streams válidas após fallback (respeitando limit=25).
# 🌐 Acessando API principal: https://api.xcam.gay/?limit=25&page=2
# ✅ 0 transmissões com URL na API principal (página 2).
# 🔁 Buscando liveInfo para 25 streams sem URL na API principal...
# 🎬 Gerando poster com ffmpeg para Alexpiers no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Alexpiers_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para brunootz no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/brunootz_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para ApollonFit_X no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/ApollonFit_X_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para fervalle1975 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/fervalle1975_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Indian_Brasil no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Indian_Brasil_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Dziignr no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Dziignr_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para hotboyneon49 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/hotboyneon49_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Jam3sGh0st no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Jam3sGh0st_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Mathewwjm no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Mathewwjm_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Billcurioso no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Billcurioso_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para HANMUSCLEHOT no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/HANMUSCLEHOT_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para robert1774 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/robert1774_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para 22cmBigCockMilk no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/22cmBigCockMilk_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para scrocchia84 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/scrocchia84_poster_ffmpeg.jpg
# ⚠️ liveInfo de Omiranhaaaa não retornou cdnURL/edgeURL (usuário possivelmente offline).
# 🎬 Gerando poster com ffmpeg para heathen2505 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/heathen2505_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para LuisRico30 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/LuisRico30_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Jefer_rick no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Jefer_rick_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para rosamelah no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/rosamelah_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Hcapixaba no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Hcapixaba_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Alphapimmelchen no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Alphapimmelchen_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para 4sexBR no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/4sexBR_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para karlito27 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/karlito27_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para albertoo40 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/albertoo40_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para physicssexpert no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/physicssexpert_poster_ffmpeg.jpg
# 🔎 Página 2: 24 streams válidas após fallback (respeitando limit=25).
# 🚀 Gravando 25 streams em paralelo...
#
# 🎬 Iniciando gravação de: Clausribeiro (URL: https://stackvaults-hls.xcdnpro.com/5611fbaa-49d5-4944-bcca-9fd637fdc406/hls/as+338b6209-cf54-43fb-99e4-d3152a31d06c/index.m3u8) em /content/temp_recordings/Clausribeiro_20250605_010558_temp.mp4
#
# 🎬 Iniciando gravação de: NicoDavis (URL: https://cam4-hls.xcdnpro.com/319/cam4-origin-live/NicoDavis-319-0c499fec-03a6-4422-a919-6bb9ad2dd3d3_aac/playlist.m3u8) em /content/temp_recordings/NicoDavis_20250605_010558_temp.mp4
#
# 🎬 Iniciando gravação de: Jt14 (URL: https://cam4-hls.xcdnpro.com/322/cam4-origin-live/Jt14-322-17404716-c7f0-45d8-8cc4-31d06894e398_aac/playlist.m3u8) em /content/temp_recordings/Jt14_20250605_010558_temp.mp4
# 🎬 Iniciando gravação de: Johnklleyn (URL: https://cam4-hls.xcdnpro.com/320/cam4-origin-live/Johnklleyn-320-8f41ad44-6db6-430d-b8ea-0c0454f93355_aac/playlist.m3u8) em /content/temp_recordings/Johnklleyn_20250605_010558_temp.mp4
#
#
# 🎬 Iniciando gravação de: camcouple27 (URL: https://stackvaults-hls.xcdnpro.com/681d8880-b178-4daf-b3bf-f0f21a8964bd/hls/as+13864e99-4799-4f25-88b2-6a3c9b946b71/index.m3u8) em /content/temp_recordings/camcouple27_20250605_010558_temp.mp4
#
# 🎬 Iniciando gravação de: NeilCage66 (URL: https://stackvaults-hls.xcdnpro.com/d7346eda-5a72-4222-9ab7-4d7360cb7874/hls/as+18519ca3-5416-4693-b2bb-2617f18b71c1/index.m3u8) em /content/temp_recordings/NeilCage66_20250605_010558_temp.mp4
#
# 🎬 Iniciando gravação de: SchagenNH (URL: https://stackvaults-hls.xcdnpro.com/0ee695cb-1a9a-4e15-87e4-79c0509805bc/hls/as+0a18e4ad-c65a-4945-98d6-acb08bbd7e1d/index.m3u8) em /content/temp_recordings/SchagenNH_20250605_010558_temp.mp4
#
# 🎬 Iniciando gravação de: weedluv420 (URL: https://stackvaults-hls.xcdnpro.com/ac033bd1-bc13-4d38-b0c7-63fd22695972/hls/as+d18c7874-ede5-4a4e-9856-6dc9d03f4c37/index.m3u8) em /content/temp_recordings/weedluv420_20250605_010558_temp.mp4
# 🎬 Iniciando gravação de: EDuardoBranco (URL: https://stackvaults-hls.xcdnpro.com/ff7e569f-f7f8-4ef8-b56d-4cec556fc516/hls/as+7cc701ef-7748-4bec-86e7-f99a5a6b8e91/index.m3u8) em /content/temp_recordings/EDuardoBranco_20250605_010558_temp.mp4
#
# 🎬 Iniciando gravação de: toshi603 (URL: https://stackvaults-hls.xcdnpro.com/28aac0c1-771e-4474-8b8b-352a74c98e99/hls/as+501489a3-7263-4ccc-9c85-78556400ef1f/index.m3u8) em /content/temp_recordings/toshi603_20250605_010558_temp.mp4
#
#
# 🎬 Iniciando gravação de: aqa192 (URL: https://cam4-hls.xcdnpro.com/299/cam4-origin-live/aqa192-299-d16f5194-cfd0-4fd3-9813-6a7318115fbb_aac/playlist.m3u8) em /content/temp_recordings/aqa192_20250605_010558_temp.mp4
#
#
# 🎬 Iniciando gravação de: VNA027 (URL: https://stackvaults-hls.xcdnpro.com/629815e5-8301-491f-a9d0-51945fe351ee/hls/as+30ed722f-cf59-44de-9341-1593ccff7a21/index.m3u8) em /content/temp_recordings/VNA027_20250605_010558_temp.mp4
# 🎬 Iniciando gravação de: LoiroFortal085 (URL: https://cam4-hls.xcdnpro.com/319/cam4-origin-live/LoiroFortal085-319-0676e8b2-6ed2-4f02-9e00-f8a2e1522690_aac/playlist.m3u8) em /content/temp_recordings/LoiroFortal085_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: Caballerozodi (URL: https://cam4-hls.xcdnpro.com/319/cam4-origin-live/Caballerozodi-319-07aa8b34-9ea3-416b-91f6-4da2494b7e51_aac/playlist.m3u8) em /content/temp_recordings/Caballerozodi_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: MaxBenetti (URL: https://cam4-hls.xcdnpro.com/320/cam4-origin-live/MaxBenetti-320-508caccc-9bae-4519-b25f-5e6db3a895c8_aac/playlist.m3u8) em /content/temp_recordings/MaxBenetti_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: Angelgarcia_2 (URL: https://cam4-hls.xcdnpro.com/317/cam4-origin-live/Angelgarcia_2-317-02d46915-f333-49c6-8974-644e9e043412_aac/playlist.m3u8) em /content/temp_recordings/Angelgarcia_2_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: br1974fun (URL: https://stackvaults-hls.xcdnpro.com/e1bbd339-614d-443f-88eb-192c2ff4cb23/hls/as+f19b54eb-5836-4d47-8770-1af9972912cf/index.m3u8) em /content/temp_recordings/br1974fun_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: IanandJoseph (URL: https://cam4-hls.xcdnpro.com/319/cam4-origin-live/IanandJoseph-319-d9e0b257-dec8-40ad-af15-79ee6c6f7407_aac/playlist.m3u8) em /content/temp_recordings/IanandJoseph_20250605_010559_temp.mp4
# 🎬 Iniciando gravação de: JacksonOlsenn (URL: https://cam4-hls.xcdnpro.com/316/cam4-origin-live/JacksonOlsenn-316-1777e3d3-487e-486b-ac9e-702c8ec0af6c_aac/playlist.m3u8) em /content/temp_recordings/JacksonOlsenn_20250605_010559_temp.mp4
#
#
# 🎬 Iniciando gravação de: Paulhot18 (URL: https://cam4-hls.xcdnpro.com/320/cam4-origin-live/Paulhot18-320-3d85b292-be25-4f75-b409-b6b08b7fae80_aac/playlist.m3u8) em /content/temp_recordings/Paulhot18_20250605_010559_temp.mp4
# 🎬 Iniciando gravação de: Hotdickyxxx (URL: https://stackvaults-hls.xcdnpro.com/501017d5-03cd-4211-90f5-f7d9e74ebdfd/hls/as+3cd406de-a1f7-4620-86bc-eea72693d2e1/index.m3u8) em /content/temp_recordings/Hotdickyxxx_20250605_010559_temp.mp4
#
#
# 🎬 Iniciando gravação de: classied3 (URL: https://cam4-hls.xcdnpro.com/316/cam4-origin-live/classied3-316-1c9347a9-765d-4657-9eac-dfaa391b432f_aac/playlist.m3u8) em /content/temp_recordings/classied3_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: Slendt94 (URL: https://cam4-hls.xcdnpro.com/320/cam4-origin-live/Slendt94-320-1ed2a532-b423-4ccf-a560-3d34d2975a3d_aac/playlist.m3u8) em /content/temp_recordings/Slendt94_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: Alexpiers (URL: https://cam4-hls.xcdnpro.com/318/cam4-origin-live/Alexpiers-318-2e0a3b1e-fbd6-4005-a44f-a81d8bc8b4a1_aac/playlist.m3u8) em /content/temp_recordings/Alexpiers_20250605_010559_temp.mp4
#
# 🎬 Iniciando gravação de: brunootz (URL: https://stackvaults-hls.xcdnpro.com/cc0e9f41-5b4b-4f48-a77c-d9117cedf561/hls/as+16779247-41f8-4938-a518-90b05995bfee/index.m3u8) em /content/temp_recordings/brunootz_20250605_010600_temp.mp4
# ⚠️ Stream offline ou não disponível para classied3 (status 403)
# ⏱️ [LoiroFortal085] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m3s — 📊 0.7% concluído
# ❌ FFmpeg falhou para LoiroFortal085. Código de saída: 1
# ⏱️ [Clausribeiro] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Jt14] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Johnklleyn] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [EDuardoBranco] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [classied3] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m3s — 📊 0.7% concluído
# ❌ FFmpeg falhou para classied3. Código de saída: 1
# ⏱️ [brunootz] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m3s — 📊 0.7% concluído
# ❌ FFmpeg falhou para brunootz. Código de saída: 1
# ⏱️ [SchagenNH] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [toshi603] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [weedluv420] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [NeilCage66] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [camcouple27] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Caballerozodi] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [aqa192] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m5s — 📊 1.2% concluído
# ❌ FFmpeg falhou para aqa192. Código de saída: 1
# ⏱️ [NicoDavis] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [VNA027] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Paulhot18] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [br1974fun] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Hotdickyxxx] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [MaxBenetti] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [JacksonOlsenn] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [IanandJoseph] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Alexpiers] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Slendt94] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Angelgarcia_2] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Caballerozodi] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m52s — 📊 12.4% concluído
# ✅ Duração real do arquivo gravado: 14s (ffprobe)
# ⏩ Duração gravada (14s) menor que o mínimo (300s). Arquivo descartado.
# ⏱️ [br1974fun] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [NeilCage66] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [NicoDavis] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m1s — 📊 14.5% concluído
# ⏱️ [EDuardoBranco] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m2s — 📊 14.8% concluído
# ⏱️ [Alexpiers] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [Johnklleyn] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [Clausribeiro] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [SchagenNH] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [Jt14] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [IanandJoseph] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [weedluv420] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [JacksonOlsenn] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [Slendt94] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [Hotdickyxxx] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m — 📊 14.3% concluído
# ⏱️ [Angelgarcia_2] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m1s — 📊 14.5% concluído
# ⏱️ [camcouple27] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m4s — 📊 15.2% concluído
# ⏱️ [VNA027] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m2s — 📊 14.8% concluído
# ⏱️ [MaxBenetti] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m1s — 📊 14.5% concluído
# ⏱️ [toshi603] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m2s — 📊 14.8% concluído
# ⏱️ [Paulhot18] Gravados: 1 min | Restantes: 6 min | Tempo total: 1m8s — 📊 16.2% concluído
# ✅ Duração real do arquivo gravado: 33s (ffprobe)
# ⏩ Duração gravada (33s) menor que o mínimo (300s). Arquivo descartado.
# ⏱️ [br1974fun] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [EDuardoBranco] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [NicoDavis] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [NeilCage66] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m4s — 📊 29.5% concluído
# ⏱️ [Johnklleyn] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [JacksonOlsenn] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [toshi603] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [MaxBenetti] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m1s — 📊 28.8% concluído
# ⏱️ [camcouple27] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [Clausribeiro] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [IanandJoseph] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [SchagenNH] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [Alexpiers] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [VNA027] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [Angelgarcia_2] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [Jt14] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m1s — 📊 28.8% concluído
# ⏱️ [Slendt94] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [Hotdickyxxx] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m — 📊 28.6% concluído
# ⏱️ [weedluv420] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m2s — 📊 29.0% concluído
# ⏱️ [weedluv420] Gravados: 2 min | Restantes: 5 min | Tempo total: 2m52s — 📊 41.0% concluído
# ✅ Duração real do arquivo gravado: 170s (ffprobe)
# ⏩ Duração gravada (170s) menor que o mínimo (300s). Arquivo descartado.
# ⏱️ [NeilCage66] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [NicoDavis] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [SchagenNH] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [Johnklleyn] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [EDuardoBranco] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m4s — 📊 43.8% concluído
# ⏱️ [Clausribeiro] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [IanandJoseph] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [JacksonOlsenn] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [camcouple27] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m2s — 📊 43.3% concluído
# ⏱️ [toshi603] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [Alexpiers] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [Angelgarcia_2] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m1s — 📊 43.1% concluído
# ⏱️ [Slendt94] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [Jt14] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m1s — 📊 43.1% concluído
# ⏱️ [VNA027] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [Hotdickyxxx] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m — 📊 42.9% concluído
# ⏱️ [MaxBenetti] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m1s — 📊 43.1% concluído
# ⏱️ [br1974fun] Gravados: 3 min | Restantes: 4 min | Tempo total: 3m6s — 📊 44.3% concluído
# ⏱️ [NicoDavis] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [NeilCage66] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [Alexpiers] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [Johnklleyn] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [MaxBenetti] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [camcouple27] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [JacksonOlsenn] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído⏱️ [EDuardoBranco] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m2s — 📊 57.6% concluído
#
# ⏱️ [IanandJoseph] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [Jt14] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m3s — 📊 57.9% concluído
# ⏱️ [br1974fun] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [Clausribeiro] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [Angelgarcia_2] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [SchagenNH] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [Slendt94] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [VNA027] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [toshi603] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m2s — 📊 57.6% concluído
# ⏱️ [Hotdickyxxx] Gravados: 4 min | Restantes: 3 min | Tempo total: 4m — 📊 57.1% concluído
# ⏱️ [NeilCage66] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m2s — 📊 71.9% concluído
# ⏱️ [EDuardoBranco] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [Jt14] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [br1974fun] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [Alexpiers] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [JacksonOlsenn] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [Johnklleyn] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [Angelgarcia_2] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [NicoDavis] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m1s — 📊 71.7% concluído
# ⏱️ [IanandJoseph] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [Clausribeiro] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [camcouple27] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m2s — 📊 71.9% concluído
# ⏱️ [SchagenNH] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [VNA027] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [Hotdickyxxx] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m — 📊 71.4% concluído
# ⏱️ [MaxBenetti] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m1s — 📊 71.7% concluído
# ⏱️ [toshi603] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m2s — 📊 71.9% concluído
# ⏱️ [Slendt94] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m2s — 📊 71.9% concluído
# ⏱️ [Johnklleyn] Gravados: 5 min | Restantes: 2 min | Tempo total: 5m55s — 📊 84.5% concluído
# ✅ Duração real do arquivo gravado: 316s (ffprobe)
# ✅ Arquivo renomeado para: Johnklleyn_05-06-2025_01-05_5m16s.mp4
# ⬆️ Upload de: Johnklleyn_05-06-2025_01-05_5m16s.mp4 para Abyss.to...
# ⏱️ [NicoDavis] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [Alexpiers] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [NeilCage66] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m2s — 📊 86.2% concluído
# ⏱️ [camcouple27] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m2s — 📊 86.2% concluído
# ⏱️ [Clausribeiro] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [JacksonOlsenn] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [br1974fun] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [IanandJoseph] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m2s — 📊 86.2% concluído
# ⏱️ [SchagenNH] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [Angelgarcia_2] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [EDuardoBranco] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m4s — 📊 86.7% concluído
# ⏱️ [MaxBenetti] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [VNA027] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [Slendt94] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m2s — 📊 86.2% concluído
# ⏱️ [Hotdickyxxx] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m — 📊 85.7% concluído
# ⏱️ [Jt14] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m3s — 📊 86.4% concluído
# ⏱️ [toshi603] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m2s — 📊 86.2% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/VXs2pKsW7s | SLUG: VXs2pKsW7s
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Johnklleyn/VXs2pKsW7s.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Johnklleyn/VXs2pKsW7s.jpg
# ✅ rec.json para Johnklleyn atualizado em /content/XCam/xcam-db/user/Johnklleyn/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Johnklleyn/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Johnklleyn_05-06-2025_01-05_5m16s.mp4
# ⏱️ [EDuardoBranco] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m49s — 📊 97.4% concluído
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: EDuardoBranco_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: EDuardoBranco_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [br1974fun] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m52s — 📊 98.1% concluído
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: br1974fun_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: br1974fun_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [NeilCage66] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m53s — 📊 98.3% concluído
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: NeilCage66_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: NeilCage66_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [camcouple27] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m56s — 📊 99.0% concluído
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: camcouple27_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: camcouple27_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [Angelgarcia_2] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m57s — 📊 99.3% concluído
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: Angelgarcia_2_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: Angelgarcia_2_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [Clausribeiro] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m58s — 📊 99.5% concluído
# ⏱️ [toshi603] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m58s — 📊 99.5% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/ohrqD9WRj | SLUG: ohrqD9WRj
# 🖼️ Poster movido para /content/XCam/xcam-db/user/EDuardoBranco/ohrqD9WRj.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/EDuardoBranco/ohrqD9WRj.jpg
# ✅ rec.json para EDuardoBranco atualizado em /content/XCam/xcam-db/user/EDuardoBranco/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/EDuardoBranco/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# ⏱️ [SchagenNH] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m59s — 📊 99.8% concluído
# ✅ Duração real do arquivo gravado: 420s (ffprobe)✅ Duração real do arquivo gravado: 420s (ffprobe)
#
# ✅ Arquivo renomeado para: Clausribeiro_05-06-2025_01-05_7m.mp4✅ Arquivo renomeado para: toshi603_05-06-2025_01-05_7m.mp4
# ⏱️ [NicoDavis] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m59s — 📊 99.8% concluído⬆️ Upload de: Clausribeiro_05-06-2025_01-05_7m.mp4 para Abyss.to...
#
# ⬆️ Upload de: toshi603_05-06-2025_01-05_7m.mp4 para Abyss.to...
#
# ⏱️ [VNA027] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m59s — 📊 99.8% concluído
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/EDuardoBranco_05-06-2025_01-05_7m.mp4
# ⏱️ [MaxBenetti] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m59s — 📊 99.8% concluído
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: SchagenNH_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: SchagenNH_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [Jt14] Gravados: 7 min | Restantes: 0 min | Tempo total: 7m — 📊 100.0% concluído
# 📤 Upload bem-sucedido. URL: https://short.icu/ZBR5bibar | SLUG: ZBR5bibar
# 🖼️ Poster movido para /content/XCam/xcam-db/user/br1974fun/ZBR5bibar.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/br1974fun/ZBR5bibar.jpg
# ✅ rec.json para br1974fun atualizado em /content/XCam/xcam-db/user/br1974fun/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/br1974fun/rec.json
# ⏱️ [IanandJoseph] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m59s — 📊 99.8% concluído🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
#
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: NicoDavis_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: NicoDavis_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [Alexpiers] Gravados: 6 min | Restantes: 1 min | Tempo total: 6m59s — 📊 99.8% concluído
# ⏱️ [Slendt94] Gravados: 7 min | Restantes: 0 min | Tempo total: 7m — 📊 100.0% concluído
# ⏱️ [JacksonOlsenn] Gravados: 7 min | Restantes: 0 min | Tempo total: 7m — 📊 100.0% concluído✅ Duração real do arquivo gravado: 420s (ffprobe)
#
# ✅ Arquivo renomeado para: VNA027_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: VNA027_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ⏱️ [Hotdickyxxx] Gravados: 7 min | Restantes: 0 min | Tempo total: 7m — 📊 100.0% concluído
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/br1974fun_05-06-2025_01-05_7m.mp4✅ Duração real do arquivo gravado: 420s (ffprobe)
#
# ✅ Arquivo renomeado para: MaxBenetti_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: MaxBenetti_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ✅ Duração real do arquivo gravado: 420s (ffprobe)✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: Jt14_05-06-2025_01-05_7m.mp4
#
# ⬆️ Upload de: Jt14_05-06-2025_01-05_7m.mp4 para Abyss.to...✅ Arquivo renomeado para: IanandJoseph_05-06-2025_01-05_7m.mp4
#
# ⬆️ Upload de: IanandJoseph_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Duração real do arquivo gravado: 420s (ffprobe)✅ Arquivo renomeado para: Hotdickyxxx_05-06-2025_01-05_7m.mp4
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
#
# ⬆️ Upload de: Hotdickyxxx_05-06-2025_01-05_7m.mp4 para Abyss.to...
# ✅ Arquivo renomeado para: Alexpiers_05-06-2025_01-05_7m.mp4✅ Arquivo renomeado para: JacksonOlsenn_05-06-2025_01-05_7m.mp4
#
# ⬆️ Upload de: Alexpiers_05-06-2025_01-05_7m.mp4 para Abyss.to...⬆️ Upload de: JacksonOlsenn_05-06-2025_01-05_7m.mp4 para Abyss.to...
#
# ✅ Duração real do arquivo gravado: 420s (ffprobe)
# ✅ Arquivo renomeado para: Slendt94_05-06-2025_01-05_7m.mp4
# ⬆️ Upload de: Slendt94_05-06-2025_01-05_7m.mp4 para Abyss.to...
# 📤 Upload bem-sucedido. URL: https://short.icu/udUFnHz8i | SLUG: udUFnHz8i
# 🖼️ Poster movido para /content/XCam/xcam-db/user/camcouple27/udUFnHz8i.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/camcouple27/udUFnHz8i.jpg
# ✅ rec.json para camcouple27 atualizado em /content/XCam/xcam-db/user/camcouple27/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/camcouple27/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/camcouple27_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/U5Ypg15ix | SLUG: U5Ypg15ix
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Angelgarcia_2/U5Ypg15ix.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Angelgarcia_2/U5Ypg15ix.jpg
# ✅ rec.json para Angelgarcia_2 atualizado em /content/XCam/xcam-db/user/Angelgarcia_2/rec.json
# 📤 Upload bem-sucedido. URL: https://short.icu/_vv5vh26F | SLUG: _vv5vh26F
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Clausribeiro/_vv5vh26F.jpg
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Angelgarcia_2/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Clausribeiro/_vv5vh26F.jpg
# ✅ rec.json para Clausribeiro atualizado em /content/XCam/xcam-db/user/Clausribeiro/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Clausribeiro/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Clausribeiro_05-06-2025_01-05_7m.mp4
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Angelgarcia_2_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/O1Q4CwmFd | SLUG: O1Q4CwmFd
# 🖼️ Poster movido para /content/XCam/xcam-db/user/SchagenNH/O1Q4CwmFd.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/SchagenNH/O1Q4CwmFd.jpg
# ✅ rec.json para SchagenNH atualizado em /content/XCam/xcam-db/user/SchagenNH/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/SchagenNH/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/SchagenNH_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/BuRXYDFN9 | SLUG: BuRXYDFN9
# 🖼️ Poster movido para /content/XCam/xcam-db/user/NeilCage66/BuRXYDFN9.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/NeilCage66/BuRXYDFN9.jpg
# ✅ rec.json para NeilCage66 atualizado em /content/XCam/xcam-db/user/NeilCage66/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/NeilCage66/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/NeilCage66_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/OOPGrMX2o | SLUG: OOPGrMX2o
# 🖼️ Poster movido para /content/XCam/xcam-db/user/toshi603/OOPGrMX2o.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/toshi603/OOPGrMX2o.jpg
# ✅ rec.json para toshi603 atualizado em /content/XCam/xcam-db/user/toshi603/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/toshi603/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/toshi603_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/o-ZmSdSuZ | SLUG: o-ZmSdSuZ
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Jt14/o-ZmSdSuZ.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Jt14/o-ZmSdSuZ.jpg
# ✅ rec.json para Jt14 atualizado em /content/XCam/xcam-db/user/Jt14/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Jt14/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Jt14_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/cc20C-0EC | SLUG: cc20C-0EC
# 🖼️ Poster movido para /content/XCam/xcam-db/user/VNA027/cc20C-0EC.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/VNA027/cc20C-0EC.jpg
# ✅ rec.json para VNA027 atualizado em /content/XCam/xcam-db/user/VNA027/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/VNA027/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/VNA027_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/_ER3MIim_ | SLUG: _ER3MIim_
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Slendt94/_ER3MIim_.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Slendt94/_ER3MIim_.jpg
# ✅ rec.json para Slendt94 atualizado em /content/XCam/xcam-db/user/Slendt94/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Slendt94/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 📤 Upload bem-sucedido. URL: https://short.icu/ze8IVVxzT | SLUG: ze8IVVxzT
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Hotdickyxxx/ze8IVVxzT.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Hotdickyxxx/ze8IVVxzT.jpg
# ✅ rec.json para Hotdickyxxx atualizado em /content/XCam/xcam-db/user/Hotdickyxxx/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Hotdickyxxx/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Slendt94_05-06-2025_01-05_7m.mp4
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Hotdickyxxx_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/conVTvKbB | SLUG: conVTvKbB
# 🖼️ Poster movido para /content/XCam/xcam-db/user/IanandJoseph/conVTvKbB.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/IanandJoseph/conVTvKbB.jpg
# ✅ rec.json para IanandJoseph atualizado em /content/XCam/xcam-db/user/IanandJoseph/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/IanandJoseph/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/IanandJoseph_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/AL9uibW5A | SLUG: AL9uibW5A
# 🖼️ Poster movido para /content/XCam/xcam-db/user/Alexpiers/AL9uibW5A.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Alexpiers/AL9uibW5A.jpg
# ✅ rec.json para Alexpiers atualizado em /content/XCam/xcam-db/user/Alexpiers/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/Alexpiers/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/Alexpiers_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/y8Lr57Pw3 | SLUG: y8Lr57Pw3
# 🖼️ Poster movido para /content/XCam/xcam-db/user/MaxBenetti/y8Lr57Pw3.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/MaxBenetti/y8Lr57Pw3.jpg
# ✅ rec.json para MaxBenetti atualizado em /content/XCam/xcam-db/user/MaxBenetti/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/MaxBenetti/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/MaxBenetti_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/KijjejFsP | SLUG: KijjejFsP
# 🖼️ Poster movido para /content/XCam/xcam-db/user/JacksonOlsenn/KijjejFsP.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/JacksonOlsenn/KijjejFsP.jpg
# ✅ rec.json para JacksonOlsenn atualizado em /content/XCam/xcam-db/user/JacksonOlsenn/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/JacksonOlsenn/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/JacksonOlsenn_05-06-2025_01-05_7m.mp4
# 📤 Upload bem-sucedido. URL: https://short.icu/ZnRtXkJl0 | SLUG: ZnRtXkJl0
# 🖼️ Poster movido para /content/XCam/xcam-db/user/NicoDavis/ZnRtXkJl0.jpg
# 🗂️ Poster também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/NicoDavis/ZnRtXkJl0.jpg
# ✅ rec.json para NicoDavis atualizado em /content/XCam/xcam-db/user/NicoDavis/rec.json
# 🗂️ rec.json também salvo no Drive: /content/drive/MyDrive/XCam.Drive/XCam/xcam-db/user/NicoDavis/rec.json
# 🚀 Commit/push automático IMEDIATO (threshold=0): 2 arquivos
# 🗑️ Arquivo de vídeo removido do Colab: /content/temp_recordings/NicoDavis_05-06-2025_01-05_7m.mp4
#
# 🏁 Todas as gravações da página 1 concluídas.
#
# Aguardando 5 segundos antes de processar a próxima página...
#
# 📄 Processando página 2
#
# 🌐 Acessando API principal: https://api.xcam.gay/?limit=25&page=2
# ✅ 0 transmissões com URL na API principal (página 2).
# 🔁 Buscando liveInfo para 25 streams sem URL na API principal...
# 🎬 Gerando poster com ffmpeg para MorenoCarente no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/MorenoCarente_poster_ffmpeg.jpg
# ⚠️ Stream offline ou não disponível para Caballerozodi (status 403)
# 🎬 Gerando poster com ffmpeg para artcruz no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/artcruz_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para fervalle1975 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/fervalle1975_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para ApollonFit_X no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/ApollonFit_X_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Hotdickyxxx no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Hotdickyxxx_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para 22cmBigCockMilk no segundo 7...
# ⏰ Tempo excedido ao tentar gerar poster para 22cmBigCockMilk via ffmpeg.
# 🎬 Gerando poster com ffmpeg para Alexpiers no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Alexpiers_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para 3numeroperfet no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/3numeroperfet_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para HerculesMty no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/HerculesMty_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para robert1774 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/robert1774_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para _MrPrecum_ no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/_MrPrecum__poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Jam3sGh0st no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Jam3sGh0st_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para lovepassion2023 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/lovepassion2023_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Mathewwjm no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Mathewwjm_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para LuisRico30 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/LuisRico30_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para karlito27 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/karlito27_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Macacovuelve no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Macacovuelve_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para heathen2505 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/heathen2505_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Dziignr no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Dziignr_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para scrocchia84 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/scrocchia84_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para physicssexpert no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/physicssexpert_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Alphapimmelchen no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Alphapimmelchen_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Jezus1992 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Jezus1992_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para HANMUSCLEHOT no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/HANMUSCLEHOT_poster_ffmpeg.jpg
# 🔎 Página 2: 25 streams válidas após fallback (respeitando limit=25).
# 🚀 Gravando 25 streams em paralelo...
#
# 🎬 Iniciando gravação de: MorenoCarente (URL: https://stackvaults-hls.xcdnpro.com/6909630a-29e5-4cb8-aed0-edc152b1204f/hls/as+d2f1b4ee-29d8-4b8f-b1dc-7930200d1d7a/index.m3u8) em /content/temp_recordings/MorenoCarente_20250605_011528_temp.mp4
# 🎬 Iniciando gravação de: Caballerozodi (URL: https://jf22-r18.cam4.com:443/cam4-edge-live/Caballerozodi-317-601a0e48-1084-4c37-b0e6-9e915417d066_aac/playlist.m3u8) em /content/temp_recordings/Caballerozodi_20250605_011528_temp.mp4
#
#
# 🎬 Iniciando gravação de: artcruz (URL: https://stackvaults-hls.xcdnpro.com/a85d25f9-f838-4858-8f6a-2e5f7095a7cf/hls/as+022e4953-6dc6-403d-9ed1-7fabf271f305/index.m3u8) em /content/temp_recordings/artcruz_20250605_011528_temp.mp4
#
# 🎬 Iniciando gravação de: fervalle1975 (URL: https://stackvaults-hls.xcdnpro.com/4f88e572-85e3-4f5e-a3a9-83f77b27f878/hls/as+dd9f46b1-86f1-412e-8f2c-32f0bda93bac/index.m3u8) em /content/temp_recordings/fervalle1975_20250605_011528_temp.mp4
#
# 🎬 Iniciando gravação de: ApollonFit_X (URL: https://stackvaults-hls.xcdnpro.com/1a89a3a6-bb18-42c0-9da8-8c446c4814c9/hls/as+59f56618-51b1-49d8-b2e7-6472afcd56af/index.m3u8) em /content/temp_recordings/ApollonFit_X_20250605_011528_temp.mp4
#
# 🎬 Iniciando gravação de: Hotdickyxxx (URL: https://stackvaults-hls.xcdnpro.com/501017d5-03cd-4211-90f5-f7d9e74ebdfd/hls/as+3cd406de-a1f7-4620-86bc-eea72693d2e1/index.m3u8) em /content/temp_recordings/Hotdickyxxx_20250605_011528_temp.mp4
#
# 🎬 Iniciando gravação de: 22cmBigCockMilk (URL: https://cam4-hls.xcdnpro.com/299/cam4-origin-live/22cmBigCockMilk-299-dfa33cc8-63d4-4e69-bd5d-6272b13a94f0_aac/playlist.m3u8) em /content/temp_recordings/22cmBigCockMilk_20250605_011528_temp.mp4
# 🎬 Iniciando gravação de: Alexpiers (URL: https://cam4-hls.xcdnpro.com/318/cam4-origin-live/Alexpiers-318-2e0a3b1e-fbd6-4005-a44f-a81d8bc8b4a1_aac/playlist.m3u8) em /content/temp_recordings/Alexpiers_20250605_011528_temp.mp4
# 🎬 Iniciando gravação de: 3numeroperfet (URL: https://stackvaults-hls.xcdnpro.com/6c63670b-3a3a-4c93-ae50-7895613fc74c/hls/as+a34a4495-3371-4366-956e-dec2fd26e5cb/index.m3u8) em /content/temp_recordings/3numeroperfet_20250605_011528_temp.mp4
#
#
#
# 🎬 Iniciando gravação de: HerculesMty (URL: https://stackvaults-hls.xcdnpro.com/b8fb3736-2252-4ecc-ae15-74d3fec24e63/hls/as+dca5b7a7-8560-4263-ace5-c0dce6a9dfc9/index.m3u8) em /content/temp_recordings/HerculesMty_20250605_011528_temp.mp4🎬 Gerando poster com ffmpeg para 22cmBigCockMilk no segundo 7...
#
# 🎬 Iniciando gravação de: robert1774 (URL: https://stackvaults-hls.xcdnpro.com/f09dd3e2-3a08-4051-821d-d4566b694c41/hls/as+a5f74238-3f8e-47c1-b0ee-ebad9472d684/index.m3u8) em /content/temp_recordings/robert1774_20250605_011528_temp.mp4
#
#
# 🎬 Iniciando gravação de: _MrPrecum_ (URL: https://cam4-hls.xcdnpro.com/296/cam4-origin-live/_MrPrecum_-296-6eab66fc-cf83-4a00-90ac-abb0845f3ea8_aac/playlist.m3u8) em /content/temp_recordings/_MrPrecum__20250605_011528_temp.mp4
#
# ...
# [hls @ 0x59aa39770040] Failed to reload playlist 0
# [hls @ 0x59aa39770040] Opening 'https://stackvaults-hls.xcdnpro.com/6807eaf2-38ff-4c44-9013-ffaaa06bfe97/hls/as+ddce1b4a-1a1d-423b-a91e-04f6d90a2eae/0_2/index.m3u8?tkn=0' for reading
# [https @ 0x59aa3a48cd80] HTTP error 404 Not Found
# [hls @ 0x59aa39770040] Failed to reload playlist 0
# [hls @ 0x59aa39770040] Opening 'https://stackvaults-hls.xcdnpro.com/6807eaf2-38ff-4c44-9013-ffaaa06bfe97/hls/as+ddce1b4a-1a1d-423b-a91e-04f6d90a2eae/0_2/index.m3u8?tkn=0' for reading
# [https @ 0x59aa3a43fe00] HTTP error 404 Not Found
# [hls @ 0x59aa39770040] Failed to reload playlist 0
# [hls @ 0x59aa39770040] Opening 'https://stackvaults-hls.xcdnpro.com/6807eaf2-38ff-4c44-9013-ffaaa06bfe97/hls/as+ddce1b4a-1a1d-423b-a91e-04f6d90a2eae/0_2/index.m3u8?tkn=0' for reading
# [https @ 0x59aa39ceed00] HTTP error 404 Not Found
# [hls @ 0x59aa39770040] Failed to reload playlist 0
# [image2 @ 0x59aa3a675dc0] Frame rate very high for a muxer not efficiently supporting it.
# Please consider specifying a lower framerate, a different muxer or -vsync 2
# Output #0, image2, to '/content/Dey_jhosuaxxx_poster_ffmpeg.jpg':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc), 960x540, q=2-31, 200 kb/s, 90k fps, 90k tbn
#     Metadata:
#       variant_bitrate : 1568408
#       encoder         : Lavc58.134.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=    0 fps=0.0 q=0.0 Lsize=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# video:0kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# Output file is empty, nothing was encoded (check -ss / -t / -frames parameters if used)
#
# 🎬 Gerando poster com ffmpeg para Ryan_the_man no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Ryan_the_man_poster_ffmpeg.jpg
# ❌ Erro ao buscar liveInfo para ArturCarter: 500 Server Error: Internal Server Error for url: https://api.xcam.gay/user/ArturCarter/liveInfo
# 🎬 Gerando poster com ffmpeg para Darind_bag no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Darind_bag_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para die951753hot no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/die951753hot_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para PatrickTed no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/PatrickTed_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para andrew_00 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/andrew_00_poster_ffmpeg.jpg
# ❌ Erro ao buscar liveInfo para nathan_smithh: 500 Server Error: Internal Server Error for url: https://api.xcam.gay/user/nathan_smithh/liveInfo
# ❌ Erro ao buscar liveInfo para Damian_Kiing: 500 Server Error: Internal Server Error for url: https://api.xcam.gay/user/Damian_Kiing/liveInfo
# 🎬 Gerando poster com ffmpeg para dbudurb no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/dbudurb_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para gregory_hardxx no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/gregory_hardxx_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para newyearnewhole no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/newyearnewhole_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Samucamx no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Samucamx_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para publicslave4 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/publicslave4_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para biscoiteiro no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/biscoiteiro_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para sylraff no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/sylraff_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Kuki no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Kuki_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Danburythebeast no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Danburythebeast_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para davidroses666 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/davidroses666_poster_ffmpeg.jpg
# 🔎 Página 6: 22 streams válidas após fallback (respeitando limit=25).
# 🌐 Acessando API principal: https://api.xcam.gay/?limit=25&page=7
# ✅ 0 transmissões com URL na API principal (página 7).
# 🔁 Buscando liveInfo para 25 streams sem URL na API principal...
# 🎬 Gerando poster com ffmpeg para Xicodenia no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Xicodenia_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Hellboy888 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Hellboy888_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Akcay274 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Akcay274_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para jharol_cardona no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/jharol_cardona_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Neerajnk no segundo 7...
# ⏰ Tempo excedido ao tentar gerar poster para Neerajnk via ffmpeg.
# 🎬 Gerando poster com ffmpeg para AndyyAndFrank no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/AndyyAndFrank_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para martin_killer no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/martin_killer_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Alastis108 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Alastis108_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para aldoncehot no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/aldoncehot_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Kervs__ no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Kervs___poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para the_dog_lian no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/the_dog_lian_poster_ffmpeg.jpg
# ❌ Erro ao buscar liveInfo para kael_art: 500 Server Error: Internal Server Error for url: https://api.xcam.gay/user/kael_art/liveInfo
# 🎬 Gerando poster com ffmpeg para joker_harley890 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/joker_harley890_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para naughtyd2 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/naughtyd2_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para andrew_00 no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/andrew_00_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para leo_storm no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/leo_storm_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para dominick_evans no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/dominick_evans_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para LuigiMorgan no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/LuigiMorgan_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para gregory_hardxx no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/gregory_hardxx_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Lukarizzo_x no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Lukarizzo_x_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para Samucamx no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Samucamx_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para gorka19hot no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/gorka19hot_poster_ffmpeg.jpg
# ⚠️ liveInfo de publicslave4 não retornou cdnURL/edgeURL (usuário possivelmente offline).
# 🎬 Gerando poster com ffmpeg para Gorditohotsex no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/Gorditohotsex_poster_ffmpeg.jpg
# 🎬 Gerando poster com ffmpeg para ethanhairy no segundo 7...
# 🖼️ Poster gerado via ffmpeg: /content/ethanhairy_poster_ffmpeg.jpg
# 🔎 Página 7: 23 streams válidas após fallback (respeitando limit=25).
# 🚀 Gravando 25 streams em paralelo...
#
# 🎬 Iniciando gravação de: onlymechris1 (URL: https://cam4-hls.xcdnpro.com/297/cam4-origin-live/onlymechris1-297-0870cccf-2cf7-4d6d-8c91-056854317ef6_aac/playlist.m3u8) em /content/temp_recordings/onlymechris1_20250605_015803_temp.mp4
#
# 🎬 Iniciando gravação de: drakehott_ (URL: https://stackvaults-hls.xcdnpro.com/8c1f1af4-3698-4815-a9e9-4c282eee0c34/hls/as+86309b80-e241-419c-98e3-58dd4fb5a0fa/index.m3u8) em /content/temp_recordings/drakehott__20250605_015803_temp.mp4
# 🎬 Iniciando gravação de: Boss_Bibtch (URL: https://stackvaults-hls.xcdnpro.com/437b283d-7ed9-407b-9d26-023052cff6b9/hls/as+411ddcff-e35f-4968-99a0-2b655bdeb7aa/index.m3u8) em /content/temp_recordings/Boss_Bibtch_20250605_015803_temp.mp4
#
# ⚠️ Stream offline ou não disponível para Boss_Bibtch (status 404)
#
# 🎬 Iniciando gravação de: KalvinVoy (URL: https://stackvaults-hls.xcdnpro.com/4d622cf0-707b-4160-873d-c561b9b52b66/hls/as+6f1d3f01-c8fc-48ba-8928-705e6b6c1575/index.m3u8) em /content/temp_recordings/KalvinVoy_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: Baan9 (URL: https://cam4-hls.xcdnpro.com/320/cam4-origin-live/Baan9-320-a299656f-e856-40ca-b386-4daeccda7425_aac/playlist.m3u8) em /content/temp_recordings/Baan9_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: AndreaCarli18 (URL: https://stackvaults-hls.xcdnpro.com/9764de8f-53c5-4f10-8214-137d11cf5f3e/hls/as+e7cd8ea5-a11b-45ce-a741-9dd887a716f4/index.m3u8) em /content/temp_recordings/AndreaCarli18_20250605_015804_temp.mp4
# 🎬 Iniciando gravação de: Dey_jhosuaxxx (URL: https://stackvaults-hls.xcdnpro.com/6807eaf2-38ff-4c44-9013-ffaaa06bfe97/hls/as+ddce1b4a-1a1d-423b-a91e-04f6d90a2eae/index.m3u8) em /content/temp_recordings/Dey_jhosuaxxx_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: Ryan_the_man (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/Ryan_the_man-321-db0b89c7-2399-4e7a-8a42-e739193a6af5_aac/playlist.m3u8) em /content/temp_recordings/Ryan_the_man_20250605_015804_temp.mp4
# 🎬 Iniciando gravação de: Darind_bag (URL: https://cam4-hls.xcdnpro.com/317/cam4-origin-live/Darind_bag-317-42065133-2070-4730-9b23-430c354d3137_aac/playlist.m3u8) em /content/temp_recordings/Darind_bag_20250605_015804_temp.mp4
#
#
#
# 🎬 Iniciando gravação de: die951753hot (URL: https://stackvaults-hls.xcdnpro.com/804d9874-d7d8-4454-9720-44b84ce2a3b5/hls/as+d7011cae-5156-451c-a36e-cbbadc1831e6/index.m3u8) em /content/temp_recordings/die951753hot_20250605_015804_temp.mp4
# ⚠️ Stream offline ou não disponível para Dey_jhosuaxxx (status 404)
# 🎬 Iniciando gravação de: PatrickTed (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/PatrickTed-321-62c27070-a308-422d-836c-ff5b8b651f16_aac/playlist.m3u8) em /content/temp_recordings/PatrickTed_20250605_015804_temp.mp4
#
#
# 🎬 Iniciando gravação de: andrew_00 (URL: https://cam4-hls.xcdnpro.com/296/cam4-origin-live/andrew_00-296-8655552d-fd17-4ac9-9732-ce0817f906ac_aac/playlist.m3u8) em /content/temp_recordings/andrew_00_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: dbudurb (URL: https://stackvaults-hls.xcdnpro.com/962ddfba-febe-45da-ba00-f2407935fd92/hls/as+653cfe18-096e-4ea4-9741-5795bab882d6/index.m3u8) em /content/temp_recordings/dbudurb_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: gregory_hardxx (URL: https://cam4-hls.xcdnpro.com/321/cam4-origin-live/gregory_hardxx-321-e4219be6-1572-4490-82a7-03dc7d188dbe_aac/playlist.m3u8) em /content/temp_recordings/gregory_hardxx_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: newyearnewhole (URL: https://stackvaults-hls.xcdnpro.com/93bd08a4-6b06-4c89-9f55-5a03f163d7cc/hls/as+2ae27851-02dc-4ee7-83e0-076bb024a800/index.m3u8) em /content/temp_recordings/newyearnewhole_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: publicslave4 (URL: https://stackvaults-hls.xcdnpro.com/ee42c100-b8e4-4a39-be2c-09adf60d86f0/hls/as+b4a4f357-0a54-4cc0-acda-90366c67234c/index.m3u8) em /content/temp_recordings/publicslave4_20250605_015804_temp.mp4
# 🎬 Iniciando gravação de: Samucamx (URL: https://stackvaults-hls.xcdnpro.com/0312c5b7-1c23-45f0-bb99-3a3069d86af1/hls/as+43628194-5280-4171-a52e-9a26ce84595b/index.m3u8) em /content/temp_recordings/Samucamx_20250605_015804_temp.mp4
#
#
# 🎬 Iniciando gravação de: biscoiteiro (URL: https://stackvaults-hls.xcdnpro.com/d0533e3f-d6b1-4dfa-810f-67bc2fb579ab/hls/as+827e2cf4-646b-47fa-987a-9154bdbe4fbb/index.m3u8) em /content/temp_recordings/biscoiteiro_20250605_015804_temp.mp4
#
# 🎬 Iniciando gravação de: sylraff (URL: https://stackvaults-hls.xcdnpro.com/5833919f-9521-4d76-8f58-868e3dae3da8/hls/as+2b9fa0b9-71d2-453f-a627-e05bf81e70c7/index.m3u8) em /content/temp_recordings/sylraff_20250605_015804_temp.mp4
# 🎬 Iniciando gravação de: Kuki (URL: https://stackvaults-hls.xcdnpro.com/8e33f18a-21f2-4d88-88be-3d5f2e7ffbbf/hls/as+e363e3e2-ff6e-4b9a-b3df-d933225ac828/index.m3u8) em /content/temp_recordings/Kuki_20250605_015804_temp.mp4
#
#
# 🎬 Iniciando gravação de: davidroses666 (URL: https://cam4-hls.xcdnpro.com/317/cam4-origin-live/davidroses666-317-48734e2f-9360-4ca0-95ca-ee2171376a49_aac/playlist.m3u8) em /content/temp_recordings/davidroses666_20250605_015805_temp.mp4
# 🎬 Iniciando gravação de: Danburythebeast (URL: https://stackvaults-hls.xcdnpro.com/f85d4541-fe66-4ac3-b2d7-89a06ca790c8/hls/as+68013f6d-d6bb-4a70-a66c-9cc2e75b0aa8/index.m3u8) em /content/temp_recordings/Danburythebeast_20250605_015804_temp.mp4
#
#
# 🎬 Iniciando gravação de: Xicodenia (URL: https://cam4-hls.xcdnpro.com/297/cam4-origin-live/Xicodenia-297-150a6d33-ee5e-493e-8cad-b25d746b9201_aac/playlist.m3u8) em /content/temp_recordings/Xicodenia_20250605_015805_temp.mp4
#
# 🎬 Iniciando gravação de: Hellboy888 (URL: https://stackvaults-hls.xcdnpro.com/01a7327c-e866-4c46-bebd-2b8d818f2937/hls/as+5bd45ce2-9c5e-4952-9f95-779ab863362e/index.m3u8) em /content/temp_recordings/Hellboy888_20250605_015805_temp.mp4
#
# 🎬 Iniciando gravação de: Akcay274 (URL: https://stackvaults-hls.xcdnpro.com/f4f6bff2-fd2e-45e0-8a4c-74ed687799b6/hls/as+68d6fc69-cc7b-4370-a549-2edbd812fe9a/index.m3u8) em /content/temp_recordings/Akcay274_20250605_015805_temp.mp4
# ⏱️ [Boss_Bibtch] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m3s — 📊 0.7% concluído
# ❌ FFmpeg falhou para Boss_Bibtch. Código de saída: 1
# ⏱️ [Dey_jhosuaxxx] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m2s — 📊 0.5% concluído
# ❌ FFmpeg falhou para Dey_jhosuaxxx. Código de saída: 1
# ⏱️ [publicslave4] Gravados: 0 min | Restantes: 7 min | Tempo total: 0m2s — 📊 0.5% concluído
# ❌ FFmpeg falhou para publicslave4. Código de saída: 1
# ⏱️ [onlymechris1] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [drakehott_] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [KalvinVoy] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Ryan_the_man] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [PatrickTed] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [AndreaCarli18] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [andrew_00] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [gregory_hardxx] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [biscoiteiro] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [newyearnewhole] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [die951753hot] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [sylraff] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Samucamx] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído⏱️ [Xicodenia] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Baan9] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Danburythebeast] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
#
# ⏱️ [Akcay274] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [davidroses666] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Darind_bag] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [dbudurb] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Kuki] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído
# ⏱️ [Hellboy888] Gravados: 0 min | Restantes: 7 min | Tempo total: 0s — 📊 0.0% concluído

# %%
# Célula extra: Commit final de pendências
def commit_final_pendencias():
    commit_buffer = getattr(upload_to_abyss_and_update_json, 'commit_buffer', [])
    if commit_buffer:
        print(f"🔔 Realizando commit/push final de {len(commit_buffer)} pendências...")
        git_commit_and_push(commit_buffer, commit_message="Commit final de pendências")
        commit_buffer.clear()
    else:
        print("✅ Sem pendências para commit final.")

# Execute isto ao final do processamento
# commit_final_pendencias()
