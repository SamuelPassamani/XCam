# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datetime import timedelta

def format_seconds(seconds):
    return str(timedelta(seconds=int(seconds)))

def log_progress(username, elapsed_seconds):
    percent = min((elapsed_seconds / 5400) * 100, 100)
    tempo = format_seconds(elapsed_seconds)
    print(f"⏱️ [{username}] Tempo gravado: {tempo} — 📊 {percent:.1f}% concluído")

# %%
# ✅ Instalação do ffmpeg
# !apt-get update -y
# !apt-get install -y ffmpeg

# 📁 Diretório onde os arquivos serão salvos
output_folder = "/content/drive/MyDrive/XCam.Drive/Gravações"

import os
import requests
import multiprocessing
from datetime import datetime
from time import sleep

# 📥 Etapa 1 – Buscar os 5 broadcasts da API XCam
def get_broadcasts(limit=5):
    api_url = f"http://api.xcam.gay/?limit={limit}"
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        broadcasts = data.get("broadcasts", {}).get("items", [])
        result = []
        for item in broadcasts:
            preview = item.get("preview") or {}
            src = preview.get("src")
            username = item.get("username", "desconhecido")
            if src:
                result.append({"username": username, "src": src})
        return result
    else:
        raise Exception(f"Erro ao acessar API: {response.status_code}")

# 🎥 Etapa 2 – Gravar stream com ffmpeg por 1h30m
def gravar_stream(username, m3u8_url):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"{username}_{timestamp}.mp4"
# ✅ Instalação do ffmpeg
# !apt-get update -y
# !apt-get install -y ffmpeg

# 📁 Diretório onde os arquivos serão salvos
output_folder = "/content/drive/MyDrive/XCam.Drive/Gravações"

import os
import requests
import multiprocessing
from datetime import datetime
from time import sleep

# 📥 Etapa 1 – Buscar os 5 broadcasts da API XCam
def get_broadcasts(limit=5):
    api_url = f"http://api.xcam.gay/?limit={limit}"
    response = requests.get(api_url)
    if response.status_code == 200:
        data = response.json()
        broadcasts = data.get("broadcasts", {}).get("items", [])
        result = []
        for item in broadcasts:
            preview = item.get("preview") or {}
            src = preview.get("src")
            username = item.get("username", "desconhecido")
            if src:
                result.append({"username": username, "src": src})
        return result
    else:
        raise Exception(f"Erro ao acessar API: {response.status_code}")

# 🎥 Etapa 2 – Gravar stream com ffmpeg por 1h30m
def gravar_stream(username, m3u8_url):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"{username}_{timestamp}.mp4"
    filepath = os.path.join(output_folder, filename)

    print(f"🎬 Iniciando gravação de: {username}")
    command = f"ffmpeg -i {m3u8_url} -t 01:30:00 -c copy -y \"{filepath}\""
    os.system(command)

    print(f"✅ Gravação finalizada: {filename}")
    upload_to_abyss(filepath)

# ☁️ Etapa 3 – Upload para Abyss.to
def upload_to_abyss(filepath):
    url = 'http://up.hydrax.net/0128263f78f0b426d617bb61c2a8ff43'
    file_name = os.path.basename(filepath)
    file_type = 'video/mp4'

    with open(filepath, 'rb') as f:
        files = { 'file': (file_name, f, file_type) }
        response = requests.post(url, files=files)
        print(f"📤 Upload realizado: {response.text}")

# 🚀 Etapa 4 – Executar tudo em paralelo
if __name__ == '__main__':
    streams = get_broadcasts(limit=5)
    jobs = []

    for stream in streams:
        username = stream["username"]
        m3u8_url = stream["src"]
        p = multiprocessing.Process(target=gravar_stream, args=(username, m3u8_url))
        jobs.append(p)
        p.start()

    for job in jobs:
        job.join()

    print("🏁 Todas as gravações foram concluídas.")

    print(f"✅ Gravação finalizada: {filename}")
    upload_to_abyss(filepath)

# ☁️ Etapa 3 – Upload para Abyss.to
def upload_to_abyss(filepath):
    url = 'http://up.hydrax.net/0128263f78f0b426d617bb61c2a8ff43'
    file_name = os.path.basename(filepath)
    file_type = 'video/mp4'

    with open(filepath, 'rb') as f:
        files = { 'file': (file_name, f, file_type) }
        response = requests.post(url, files=files)
        print(f"📤 Upload realizado: {response.text}")

# 🚀 Etapa 4 – Executar tudo em paralelo
if __name__ == '__main__':
    streams = get_broadcasts(limit=5)
    jobs = []

    for stream in streams:
        username = stream["username"]
        m3u8_url = stream["src"]
        p = multiprocessing.Process(target=gravar_stream, args=(username, m3u8_url))
        jobs.append(p)
        p.start()

    for job in jobs:
        job.join()

    print("🏁 Todas as gravações foram concluídas.")
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,702 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,735 kB]
# ...
